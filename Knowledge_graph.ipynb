# %% [markdown]
# # Using the final.json file

# %%
# reading all the json data as text, seeparating each {"document": x, "annotation":{y:z}} dict with a comma


data = [{"document": "The house plan has two bedrooms, two washrooms, two balconys, one livingroom, and one kitchen. To be specific, floor of bedroom1 is Quartz and White, and wall is Wall_Cloth and Yellow. bedroom1 is in southwest with 17 square meters. In addition, bedroom2 wall is White Bamboo_Vine as well as uses Wood_color Ceramics for floor. bedroom2 has 12 squares in north. washroom1 has Blue Wall_Cloth wall, and has Wood_color Jade floor. washroom1 has 5 squares in west. Besides, washroom2 has 3 squares in west. floor of washroom2 is Bamboo_Vine and Gray while wall is Blue Wood_Veneer. In addition, balcony1 is in south with 5 square meters. balcony1 floor is Earth_color Pure_Color_Wood as well as wall is Pure_Color_Wood and White. balcony2 wall is Orange Stone_Brick, and floor is Log and White. balcony2 covers 3 square meters located in north. Besides, wall of livingroom1 is Marble and Pink while floor is Orange Wood_Veneer. livingroom1 has 36 squares in center. kitchen1 has Gray Granite wall as well as floor is White Wall_Cloth. kitchen1 has 7 squares in northeast. bedroom1, bedroom2, kitchen1, balcony1, washroom1, washroom2, balcony2 and livingroom1 are connected. bedroom1 is adjacent to balcony1, washroom1. bedroom2 is next to washroom2, balcony2. kitchen1 is adjacent to balcony2. washroom2 and washroom1 are connected. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 31, "label": "ROOM", "text": "bedrooms"}, {"start": 33, "end": 36, "label": "QUANT", "text": "two"}, {"start": 37, "end": 46, "label": "ROOM", "text": "washrooms"}, {"start": 48, "end": 51, "label": "QUANT", "text": "two"}, {"start": 52, "end": 60, "label": "ROOM", "text": "balconys"}, {"start": 62, "end": 65, "label": "QUANT", "text": "one"}, {"start": 66, "end": 76, "label": "ROOM", "text": "livingroom"}, {"start": 82, "end": 85, "label": "QUANT", "text": "one"}, {"start": 86, "end": 93, "label": "ROOM", "text": "kitchen"}, {"start": 120, "end": 128, "label": "ROOM", "text": "bedroom1"}, {"start": 200, "end": 209, "label": "DIRECTION", "text": "southwest"}, {"start": 215, "end": 231, "label": "DIMENSION", "text": "17 square meters"}, {"start": 246, "end": 254, "label": "ROOM", "text": "bedroom2"}, {"start": 341, "end": 351, "label": "DIMENSION", "text": "12 squares"}, {"start": 355, "end": 360, "label": "DIRECTION", "text": "north"}, {"start": 362, "end": 371, "label": "ROOM", "text": "washroom1"}, {"start": 443, "end": 452, "label": "DIMENSION", "text": "5 squares"}, {"start": 456, "end": 460, "label": "DIRECTION", "text": "west"}, {"start": 471, "end": 480, "label": "ROOM", "text": "washroom2"}, {"start": 485, "end": 494, "label": "DIMENSION", "text": "3 squares"}, {"start": 498, "end": 502, "label": "DIRECTION", "text": "west"}, {"start": 592, "end": 600, "label": "ROOM", "text": "balcony1"}, {"start": 607, "end": 612, "label": "DIRECTION", "text": "south"}, {"start": 618, "end": 633, "label": "DIMENSION", "text": "5 square meters"}, {"start": 727, "end": 735, "label": "ROOM", "text": "balcony2"}, {"start": 808, "end": 823, "label": "DIMENSION", "text": "3 square meters"}, {"start": 835, "end": 840, "label": "DIRECTION", "text": "north"}, {"start": 859, "end": 870, "label": "ROOM", "text": "livingroom1"}, {"start": 941, "end": 951, "label": "DIMENSION", "text": "36 squares"}, {"start": 963, "end": 971, "label": "ROOM", "text": "kitchen1"}, {"start": 1045, "end": 1054, "label": "DIMENSION", "text": "7 squares"}, {"start": 1058, "end": 1067, "label": "DIRECTION", "text": "northeast"}, {"start": 1069, "end": 1169, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, balcony1, washroom1, washroom2, balcony2 and livingroom1 are connected"}, {"start": 1171, "end": 1214, "label": "CONNECTION", "text": "bedroom1 is adjacent to balcony1, washroom1"}, {"start": 1216, "end": 1255, "label": "CONNECTION", "text": "bedroom2 is next to washroom2, balcony2"}, {"start": 1257, "end": 1289, "label": "CONNECTION", "text": "kitchen1 is adjacent to balcony2"}, {"start": 1291, "end": 1328, "label": "CONNECTION", "text": "washroom2 and washroom1 are connected"}]},
{"document": "House has one washroom, one livingroom, one study, two bedrooms, one kitchen, and one balcony. In practice, washroom1 has 5 squares in east. washroom1 wall is Green Pure_Color_Wood as well as floor is Pink Mosaic. livingroom1 uses Orange Jade for floor while has Blue Wallpaper wall. livingroom1 is in center with 31 square meters. Additionally, study1 has 9 squares in northwest. study1 floor is Yellow Rock_Plate as well as wall is Gray Stone_Brick. bedroom1 is in southeast with 13 square meters. bedroom1 uses Yellow Wall_Cloth for floor while has Blue Wood_Grain wall. bedroom2 has Yellow Ceramic_Tile floor, and wall is Wood_color Wood_Grain. bedroom2 covers 11 square meters located in west. Besides, kitchen1 covers 6 square meters located in northeast. kitchen1 has Black Quartz floor while wall is Coating and Earth_color. balcony1 uses Yellow Ceramic_Tile for floor, and wall is Cement_Board and Blue. balcony1 has 7 squares in south. bedroom1, bedroom2, study1, balcony1, kitchen1, washroom1 and livingroom1 are connected. bedroom1 is next to balcony1, washroom1. bedroom2 is adjacent to study1. kitchen1 is next to washroom1. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "one"}, {"start": 14, "end": 22, "label": "ROOM", "text": "washroom"}, {"start": 24, "end": 27, "label": "QUANT", "text": "one"}, {"start": 28, "end": 38, "label": "ROOM", "text": "livingroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 49, "label": "ROOM", "text": "study"}, {"start": 51, "end": 54, "label": "QUANT", "text": "two"}, {"start": 55, "end": 63, "label": "ROOM", "text": "bedrooms"}, {"start": 65, "end": 68, "label": "QUANT", "text": "one"}, {"start": 69, "end": 76, "label": "ROOM", "text": "kitchen"}, {"start": 82, "end": 85, "label": "QUANT", "text": "one"}, {"start": 86, "end": 93, "label": "ROOM", "text": "balcony"}, {"start": 108, "end": 117, "label": "ROOM", "text": "washroom1"}, {"start": 122, "end": 131, "label": "DIMENSION", "text": "5 squares"}, {"start": 135, "end": 139, "label": "DIRECTION", "text": "east"}, {"start": 214, "end": 225, "label": "ROOM", "text": "livingroom1"}, {"start": 314, "end": 330, "label": "DIMENSION", "text": "31 square meters"}, {"start": 346, "end": 352, "label": "ROOM", "text": "study1"}, {"start": 357, "end": 366, "label": "DIMENSION", "text": "9 squares"}, {"start": 370, "end": 379, "label": "DIRECTION", "text": "northwest"}, {"start": 452, "end": 460, "label": "ROOM", "text": "bedroom1"}, {"start": 467, "end": 476, "label": "DIRECTION", "text": "southeast"}, {"start": 482, "end": 498, "label": "DIMENSION", "text": "13 square meters"}, {"start": 500, "end": 508, "label": "ROOM", "text": "bedroom1"}, {"start": 574, "end": 582, "label": "ROOM", "text": "bedroom2"}, {"start": 665, "end": 681, "label": "DIMENSION", "text": "11 square meters"}, {"start": 693, "end": 697, "label": "DIRECTION", "text": "west"}, {"start": 708, "end": 716, "label": "ROOM", "text": "kitchen1"}, {"start": 724, "end": 739, "label": "ROOM", "text": "6 square meters"}, {"start": 751, "end": 760, "label": "DIRECTION", "text": "northeast"}, {"start": 833, "end": 841, "label": "ROOM", "text": "balcony1"}, {"start": 913, "end": 921, "label": "ROOM", "text": "balcony1"}, {"start": 926, "end": 935, "label": "DIMENSION", "text": "7 squares"}, {"start": 939, "end": 944, "label": "DIRECTION", "text": "south"}, {"start": 946, "end": 1033, "label": "CONNECTION", "text": "bedroom1, bedroom2, study1, balcony1, kitchen1, washroom1 and livingroom1 are connected"}, {"start": 1035, "end": 1074, "label": "CONNECTION", "text": "bedroom1 is next to balcony1, washroom1"}, {"start": 1076, "end": 1137, "label": "CONNECTION", "text": "bedroom2 is adjacent to study1. kitchen1 is next to washroom1"}]},
{"document": "House has three bedrooms, one washroom, one balcony, one livingroom, and one kitchen. Specifically, bedroom1 is in northwest with 15 square meters. bedroom1 has Blue Granite wall as well as uses Gray Ceramic_Tile for floor. Additionally, bedroom2 wall is Yellow Coating while uses Blue Log for floor. bedroom2 is in northeast with 11 square meters. Besides, bedroom3 covers 9 square meters located in southeast. bedroom3 uses Orange Bamboo_Vine for floor as well as has Black Rock_Plate wall. washroom1 covers 4 square meters located in north. floor of washroom1 is Bamboo_Vine and Earth_color while wall is Orange Wood_Grain. balcony1 uses Green Log for floor as well as wall is Wallpaper and Wood_color. balcony1 covers 7 square meters located in west. livingroom1 wall is Gray Pure_Color_Wood, and has Wood_color Painted_Wood floor. livingroom1 has 37 squares in center. Additionally, wall of kitchen1 is Wood_Grain and Black as well as floor is Yellow Log. kitchen1 is in southeast with 7 square meters. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1. bedroom1 is next to balcony1, washroom1. bedroom2 is adjacent to washroom1. kitchen1 and bedroom3 are connected. ", "annotation": [{"start": 10, "end": 15, "label": "QUANT", "text": "three"}, {"start": 16, "end": 24, "label": "ROOM", "text": "bedrooms"}, {"start": 26, "end": 29, "label": "QUANT", "text": "one"}, {"start": 30, "end": 38, "label": "ROOM", "text": "washroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 51, "label": "ROOM", "text": "balcony"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 67, "label": "ROOM", "text": "livingroom"}, {"start": 73, "end": 76, "label": "QUANT", "text": "one"}, {"start": 77, "end": 84, "label": "ROOM", "text": "kitchen"}, {"start": 100, "end": 108, "label": "ROOM", "text": "bedroom1"}, {"start": 115, "end": 124, "label": "DIRECTION", "text": "northwest"}, {"start": 130, "end": 146, "label": "DIMENSION", "text": "15 square meters"}, {"start": 148, "end": 156, "label": "ROOM", "text": "bedroom1"}, {"start": 238, "end": 246, "label": "ROOM", "text": "bedroom2"}, {"start": 316, "end": 325, "label": "DIRECTION", "text": "northeast"}, {"start": 331, "end": 340, "label": "DIMENSION", "text": "11 square"}, {"start": 358, "end": 366, "label": "ROOM", "text": "bedroom3"}, {"start": 374, "end": 389, "label": "DIMENSION", "text": "9 square meters"}, {"start": 401, "end": 410, "label": "DIRECTION", "text": "southeast"}, {"start": 493, "end": 502, "label": "ROOM", "text": "washroom1"}, {"start": 510, "end": 525, "label": "DIMENSION", "text": "4 square meters"}, {"start": 537, "end": 542, "label": "DIRECTION", "text": "north"}, {"start": 627, "end": 635, "label": "ROOM", "text": "balcony1"}, {"start": 715, "end": 737, "label": "DIMENSION", "text": "covers 7 square meters"}, {"start": 749, "end": 753, "label": "DIRECTION", "text": "west"}, {"start": 755, "end": 766, "label": "ROOM", "text": "livingroom1"}, {"start": 852, "end": 862, "label": "DIMENSION", "text": "37 squares"}, {"start": 961, "end": 969, "label": "ROOM", "text": "kitchen1"}, {"start": 976, "end": 985, "label": "DIRECTION", "text": "southeast"}, {"start": 991, "end": 1006, "label": "DIMENSION", "text": "7 square meters"}, {"start": 1008, "end": 1094, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1"}, {"start": 1096, "end": 1135, "label": "CONNECTION", "text": "bedroom1 is next to balcony1, washroom1"}, {"start": 1137, "end": 1170, "label": "CONNECTION", "text": "bedroom2 is adjacent to washroom1"}, {"start": 1172, "end": 1207, "label": "CONNECTION", "text": "kitchen1 and bedroom3 are connected"}]},
{"document": "Building layout contains two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. In practice, bedroom1 uses Purple Rock_Plate for floor, and wall is Green Quartz. bedroom1 has 15 squares in southeast. Moreover, bedroom2 covers 13 square meters located in west. floor of bedroom2 is Wall_Cloth and Green as well as wall is Wood_Grain and Black. washroom1 has 4 squares in south. washroom1 has White Ceramics wall, and floor is Orange Stone_Brick. balcony1 is in northwest with 4 square meters. floor of balcony1 is Coating and Purple as well as wall is Quartz and Red. In addition, livingroom1 wall is Orange Quartz while has Black Painted_Wood floor. livingroom1 covers 31 square meters located in center. kitchen1 covers 6 square meters located in north. kitchen1 has Black Wall_Cloth wall as well as floor is Wood_Veneer and Red. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1, balcony1. washroom1 and bedroom1 are connected. bedroom2 is adjacent to washroom1. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "two"}, {"start": 29, "end": 37, "label": "ROOM", "text": "bedrooms"}, {"start": 39, "end": 42, "label": "QUANT", "text": "one"}, {"start": 43, "end": 51, "label": "ROOM", "text": "washroom"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 64, "label": "ROOM", "text": "balcony"}, {"start": 66, "end": 69, "label": "QUANT", "text": "one"}, {"start": 70, "end": 80, "label": "ROOM", "text": "livingroom"}, {"start": 86, "end": 89, "label": "QUANT", "text": "one"}, {"start": 90, "end": 97, "label": "ROOM", "text": "kitchen"}, {"start": 112, "end": 120, "label": "ROOM", "text": "bedroom1"}, {"start": 194, "end": 204, "label": "DIMENSION", "text": "15 squares"}, {"start": 208, "end": 217, "label": "DIRECTION", "text": "southeast"}, {"start": 229, "end": 237, "label": "ROOM", "text": "bedroom2"}, {"start": 245, "end": 261, "label": "DIMENSION", "text": "13 square meters"}, {"start": 273, "end": 277, "label": "DIRECTION", "text": "west"}, {"start": 362, "end": 371, "label": "ROOM", "text": "washroom1"}, {"start": 376, "end": 385, "label": "DIMENSION", "text": "4 squares"}, {"start": 389, "end": 394, "label": "DIRECTION", "text": "south"}, {"start": 464, "end": 472, "label": "ROOM", "text": "balcony1"}, {"start": 479, "end": 488, "label": "DIRECTION", "text": "northwest"}, {"start": 494, "end": 509, "label": "DIMENSION", "text": "4 square meters"}, {"start": 599, "end": 610, "label": "ROOM", "text": "livingroom1"}, {"start": 688, "end": 704, "label": "DIMENSION", "text": "31 square meters"}, {"start": 724, "end": 732, "label": "ROOM", "text": "kitchen1"}, {"start": 740, "end": 755, "label": "DIMENSION", "text": "6 square meters"}, {"start": 767, "end": 772, "label": "DIRECTION", "text": "north"}, {"start": 850, "end": 926, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1, balcony1"}, {"start": 928, "end": 964, "label": "CONNECTION", "text": "washroom1 and bedroom1 are connected"}, {"start": 966, "end": 999, "label": "CONNECTION", "text": "bedroom2 is adjacent to washroom1"}]},
{"document": "Building layout contains three bedrooms, two washrooms, two balconys, one livingroom, and one kitchen. Specifically, bedroom1 floor is Green Granite as well as wall is Pure_Color_Wood and Yellow. bedroom1 has 13 squares in northwest. bedroom2 has 11 squares in northeast. bedroom2 wall is Red Jade, and has Black Jade floor. Moreover, bedroom3 covers 10 square meters located in southwest. bedroom3 uses Blue Rock_Plate for floor as well as wall is Purple Ceramics. Besides, washroom1 is in north with 3 square meters. washroom1 uses Black Mosaic for floor, and wall is Wood_Grain and White. washroom2 has Yellow Ceramics floor as well as wall is Ceramics and Red. washroom2 has 3 squares in north. Additionally, balcony1 is in west with 7 square meters. balcony1 uses Green Cement_Board for floor while has Red Painted_Wood wall. balcony2 is in east with 4 square meters. balcony2 wall is Red Marble, and floor is Wall_Cloth and Green. livingroom1 has 42 squares in center. livingroom1 has Red Painted_Wood floor as well as wall is Orange Stone_Brick. kitchen1 is in southeast with 5 square meters. kitchen1 wall is Blue Wallpaper while floor is Earth_color Bamboo_Vine. bedroom1, bedroom2, bedroom3, balcony1, kitchen1, balcony2, washroom2 and livingroom1 are connected. bedroom1 is next to washroom1. washroom2 and bedroom2 are connected. bedroom3 is next to balcony1. washroom2 and washroom1 are connected. ", "annotation": [{"start": 25, "end": 30, "label": "QUANT", "text": "three"}, {"start": 31, "end": 39, "label": "ROOM", "text": "bedrooms"}, {"start": 41, "end": 44, "label": "QUANT", "text": "two"}, {"start": 45, "end": 54, "label": "ROOM", "text": "washrooms"}, {"start": 56, "end": 59, "label": "QUANT", "text": "two"}, {"start": 60, "end": 68, "label": "ROOM", "text": "balconys"}, {"start": 70, "end": 73, "label": "QUANT", "text": "one"}, {"start": 74, "end": 84, "label": "ROOM", "text": "livingroom"}, {"start": 90, "end": 93, "label": "QUANT", "text": "one"}, {"start": 94, "end": 101, "label": "ROOM", "text": "kitchen"}, {"start": 117, "end": 125, "label": "ROOM", "text": "bedroom1"}, {"start": 196, "end": 204, "label": "ROOM", "text": "bedroom1"}, {"start": 209, "end": 219, "label": "DIMENSION", "text": "13 squares"}, {"start": 223, "end": 232, "label": "DIRECTION", "text": "northwest"}, {"start": 234, "end": 242, "label": "ROOM", "text": "bedroom2"}, {"start": 247, "end": 257, "label": "DIMENSION", "text": "11 squares"}, {"start": 261, "end": 270, "label": "DIRECTION", "text": "northeast"}, {"start": 335, "end": 343, "label": "ROOM", "text": "bedroom3"}, {"start": 351, "end": 367, "label": "DIMENSION", "text": "10 square meters"}, {"start": 379, "end": 388, "label": "DIRECTION", "text": "southwest"}, {"start": 390, "end": 398, "label": "ROOM", "text": "bedroom3"}, {"start": 475, "end": 484, "label": "ROOM", "text": "washroom1"}, {"start": 491, "end": 496, "label": "DIRECTION", "text": "north"}, {"start": 502, "end": 517, "label": "ROOM", "text": "3 square meters"}, {"start": 592, "end": 601, "label": "ROOM", "text": "washroom2"}, {"start": 679, "end": 688, "label": "DIMENSION", "text": "3 squares"}, {"start": 692, "end": 697, "label": "DIRECTION", "text": "north"}, {"start": 713, "end": 721, "label": "ROOM", "text": "balcony1"}, {"start": 728, "end": 732, "label": "DIRECTION", "text": "west"}, {"start": 738, "end": 753, "label": "DIMENSION", "text": "7 square meters"}, {"start": 831, "end": 839, "label": "ROOM", "text": "balcony2"}, {"start": 846, "end": 850, "label": "DIRECTION", "text": "east"}, {"start": 856, "end": 871, "label": "DIMENSION", "text": "4 square meters"}, {"start": 937, "end": 948, "label": "ROOM", "text": "livingroom1"}, {"start": 953, "end": 963, "label": "DIMENSION", "text": "42 squares"}, {"start": 1053, "end": 1061, "label": "ROOM", "text": "kitchen1"}, {"start": 1068, "end": 1077, "label": "DIRECTION", "text": "southeast"}, {"start": 1083, "end": 1098, "label": "DIMENSION", "text": "5 square meters"}, {"start": 1100, "end": 1108, "label": "ROOM", "text": "kitchen1"}, {"start": 1172, "end": 1271, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, balcony1, kitchen1, balcony2, washroom2 and livingroom1 are connected"}, {"start": 1273, "end": 1302, "label": "CONNECTION", "text": "bedroom1 is next to washroom1"}, {"start": 1304, "end": 1340, "label": "CONNECTION", "text": "washroom2 and bedroom2 are connected"}, {"start": 1342, "end": 1370, "label": "CONNECTION", "text": "bedroom3 is next to balcony1"}, {"start": 1372, "end": 1409, "label": "CONNECTION", "text": "washroom2 and washroom1 are connected"}]},
{"document": "Building layout contains two bedrooms, two washrooms, one balcony, one livingroom, and one kitchen. To be specific, bedroom1 has 14 squares in east. bedroom1 uses Earth_color Marble for floor as well as wall is Green Painted_Wood. In addition, bedroom2 wall is Wood_color Ceramics, and floor is Pink Wood_Grain. bedroom2 covers 8 square meters located in north. washroom1 covers 3 square meters located in southeast. washroom1 floor is Red Mosaic as well as wall is Stone_Brick and Earth_color. Besides, washroom2 covers 2 square meters located in southeast. wall of washroom2 is Wall_Cloth and Green while floor is Ceramics and Black. In addition, balcony1 is in northeast with 5 square meters. balcony1 has Purple Pure_Color_Wood wall as well as floor is Rock_Plate and Earth_color. Additionally, livingroom1 covers 20 square meters located in southwest. floor of livingroom1 is Ceramic_Tile and Yellow, and wall is Orange Jade. kitchen1 wall is White Pure_Color_Wood as well as floor is Yellow Marble. kitchen1 is in northwest with 11 square meters. livingroom1 is adjacent to bedroom1, kitchen1, washroom2. bedroom1 is next to bedroom2, balcony1, washroom1, washroom2. bedroom2 and kitchen1 are connected. bedroom2 is next to balcony1. washroom2 and washroom1 are connected. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "two"}, {"start": 29, "end": 37, "label": "ROOM", "text": "bedrooms"}, {"start": 39, "end": 42, "label": "QUANT", "text": "two"}, {"start": 43, "end": 52, "label": "ROOM", "text": "washrooms"}, {"start": 54, "end": 57, "label": "QUANT", "text": "one"}, {"start": 58, "end": 65, "label": "ROOM", "text": "balcony"}, {"start": 67, "end": 70, "label": "QUANT", "text": "one"}, {"start": 71, "end": 81, "label": "ROOM", "text": "livingroom"}, {"start": 87, "end": 90, "label": "QUANT", "text": "one"}, {"start": 91, "end": 98, "label": "ROOM", "text": "kitchen"}, {"start": 116, "end": 124, "label": "ROOM", "text": "bedroom1"}, {"start": 129, "end": 139, "label": "DIMENSION", "text": "14 squares"}, {"start": 143, "end": 147, "label": "DIRECTION", "text": "east"}, {"start": 244, "end": 252, "label": "ROOM", "text": "bedroom2"}, {"start": 328, "end": 343, "label": "DIMENSION", "text": "8 square meters"}, {"start": 355, "end": 360, "label": "DIRECTION", "text": "north"}, {"start": 362, "end": 371, "label": "ROOM", "text": "washroom1"}, {"start": 379, "end": 394, "label": "DIMENSION", "text": "3 square meters"}, {"start": 406, "end": 415, "label": "DIRECTION", "text": "southeast"}, {"start": 504, "end": 513, "label": "ROOM", "text": "washroom2"}, {"start": 521, "end": 536, "label": "DIMENSION", "text": "2 square meters"}, {"start": 548, "end": 557, "label": "DIRECTION", "text": "southeast"}, {"start": 649, "end": 657, "label": "ROOM", "text": "balcony1"}, {"start": 664, "end": 673, "label": "DIRECTION", "text": "northeast"}, {"start": 679, "end": 694, "label": "DIMENSION", "text": "5 square meters"}, {"start": 799, "end": 810, "label": "ROOM", "text": "livingroom1"}, {"start": 818, "end": 834, "label": "DIMENSION", "text": "20 square meters"}, {"start": 846, "end": 855, "label": "DIRECTION", "text": "southwest"}, {"start": 931, "end": 939, "label": "ROOM", "text": "kitchen1"}, {"start": 1020, "end": 1029, "label": "DIRECTION", "text": "northwest"}, {"start": 1035, "end": 1051, "label": "DIMENSION", "text": "11 square meters"}, {"start": 1053, "end": 1109, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, kitchen1, washroom2"}, {"start": 1111, "end": 1171, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2, balcony1, washroom1, washroom2"}, {"start": 1173, "end": 1208, "label": "CONNECTION", "text": "bedroom2 and kitchen1 are connected"}, {"start": 1210, "end": 1238, "label": "CONNECTION", "text": "bedroom2 is next to balcony1"}, {"start": 1240, "end": 1277, "label": "CONNECTION", "text": "washroom2 and washroom1 are connected"}]},
{"document": "House has three bedrooms, one washroom, two balconys, one livingroom, and one kitchen. In practice, bedroom1 has Gray Painted_Wood wall as well as floor is Pink Bamboo_Vine. bedroom1 is in south with 13 square meters. bedroom2 has Purple Granite floor while has Purple Pure_Color_Wood wall. bedroom2 has 9 squares in north. Additionally, bedroom3 has 5 squares in west. bedroom3 has Purple Wall_Cloth wall as well as has Wood_color Ceramic_Tile floor. washroom1 floor is Pink Wood_Veneer while has Red Marble wall. washroom1 has 4 squares in west. wall of balcony1 is Marble and Black, and has Blue Pure_Color_Wood floor. balcony1 is in south with 6 square meters. balcony2 has 2 squares in north. balcony2 wall is Wood_color Rock_Plate while floor is Painted_Wood and Gray. Moreover, floor of livingroom1 is Granite and Black as well as wall is Green Granite. livingroom1 has 29 squares in center. kitchen1 has 5 squares in north. kitchen1 has Wood_color Log wall while has Purple Ceramic_Tile floor. livingroom1 is adjacent to bedroom1, bedroom2, balcony1, bedroom3, kitchen1, washroom1. balcony1, bedroom3 and bedroom1 are connected. bedroom2 is adjacent to kitchen1, washroom1, balcony2. bedroom3 is next to washroom1. balcony2 and kitchen1 are connected. ", "annotation": [{"start": 10, "end": 15, "label": "QUANT", "text": "three"}, {"start": 16, "end": 24, "label": "ROOM", "text": "bedrooms"}, {"start": 26, "end": 29, "label": "QUANT", "text": "one"}, {"start": 30, "end": 38, "label": "ROOM", "text": "washroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "two"}, {"start": 44, "end": 52, "label": "ROOM", "text": "balconys"}, {"start": 54, "end": 57, "label": "QUANT", "text": "one"}, {"start": 58, "end": 68, "label": "ROOM", "text": "livingroom"}, {"start": 74, "end": 77, "label": "QUANT", "text": "one"}, {"start": 78, "end": 85, "label": "ROOM", "text": "kitchen"}, {"start": 100, "end": 108, "label": "ROOM", "text": "bedroom1"}, {"start": 189, "end": 194, "label": "DIRECTION", "text": "south"}, {"start": 200, "end": 216, "label": "DIMENSION", "text": "13 square meters"}, {"start": 218, "end": 226, "label": "ROOM", "text": "bedroom2"}, {"start": 291, "end": 299, "label": "ROOM", "text": "bedroom2"}, {"start": 304, "end": 313, "label": "DIMENSION", "text": "9 squares"}, {"start": 317, "end": 322, "label": "DIRECTION", "text": "north"}, {"start": 351, "end": 360, "label": "DIMENSION", "text": "5 squares"}, {"start": 637, "end": 642, "label": "DIRECTION", "text": "south"}, {"start": 648, "end": 663, "label": "DIMENSION", "text": "6 square meters"}, {"start": 665, "end": 673, "label": "ROOM", "text": "balcony2"}, {"start": 678, "end": 687, "label": "DIMENSION", "text": "2 squares"}, {"start": 691, "end": 696, "label": "DIRECTION", "text": "north"}, {"start": 794, "end": 805, "label": "ROOM", "text": "livingroom1"}, {"start": 861, "end": 872, "label": "ROOM", "text": "livingroom1"}, {"start": 877, "end": 887, "label": "DIMENSION", "text": "29 squares"}, {"start": 899, "end": 907, "label": "ROOM", "text": "kitchen1"}, {"start": 912, "end": 921, "label": "DIMENSION", "text": "5 squares"}, {"start": 925, "end": 930, "label": "DIRECTION", "text": "north"}, {"start": 1002, "end": 1088, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, balcony1, bedroom3, kitchen1, washroom1"}, {"start": 1090, "end": 1135, "label": "CONNECTION", "text": "balcony1, bedroom3 and bedroom1 are connected"}, {"start": 1137, "end": 1190, "label": "CONNECTION", "text": "bedroom2 is adjacent to kitchen1, washroom1, balcony2"}, {"start": 1192, "end": 1221, "label": "CONNECTION", "text": "bedroom3 is next to washroom1"}, {"start": 1223, "end": 1258, "label": "CONNECTION", "text": "balcony2 and kitchen1 are connected"}]},
{"document": "The house plan has two washrooms, one livingroom, one closet, three bedrooms, one kitchen, and one balcony. Specifically, washroom1 covers 5 square meters located in center. floor of washroom1 is Ceramic_Tile and Earth_color, and has Gray Mosaic wall. washroom2 has 4 squares in north. wall of washroom2 is Wood_Veneer and Orange as well as has Yellow Ceramic_Tile floor. livingroom1 uses Green Quartz for floor, and wall is Ceramics and Red. livingroom1 has 45 squares in east. Additionally, closet1 has Green Wallpaper wall while floor is Wood_color Coating. closet1 covers 8 square meters located in north. Moreover, bedroom1 is in west with 19 square meters. bedroom1 has Gray Mosaic wall as well as floor is Orange Cement_Board. Additionally, bedroom2 has 15 squares in center. wall of bedroom2 is Wallpaper and White, and floor is Red Marble. In addition, bedroom3 has 10 squares in west. bedroom3 floor is Yellow Rock_Plate as well as has Yellow Ceramics wall. Moreover, kitchen1 covers 8 square meters located in northeast. kitchen1 has Gray Jade wall, and uses Yellow Wood_Grain for floor. balcony1 is in west with 5 square meters. balcony1 floor is Yellow Granite as well as wall is White Wallpaper. bedroom1, bedroom2, bedroom3, closet1, kitchen1, washroom1 and livingroom1 are connected. bedroom1 is next to bedroom3, washroom2. washroom1 and bedroom2 are connected. bedroom3 is adjacent to balcony1, washroom1. closet1 is next to washroom2. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 32, "label": "ROOM", "text": "washrooms"}, {"start": 34, "end": 37, "label": "QUANT", "text": "one"}, {"start": 38, "end": 48, "label": "ROOM", "text": "livingroom"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 60, "label": "ROOM", "text": "closet"}, {"start": 62, "end": 67, "label": "QUANT", "text": "three"}, {"start": 68, "end": 76, "label": "ROOM", "text": "bedrooms"}, {"start": 78, "end": 81, "label": "QUANT", "text": "one"}, {"start": 82, "end": 89, "label": "ROOM", "text": "kitchen"}, {"start": 95, "end": 98, "label": "QUANT", "text": "one"}, {"start": 99, "end": 106, "label": "ROOM", "text": "balcony"}, {"start": 122, "end": 131, "label": "ROOM", "text": "washroom1"}, {"start": 139, "end": 154, "label": "DIMENSION", "text": "5 square meters"}, {"start": 183, "end": 192, "label": "ROOM", "text": "washroom1"}, {"start": 252, "end": 261, "label": "ROOM", "text": "washroom2"}, {"start": 266, "end": 275, "label": "DIMENSION", "text": "4 squares"}, {"start": 279, "end": 284, "label": "DIRECTION", "text": "north"}, {"start": 294, "end": 303, "label": "ROOM", "text": "washroom2"}, {"start": 372, "end": 383, "label": "ROOM", "text": "livingroom1"}, {"start": 459, "end": 469, "label": "DIMENSION", "text": "45 squares"}, {"start": 473, "end": 477, "label": "DIRECTION", "text": "east"}, {"start": 493, "end": 500, "label": "ROOM", "text": "closet1"}, {"start": 576, "end": 591, "label": "DIMENSION", "text": "8 square meters"}, {"start": 603, "end": 608, "label": "DIRECTION", "text": "north"}, {"start": 620, "end": 628, "label": "ROOM", "text": "bedroom1"}, {"start": 635, "end": 639, "label": "DIRECTION", "text": "west"}, {"start": 645, "end": 661, "label": "DIMENSION", "text": "19 square meters"}, {"start": 761, "end": 771, "label": "DIMENSION", "text": "15 squares"}, {"start": 875, "end": 885, "label": "DIMENSION", "text": "10 squares"}, {"start": 889, "end": 893, "label": "DIRECTION", "text": "west"}, {"start": 895, "end": 903, "label": "ROOM", "text": "bedroom3"}, {"start": 978, "end": 986, "label": "ROOM", "text": "kitchen1"}, {"start": 994, "end": 1009, "label": "DIMENSION", "text": "8 square meters"}, {"start": 1114, "end": 1118, "label": "DIRECTION", "text": "west"}, {"start": 1124, "end": 1139, "label": "DIMENSION", "text": "5 square meters"}, {"start": 1141, "end": 1149, "label": "ROOM", "text": "balcony1"}, {"start": 1210, "end": 1298, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, closet1, kitchen1, washroom1 and livingroom1 are connected"}, {"start": 1300, "end": 1339, "label": "CONNECTION", "text": "bedroom1 is next to bedroom3, washroom2"}, {"start": 1341, "end": 1377, "label": "CONNECTION", "text": "washroom1 and bedroom2 are connected"}, {"start": 1379, "end": 1422, "label": "CONNECTION", "text": "bedroom3 is adjacent to balcony1, washroom1"}, {"start": 1424, "end": 1452, "label": "CONNECTION", "text": "closet1 is next to washroom2"}]},
{"document": "The building contains two washrooms, two livingrooms, one storage, three bedrooms, one kitchen, and one balcony. More specifically, washroom1 wall is White Quartz, and uses Green Coating for floor. washroom1 has 5 squares in west. In addition, washroom2 is in west with 4 square meters. washroom2 floor is Purple Marble as well as wall is Coating and Green. Additionally, livingroom1 has 39 squares in center. livingroom1 wall is Pink Coating while has Red Log floor. livingroom2 has Black Mosaic floor, and has Orange Wall_Cloth wall. livingroom2 is in west with 3 square meters. Moreover, storage1 covers 4 square meters located in northeast. storage1 has Gray Ceramics wall as well as has Yellow Ceramic_Tile floor. bedroom1 covers 18 square meters located in southwest. bedroom1 has Gray Cement_Board wall, and uses Blue Wood_Grain for floor. bedroom2 has Black Bamboo_Vine wall while floor is Jade and White. bedroom2 is in southeast with 11 square meters. bedroom3 is in northwest with 10 square meters. floor of bedroom3 is Marble and Blue as well as has Green Ceramics wall. kitchen1 is in north with 7 square meters. floor of kitchen1 is Bamboo_Vine and Red, and wall is Earth_color Wall_Cloth. In addition, balcony1 is in south with 6 square meters. balcony1 uses Green Quartz for floor as well as wall is Wood_Veneer and Green. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, storage1, livingroom2. balcony1, washroom1, livingroom2 and bedroom1 are connected. bedroom3 is adjacent to kitchen1, washroom2, livingroom2. storage1 and kitchen1 are connected. washroom1 is adjacent to washroom2, livingroom2. washroom2 is next to livingroom2. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "two"}, {"start": 26, "end": 35, "label": "ROOM", "text": "washrooms"}, {"start": 37, "end": 40, "label": "QUANT", "text": "two"}, {"start": 41, "end": 52, "label": "ROOM", "text": "livingrooms"}, {"start": 54, "end": 57, "label": "QUANT", "text": "one"}, {"start": 58, "end": 65, "label": "ROOM", "text": "storage"}, {"start": 67, "end": 72, "label": "QUANT", "text": "three"}, {"start": 73, "end": 81, "label": "ROOM", "text": "bedrooms"}, {"start": 83, "end": 86, "label": "QUANT", "text": "one"}, {"start": 87, "end": 94, "label": "ROOM", "text": "kitchen"}, {"start": 100, "end": 103, "label": "QUANT", "text": "one"}, {"start": 104, "end": 111, "label": "ROOM", "text": "balcony"}, {"start": 132, "end": 141, "label": "ROOM", "text": "washroom1"}, {"start": 212, "end": 221, "label": "DIMENSION", "text": "5 squares"}, {"start": 225, "end": 229, "label": "DIRECTION", "text": "west"}, {"start": 244, "end": 253, "label": "ROOM", "text": "washroom2"}, {"start": 260, "end": 264, "label": "DIRECTION", "text": "west"}, {"start": 270, "end": 285, "label": "DIMENSION", "text": "4 square meters"}, {"start": 372, "end": 383, "label": "ROOM", "text": "livingroom1"}, {"start": 388, "end": 398, "label": "DIMENSION", "text": "39 squares"}, {"start": 410, "end": 421, "label": "ROOM", "text": "livingroom1"}, {"start": 554, "end": 558, "label": "DIRECTION", "text": "west"}, {"start": 564, "end": 579, "label": "DIMENSION", "text": "3 square meters"}, {"start": 591, "end": 599, "label": "ROOM", "text": "storage1"}, {"start": 607, "end": 622, "label": "DIMENSION", "text": "4 square meters"}, {"start": 634, "end": 643, "label": "DIRECTION", "text": "northeast"}, {"start": 719, "end": 727, "label": "ROOM", "text": "bedroom1"}, {"start": 735, "end": 751, "label": "DIMENSION", "text": "18 square meters"}, {"start": 763, "end": 772, "label": "DIRECTION", "text": "southwest"}, {"start": 847, "end": 855, "label": "ROOM", "text": "bedroom2"}, {"start": 914, "end": 922, "label": "ROOM", "text": "bedroom2"}, {"start": 929, "end": 938, "label": "DIRECTION", "text": "southeast"}, {"start": 944, "end": 960, "label": "DIMENSION", "text": "11 square meters"}, {"start": 962, "end": 970, "label": "ROOM", "text": "bedroom3"}, {"start": 977, "end": 986, "label": "DIRECTION", "text": "northwest"}, {"start": 992, "end": 1008, "label": "DIMENSION", "text": "10 square meters"}, {"start": 1019, "end": 1027, "label": "ROOM", "text": "bedroom3"}, {"start": 1083, "end": 1091, "label": "ROOM", "text": "kitchen1"}, {"start": 1098, "end": 1103, "label": "DIRECTION", "text": "north"}, {"start": 1109, "end": 1124, "label": "DIMENSION", "text": "7 square meters"}, {"start": 1135, "end": 1143, "label": "ROOM", "text": "kitchen1"}, {"start": 1217, "end": 1225, "label": "ROOM", "text": "balcony1"}, {"start": 1232, "end": 1237, "label": "DIRECTION", "text": "south"}, {"start": 1243, "end": 1258, "label": "DIMENSION", "text": "6 square meters"}, {"start": 1339, "end": 1437, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, storage1, livingroom2"}, {"start": 1439, "end": 1498, "label": "CONNECTION", "text": "balcony1, washroom1, livingroom2 and bedroom1 are connected"}, {"start": 1500, "end": 1556, "label": "CONNECTION", "text": "bedroom3 is adjacent to kitchen1, washroom2, livingroom2"}, {"start": 1558, "end": 1593, "label": "CONNECTION", "text": "storage1 and kitchen1 are connected"}, {"start": 1595, "end": 1642, "label": "CONNECTION", "text": "washroom1 is adjacent to washroom2, livingroom2"}, {"start": 1644, "end": 1676, "label": "CONNECTION", "text": "washroom2 is next to livingroom2"}]},
{"document": "Building layout contains two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. More specifically, bedroom1 has 15 squares in west. bedroom1 has White Bamboo_Vine wall as well as uses Yellow Marble for floor. bedroom2 floor is Blue Cement_Board while wall is Blue Granite. bedroom2 is in east with 12 square meters. washroom1 has 5 squares in center. wall of washroom1 is Stone_Brick and Pink as well as floor is Coating and Yellow. Moreover, balcony1 is in north with 6 square meters. balcony1 wall is Earth_color Coating while has Earth_color Rock_Plate floor. Additionally, livingroom1 floor is Yellow Ceramic_Tile as well as wall is Pink Cement_Board. livingroom1 is in center with 33 square meters. Besides, kitchen1 wall is White Stone_Brick while floor is Yellow Granite. kitchen1 is in southeast with 6 square meters. bedroom1, bedroom2, kitchen1, balcony1, washroom1 and livingroom1 are connected. bedroom1 is next to washroom1. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "two"}, {"start": 29, "end": 37, "label": "ROOM", "text": "bedrooms"}, {"start": 39, "end": 42, "label": "QUANT", "text": "one"}, {"start": 43, "end": 51, "label": "ROOM", "text": "washroom"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 64, "label": "ROOM", "text": "balcony"}, {"start": 66, "end": 69, "label": "QUANT", "text": "one"}, {"start": 70, "end": 80, "label": "ROOM", "text": "livingroom"}, {"start": 86, "end": 89, "label": "QUANT", "text": "one"}, {"start": 90, "end": 97, "label": "ROOM", "text": "kitchen"}, {"start": 118, "end": 126, "label": "ROOM", "text": "bedroom1"}, {"start": 131, "end": 141, "label": "DIMENSION", "text": "15 squares"}, {"start": 145, "end": 149, "label": "DIRECTION", "text": "west"}, {"start": 151, "end": 159, "label": "ROOM", "text": "bedroom1"}, {"start": 228, "end": 236, "label": "ROOM", "text": "bedroom2"}, {"start": 307, "end": 311, "label": "DIRECTION", "text": "east"}, {"start": 317, "end": 333, "label": "DIMENSION", "text": "12 square meters"}, {"start": 335, "end": 344, "label": "ROOM", "text": "washroom1"}, {"start": 349, "end": 358, "label": "DIMENSION", "text": "5 squares"}, {"start": 378, "end": 387, "label": "ROOM", "text": "washroom1"}, {"start": 462, "end": 470, "label": "ROOM", "text": "balcony1"}, {"start": 477, "end": 482, "label": "DIRECTION", "text": "north"}, {"start": 488, "end": 503, "label": "DIMENSION", "text": "6 square meters"}, {"start": 505, "end": 513, "label": "ROOM", "text": "balcony1"}, {"start": 596, "end": 607, "label": "ROOM", "text": "livingroom1"}, {"start": 705, "end": 721, "label": "DIMENSION", "text": "33 square meters"}, {"start": 732, "end": 740, "label": "ROOM", "text": "kitchen1"}, {"start": 813, "end": 822, "label": "DIRECTION", "text": "southeast"}, {"start": 828, "end": 843, "label": "DIMENSION", "text": "6 square meters"}, {"start": 845, "end": 924, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, balcony1, washroom1 and livingroom1 are connected"}, {"start": 926, "end": 955, "label": "CONNECTION", "text": "bedroom1 is next to washroom1"}]},
{"document": "Building layout contains one washroom, three bedrooms, one livingroom, and one kitchen. To be specific, washroom1 wall is Blue Wood_Grain, and uses Red Wood_Grain for floor. washroom1 covers 4 square meters located in east. Moreover, bedroom1 uses Black Painted_Wood for floor while wall is Wood_color Stone_Brick. bedroom1 has 15 squares in northeast. In addition, bedroom2 wall is Blue Wood_Grain as well as uses Earth_color Cement_Board for floor. bedroom2 has 10 squares in northwest. bedroom3 covers 11 square meters located in southeast. bedroom3 has Blue Wood_Grain wall, and has Orange Quartz floor. livingroom1 has 47 squares in center. livingroom1 has Orange Wood_Grain wall while floor is Black Wall_Cloth. kitchen1 uses Pink Wallpaper for floor, and wall is Jade and Wood_color. kitchen1 is in south with 7 square meters. bedroom1, bedroom2, bedroom3, kitchen1, washroom1 and livingroom1 are connected. bedroom1 is next to washroom1. kitchen1, washroom1 and bedroom3 are connected. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "one"}, {"start": 29, "end": 37, "label": "ROOM", "text": "washroom"}, {"start": 39, "end": 44, "label": "QUANT", "text": "three"}, {"start": 45, "end": 53, "label": "ROOM", "text": "bedrooms"}, {"start": 55, "end": 58, "label": "QUANT", "text": "one"}, {"start": 59, "end": 69, "label": "ROOM", "text": "livingroom"}, {"start": 75, "end": 78, "label": "QUANT", "text": "one"}, {"start": 79, "end": 86, "label": "ROOM", "text": "kitchen"}, {"start": 104, "end": 113, "label": "ROOM", "text": "washroom1"}, {"start": 174, "end": 183, "label": "ROOM", "text": "washroom1"}, {"start": 191, "end": 206, "label": "DIMENSION", "text": "4 square meters"}, {"start": 218, "end": 222, "label": "DIRECTION", "text": "east"}, {"start": 234, "end": 242, "label": "ROOM", "text": "bedroom1"}, {"start": 328, "end": 338, "label": "DIMENSION", "text": "15 squares"}, {"start": 342, "end": 351, "label": "DIRECTION", "text": "northeast"}, {"start": 366, "end": 374, "label": "DIRECTION", "text": "bedroom2"}, {"start": 464, "end": 474, "label": "DIMENSION", "text": "10 squares"}, {"start": 478, "end": 487, "label": "DIRECTION", "text": "northwest"}, {"start": 489, "end": 497, "label": "ROOM", "text": "bedroom3"}, {"start": 505, "end": 514, "label": "DIMENSION", "text": "11 square"}, {"start": 533, "end": 542, "label": "DIRECTION", "text": "southeast"}, {"start": 608, "end": 619, "label": "ROOM", "text": "livingroom1"}, {"start": 624, "end": 634, "label": "DIMENSION", "text": "47 squares"}, {"start": 718, "end": 726, "label": "ROOM", "text": "kitchen1"}, {"start": 806, "end": 811, "label": "DIRECTION", "text": "south"}, {"start": 817, "end": 832, "label": "DIMENSION", "text": "7 square meters"}, {"start": 834, "end": 913, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, kitchen1, washroom1 and livingroom1 are connected"}, {"start": 915, "end": 944, "label": "CONNECTION", "text": "bedroom1 is next to washroom1"}, {"start": 946, "end": 992, "label": "CONNECTION", "text": "kitchen1, washroom1 and bedroom3 are connected"}]},
{"document": "House has two washrooms, one livingroom, one closet, one bedroom, one kitchen, and two balconys. In practice, wall of washroom1 is Mosaic and Gray, and uses Black Jade for floor. washroom1 covers 4 square meters located in southeast. Additionally, washroom2 covers 2 square meters located in south. floor of washroom2 is Wood_Grain and Green while wall is Wood_Veneer and Red. In addition, floor of livingroom1 is Granite and Blue as well as wall is Black Ceramic_Tile. livingroom1 is in center with 36 square meters. closet1 floor is White Cement_Board while wall is Stone_Brick and Green. closet1 covers 6 square meters located in center. Besides, wall of bedroom1 is Pure_Color_Wood and White, and floor is Ceramics and Green. bedroom1 has 11 squares in east. Additionally, kitchen1 uses Purple Marble for floor as well as wall is Rock_Plate and Gray. kitchen1 has 13 squares in east. wall of balcony1 is Ceramic_Tile and Gray while has Black Wood_Veneer floor. balcony1 has 10 squares in west. Moreover, balcony2 has Earth_color Ceramic_Tile floor, and wall is Ceramics and Earth_color. balcony2 has 2 squares in southeast. livingroom1 is adjacent to kitchen1, balcony1, closet1, washroom2. kitchen1 is next to bedroom1, closet1, washroom1, balcony2, washroom2. closet1 and bedroom1 are connected. washroom1 is adjacent to balcony2, washroom2. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "two"}, {"start": 14, "end": 23, "label": "ROOM", "text": "washrooms"}, {"start": 25, "end": 28, "label": "QUANT", "text": "one"}, {"start": 29, "end": 39, "label": "ROOM", "text": "livingroom"}, {"start": 41, "end": 44, "label": "QUANT", "text": "one"}, {"start": 45, "end": 51, "label": "ROOM", "text": "closet"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 65, "label": "ROOM", "text": "bedroom,"}, {"start": 66, "end": 69, "label": "QUANT", "text": "one"}, {"start": 70, "end": 82, "label": "ROOM", "text": "kitchen, and"}, {"start": 83, "end": 86, "label": "QUANT", "text": "two"}, {"start": 87, "end": 95, "label": "ROOM", "text": "balconys"}, {"start": 118, "end": 127, "label": "ROOM", "text": "washroom1"}, {"start": 196, "end": 211, "label": "DIMENSION", "text": "4 square meters"}, {"start": 223, "end": 232, "label": "DIRECTION", "text": "southeast"}, {"start": 248, "end": 257, "label": "ROOM", "text": "washroom2"}, {"start": 265, "end": 280, "label": "DIMENSION", "text": "2 square meters"}, {"start": 292, "end": 297, "label": "DIRECTION", "text": "south"}, {"start": 399, "end": 410, "label": "ROOM", "text": "livingroom1"}, {"start": 500, "end": 516, "label": "DIMENSION", "text": "36 square meters"}, {"start": 518, "end": 525, "label": "ROOM", "text": "closet1"}, {"start": 606, "end": 621, "label": "DIMENSION", "text": "6 square meters"}, {"start": 658, "end": 666, "label": "ROOM", "text": "bedroom1"}, {"start": 743, "end": 753, "label": "DIMENSION", "text": "11 squares"}, {"start": 757, "end": 761, "label": "DIRECTION", "text": "east"}, {"start": 868, "end": 878, "label": "DIMENSION", "text": "13 squares"}, {"start": 882, "end": 886, "label": "DIRECTION", "text": "east"}, {"start": 896, "end": 904, "label": "ROOM", "text": "balcony1"}, {"start": 965, "end": 973, "label": "ROOM", "text": "balcony1"}, {"start": 978, "end": 988, "label": "DIMENSION", "text": "10 squares"}, {"start": 992, "end": 996, "label": "DIRECTION", "text": "west"}, {"start": 1008, "end": 1016, "label": "ROOM", "text": "balcony2"}, {"start": 1104, "end": 1113, "label": "DIMENSION", "text": "2 squares"}, {"start": 1117, "end": 1126, "label": "DIRECTION", "text": "southeast"}, {"start": 1128, "end": 1193, "label": "CONNECTION", "text": "livingroom1 is adjacent to kitchen1, balcony1, closet1, washroom2"}, {"start": 1195, "end": 1264, "label": "CONNECTION", "text": "kitchen1 is next to bedroom1, closet1, washroom1, balcony2, washroom2"}, {"start": 1266, "end": 1300, "label": "CONNECTION", "text": "closet1 and bedroom1 are connected"}, {"start": 1302, "end": 1346, "label": "CONNECTION", "text": "washroom1 is adjacent to balcony2, washroom2"}]},
{"document": "The house plan has one washroom, two bedrooms, one livingroom, and one balcony. Specifically, washroom1 is in west with 4 square meters. wall of washroom1 is Wood_Grain and Blue as well as has Pink Wood_Grain floor. Moreover, bedroom1 has Yellow Rock_Plate floor while wall is Marble and Purple. bedroom1 covers 18 square meters located in east. bedroom2 has 8 squares in center. bedroom2 wall is Green Pure_Color_Wood, and floor is Earth_color Quartz. In addition, livingroom1 uses Earth_color Wall_Cloth for floor while has White Stone_Brick wall. livingroom1 covers 24 square meters located in west. Moreover, balcony1 has 4 squares in center. balcony1 uses Purple Wood_Grain for floor as well as wall is Ceramic_Tile and Green. livingroom1 is adjacent to bedroom1, bedroom2, washroom1, balcony1. bedroom1 is next to bedroom2. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 31, "label": "ROOM", "text": "washroom"}, {"start": 33, "end": 36, "label": "QUANT", "text": "two"}, {"start": 37, "end": 45, "label": "ROOM", "text": "bedrooms"}, {"start": 47, "end": 50, "label": "QUANT", "text": "one"}, {"start": 51, "end": 61, "label": "ROOM", "text": "livingroom"}, {"start": 67, "end": 70, "label": "QUANT", "text": "one"}, {"start": 71, "end": 78, "label": "ROOM", "text": "balcony"}, {"start": 94, "end": 103, "label": "ROOM", "text": "washroom1"}, {"start": 110, "end": 114, "label": "DIRECTION", "text": "west"}, {"start": 120, "end": 135, "label": "DIMENSION", "text": "4 square meters"}, {"start": 145, "end": 154, "label": "ROOM", "text": "washroom1"}, {"start": 226, "end": 234, "label": "ROOM", "text": "bedroom1"}, {"start": 312, "end": 328, "label": "DIMENSION", "text": "18 square meters"}, {"start": 340, "end": 344, "label": "DIRECTION", "text": "east"}, {"start": 346, "end": 354, "label": "ROOM", "text": "bedroom2"}, {"start": 359, "end": 368, "label": "DIMENSION", "text": "8 squares"}, {"start": 466, "end": 477, "label": "ROOM", "text": "livingroom1"}, {"start": 569, "end": 585, "label": "DIMENSION", "text": "24 square meters"}, {"start": 597, "end": 601, "label": "DIRECTION", "text": "west"}, {"start": 613, "end": 621, "label": "ROOM", "text": "balcony1"}, {"start": 626, "end": 635, "label": "DIMENSION", "text": "4 squares"}, {"start": 647, "end": 655, "label": "ROOM", "text": "balcony1"}, {"start": 732, "end": 798, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, washroom1, balcony1"}, {"start": 800, "end": 828, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2"}]},
{"document": "The house plan has one washroom, one livingroom, one closet, and three bedrooms. Specifically, washroom1 has 4 squares in south. washroom1 floor is Pink Wallpaper as well as wall is Blue Bamboo_Vine. livingroom1 covers 37 square meters located in center. wall of livingroom1 is Pure_Color_Wood and Yellow, and has Gray Cement_Board floor. Moreover, closet1 covers 3 square meters located in east. wall of closet1 is Ceramic_Tile and Earth_color while uses Purple Ceramics for floor. bedroom1 has Yellow Jade wall, and has Gray Wood_Grain floor. bedroom1 is in northwest with 13 square meters. Besides, bedroom2 has 12 squares in east. bedroom2 uses Green Painted_Wood for floor while has Purple Ceramic_Tile wall. Additionally, floor of bedroom3 is Marble and Pink as well as has Pink Marble wall. bedroom3 is in southeast with 10 square meters. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, washroom1. bedroom2 is next to bedroom3, closet1. bedroom3 is adjacent to washroom1, closet1. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 31, "label": "ROOM", "text": "washroom"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 47, "label": "ROOM", "text": "livingroom"}, {"start": 49, "end": 52, "label": "QUANT", "text": "one"}, {"start": 53, "end": 59, "label": "ROOM", "text": "closet"}, {"start": 65, "end": 70, "label": "QUANT", "text": "three"}, {"start": 71, "end": 79, "label": "ROOM", "text": "bedrooms"}, {"start": 95, "end": 104, "label": "ROOM", "text": "washroom1"}, {"start": 109, "end": 118, "label": "DIMENSION", "text": "4 squares"}, {"start": 122, "end": 127, "label": "DIRECTION", "text": "south"}, {"start": 200, "end": 211, "label": "ROOM", "text": "livingroom1"}, {"start": 219, "end": 235, "label": "DIMENSION", "text": "37 square meters"}, {"start": 349, "end": 356, "label": "ROOM", "text": "closet1"}, {"start": 364, "end": 379, "label": "DIMENSION", "text": "3 square meters"}, {"start": 391, "end": 395, "label": "DIRECTION", "text": "east"}, {"start": 483, "end": 491, "label": "ROOM", "text": "bedroom1"}, {"start": 560, "end": 569, "label": "DIRECTION", "text": "northwest"}, {"start": 575, "end": 591, "label": "DIMENSION", "text": "13 square meters"}, {"start": 602, "end": 610, "label": "ROOM", "text": "bedroom2"}, {"start": 615, "end": 625, "label": "DIMENSION", "text": "12 squares"}, {"start": 629, "end": 633, "label": "DIRECTION", "text": "east"}, {"start": 737, "end": 745, "label": "ROOM", "text": "bedroom3"}, {"start": 813, "end": 822, "label": "DIRECTION", "text": "southeast"}, {"start": 828, "end": 844, "label": "DIRECTION", "text": "10 square meters"}, {"start": 846, "end": 912, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, washroom1"}, {"start": 914, "end": 951, "label": "CONNECTION", "text": "bedroom2 is next to bedroom3, closet1"}, {"start": 953, "end": 995, "label": "CONNECTION", "text": "bedroom3 is adjacent to washroom1, closet1"}]},
{"document": "The building contains two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. Specifically, bedroom1 has 13 squares in west. wall of bedroom1 is Painted_Wood and Green as well as floor is Black Jade. floor of bedroom2 is Granite and Red while wall is Earth_color Ceramic_Tile. bedroom2 covers 8 square meters located in center. floor of washroom1 is Marble and Earth_color, and wall is Mosaic and Black. washroom1 is in west with 4 square meters. balcony1 uses Green Bamboo_Vine for floor as well as wall is Pure_Color_Wood and Orange. balcony1 is in north with 4 square meters. livingroom1 is in southeast with 21 square meters. livingroom1 has Black Wall_Cloth wall, and has Purple Painted_Wood floor. floor of kitchen1 is Painted_Wood and Gray while wall is Ceramic_Tile and Pink. kitchen1 has 6 squares in southwest. bedroom1, bedroom2, kitchen1, washroom1 and livingroom1 are connected. bedroom1 is next to bedroom2, washroom1, balcony1. balcony1 and bedroom2 are connected. kitchen1 is next to washroom1. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "two"}, {"start": 26, "end": 34, "label": "ROOM", "text": "bedrooms"}, {"start": 36, "end": 39, "label": "QUANT", "text": "one"}, {"start": 40, "end": 48, "label": "ROOM", "text": "washroom"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 61, "label": "ROOM", "text": "balcony"}, {"start": 63, "end": 66, "label": "QUANT", "text": "one"}, {"start": 67, "end": 77, "label": "ROOM", "text": "livingroom"}, {"start": 83, "end": 86, "label": "QUANT", "text": "one"}, {"start": 87, "end": 94, "label": "ROOM", "text": "kitchen"}, {"start": 123, "end": 133, "label": "DIMENSION", "text": "13 squares"}, {"start": 137, "end": 141, "label": "DIRECTION", "text": "west"}, {"start": 151, "end": 159, "label": "ROOM", "text": "bedroom1"}, {"start": 227, "end": 235, "label": "ROOM", "text": "bedroom2"}, {"start": 311, "end": 319, "label": "DIMENSION", "text": "8 square"}, {"start": 355, "end": 364, "label": "ROOM", "text": "washroom1"}, {"start": 438, "end": 442, "label": "DIRECTION", "text": "west"}, {"start": 448, "end": 463, "label": "DIMENSION", "text": "4 square meters"}, {"start": 465, "end": 473, "label": "ROOM", "text": "balcony1"}, {"start": 569, "end": 574, "label": "DIRECTION", "text": "north"}, {"start": 580, "end": 595, "label": "DIMENSION", "text": "4 square meters"}, {"start": 597, "end": 608, "label": "ROOM", "text": "livingroom1"}, {"start": 615, "end": 624, "label": "DIRECTION", "text": "southeast"}, {"start": 630, "end": 646, "label": "DIMENSION", "text": "21 square meters"}, {"start": 648, "end": 659, "label": "ROOM", "text": "livingroom1"}, {"start": 731, "end": 739, "label": "ROOM", "text": "kitchen1"}, {"start": 815, "end": 824, "label": "DIMENSION", "text": "6 squares"}, {"start": 828, "end": 837, "label": "DIRECTION", "text": "southwest"}, {"start": 839, "end": 908, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, washroom1 and livingroom1 are connected"}, {"start": 910, "end": 959, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2, washroom1, balcony1"}, {"start": 961, "end": 996, "label": "CONNECTION", "text": "balcony1 and bedroom2 are connected"}, {"start": 998, "end": 1027, "label": "CONNECTION", "text": "kitchen1 is next to washroom1"}]},
{"document": "Building layout contains two washrooms, one livingroom, one closet, three bedrooms, one kitchen, and two balconys. Specifically, washroom1 covers 4 square meters located in west. wall of washroom1 is Bamboo_Vine and Orange as well as floor is White Ceramics. washroom2 is in north with 3 square meters. washroom2 has Black Wallpaper wall while floor is Green Ceramic_Tile. Additionally, livingroom1 covers 32 square meters located in east. floor of livingroom1 is Stone_Brick and Red, and wall is Ceramic_Tile and Wood_color. closet1 floor is White Quartz while wall is Green Coating. closet1 has 8 squares in northeast. Moreover, bedroom1 is in southwest with 14 square meters. wall of bedroom1 is Mosaic and Pink, and has Earth_color Coating floor. Additionally, bedroom2 covers 8 square meters located in south. bedroom2 has Earth_color Coating floor as well as wall is Blue Pure_Color_Wood. bedroom3 uses Yellow Stone_Brick for floor, and wall is Blue Coating. bedroom3 has 7 squares in northwest. Besides, kitchen1 covers 6 square meters located in center. kitchen1 uses Gray Rock_Plate for floor as well as wall is White Marble. Additionally, balcony1 has Earth_color Bamboo_Vine floor while has Green Pure_Color_Wood wall. balcony1 covers 5 square meters located in southeast. balcony2 has Yellow Painted_Wood wall as well as uses Red Wall_Cloth for floor. balcony2 covers 4 square meters located in north. livingroom1 is adjacent to bedroom1, bedroom2, closet1, bedroom3, kitchen1, balcony1, washroom1, washroom2. bedroom1 is next to bedroom2, washroom1. closet1 is adjacent to kitchen1, balcony2. washroom2 and bedroom3 are connected. kitchen1 is next to balcony2, washroom2. washroom2 and balcony2 are connected. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "two"}, {"start": 29, "end": 38, "label": "ROOM", "text": "washrooms"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 54, "label": "ROOM", "text": "livingroom"}, {"start": 56, "end": 59, "label": "QUANT", "text": "one"}, {"start": 60, "end": 66, "label": "ROOM", "text": "closet"}, {"start": 68, "end": 73, "label": "QUANT", "text": "three"}, {"start": 74, "end": 82, "label": "ROOM", "text": "bedrooms"}, {"start": 84, "end": 87, "label": "QUANT", "text": "one"}, {"start": 88, "end": 95, "label": "ROOM", "text": "kitchen"}, {"start": 101, "end": 104, "label": "QUANT", "text": "two"}, {"start": 105, "end": 113, "label": "ROOM", "text": "balconys"}, {"start": 129, "end": 138, "label": "ROOM", "text": "washroom1"}, {"start": 146, "end": 161, "label": "DIMENSION", "text": "4 square meters"}, {"start": 173, "end": 177, "label": "DIRECTION", "text": "west"}, {"start": 259, "end": 268, "label": "ROOM", "text": "washroom2"}, {"start": 275, "end": 280, "label": "DIRECTION", "text": "north"}, {"start": 286, "end": 301, "label": "DIMENSION", "text": "3 square meters"}, {"start": 387, "end": 398, "label": "ROOM", "text": "livingroom1"}, {"start": 406, "end": 422, "label": "DIMENSION", "text": "32 square meters"}, {"start": 434, "end": 438, "label": "DIRECTION", "text": "east"}, {"start": 526, "end": 533, "label": "ROOM", "text": "closet1"}, {"start": 585, "end": 592, "label": "ROOM", "text": "closet1"}, {"start": 597, "end": 606, "label": "DIMENSION", "text": "8 squares"}, {"start": 610, "end": 619, "label": "DIRECTION", "text": "northeast"}, {"start": 631, "end": 639, "label": "ROOM", "text": "bedroom1"}, {"start": 646, "end": 655, "label": "DIRECTION", "text": "southwest"}, {"start": 661, "end": 677, "label": "DIMENSION", "text": "14 square meters"}, {"start": 687, "end": 695, "label": "ROOM", "text": "bedroom1"}, {"start": 765, "end": 773, "label": "ROOM", "text": "bedroom2"}, {"start": 781, "end": 796, "label": "DIMENSION", "text": "8 square meters"}, {"start": 808, "end": 813, "label": "DIRECTION", "text": "south"}, {"start": 895, "end": 903, "label": "ROOM", "text": "bedroom3"}, {"start": 965, "end": 973, "label": "ROOM", "text": "bedroom3"}, {"start": 978, "end": 987, "label": "DIMENSION", "text": "7 squares"}, {"start": 991, "end": 1000, "label": "DIRECTION", "text": "northwest"}, {"start": 1011, "end": 1019, "label": "ROOM", "text": "kitchen1"}, {"start": 1027, "end": 1042, "label": "DIMENSION", "text": "6 square meters"}, {"start": 1062, "end": 1070, "label": "ROOM", "text": "kitchen1"}, {"start": 1149, "end": 1157, "label": "ROOM", "text": "balcony1"}, {"start": 1246, "end": 1261, "label": "DIMENSION", "text": "5 square meters"}, {"start": 1273, "end": 1282, "label": "DIRECTION", "text": "southeast"}, {"start": 1284, "end": 1292, "label": "ROOM", "text": "balcony2"}, {"start": 1380, "end": 1395, "label": "DIMENSION", "text": "4 square meters"}, {"start": 1407, "end": 1412, "label": "DIRECTION", "text": "north"}, {"start": 1414, "end": 1520, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, closet1, bedroom3, kitchen1, balcony1, washroom1, washroom2"}, {"start": 1522, "end": 1561, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2, washroom1"}, {"start": 1563, "end": 1604, "label": "CONNECTION", "text": "closet1 is adjacent to kitchen1, balcony2"}, {"start": 1606, "end": 1642, "label": "CONNECTION", "text": "washroom2 and bedroom3 are connected"}, {"start": 1644, "end": 1683, "label": "CONNECTION", "text": "kitchen1 is next to balcony2, washroom2"}, {"start": 1685, "end": 1721, "label": "CONNECTION", "text": "washroom2 and balcony2 are connected"}]},
{"document": "House has two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. Specifically, floor of bedroom1 is Bamboo_Vine and Gray, and has Wood_color Wall_Cloth wall. bedroom1 is in center with 12 square meters. bedroom2 wall is Orange Jade as well as has Black Pure_Color_Wood floor. bedroom2 covers 10 square meters located in northwest. In addition, washroom1 wall is Wood_color Painted_Wood, and uses Pink Coating for floor. washroom1 is in north with 4 square meters. wall of balcony1 is Ceramics and Purple while has Wood_color Ceramic_Tile floor. balcony1 covers 6 square meters located in southeast. Moreover, livingroom1 wall is Purple Rock_Plate, and floor is Rock_Plate and Green. livingroom1 has 31 squares in east. Besides, kitchen1 wall is Purple Mosaic as well as floor is Wood_Veneer and Purple. kitchen1 has 6 squares in center. livingroom1 is adjacent to bedroom1, bedroom2, balcony1, kitchen1, washroom1. bedroom1 is next to kitchen1. bedroom2 is adjacent to kitchen1, washroom1. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "two"}, {"start": 24, "end": 27, "label": "QUANT", "text": "one"}, {"start": 38, "end": 41, "label": "QUANT", "text": "one"}, {"start": 51, "end": 54, "label": "QUANT", "text": "one"}, {"start": 71, "end": 74, "label": "QUANT", "text": "one"}, {"start": 107, "end": 115, "label": "ROOM", "text": "bedroom1"}, {"start": 116, "end": 118, "label": "ROOM", "text": "is"}, {"start": 186, "end": 188, "label": "ROOM", "text": "is"}, {"start": 204, "end": 220, "label": "DIMENSION", "text": "12 square meters"}, {"start": 222, "end": 230, "label": "ROOM", "text": "bedroom2"}, {"start": 236, "end": 238, "label": "ROOM", "text": "is"}, {"start": 311, "end": 327, "label": "DIMENSION", "text": "10 square meters"}, {"start": 339, "end": 348, "label": "DIRECTION", "text": "northwest"}, {"start": 363, "end": 372, "label": "ROOM", "text": "washroom1"}, {"start": 378, "end": 380, "label": "ROOM", "text": "is"}, {"start": 449, "end": 451, "label": "ROOM", "text": "is"}, {"start": 455, "end": 460, "label": "DIRECTION", "text": "north"}, {"start": 466, "end": 481, "label": "DIMENSION", "text": "4 square meters"}, {"start": 491, "end": 499, "label": "ROOM", "text": "balcony1"}, {"start": 500, "end": 502, "label": "ROOM", "text": "is"}, {"start": 580, "end": 595, "label": "DIMENSION", "text": "6 square meters"}, {"start": 607, "end": 616, "label": "DIRECTION", "text": "southeast"}, {"start": 628, "end": 639, "label": "ROOM", "text": "livingroom1"}, {"start": 718, "end": 728, "label": "DIMENSION", "text": "31 squares"}, {"start": 732, "end": 736, "label": "ROOM", "text": "east"}, {"start": 747, "end": 755, "label": "ROOM", "text": "kitchen1"}, {"start": 835, "end": 844, "label": "DIMENSION", "text": "6 squares"}, {"start": 856, "end": 932, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, balcony1, kitchen1, washroom1"}, {"start": 934, "end": 962, "label": "CONNECTION", "text": "bedroom1 is next to kitchen1"}, {"start": 964, "end": 1007, "label": "CONNECTION", "text": "bedroom2 is adjacent to kitchen1, washroom1"}]},
{"document": "The house plan has two washrooms, one livingroom, one study, two bedrooms, one kitchen, and one balcony. In practice, washroom1 wall is Purple Wall_Cloth as well as floor is Red Mosaic. washroom1 is in northeast with 5 square meters. washroom2 covers 3 square meters located in north. washroom2 has Yellow Granite wall, and floor is Marble and Orange. Moreover, livingroom1 has 51 squares in center. wall of livingroom1 is Mosaic and Pink while floor is Coating and Blue. Besides, study1 has White Cement_Board wall as well as uses Orange Coating for floor. study1 has 9 squares in east. In addition, floor of bedroom1 is Wood_Grain and Purple while has Red Bamboo_Vine wall. bedroom1 has 19 squares in east. Moreover, floor of bedroom2 is Coating and Earth_color as well as wall is Painted_Wood and Gray. bedroom2 has 16 squares in southeast. Additionally, kitchen1 uses Pink Wallpaper for floor, and wall is Gray Wood_Veneer. kitchen1 has 10 squares in southwest. wall of balcony1 is Jade and Blue while has Yellow Stone_Brick floor. balcony1 has 3 squares in west. bedroom1, bedroom2, kitchen1, study1, washroom1, washroom2 and livingroom1 are connected. bedroom1 is adjacent to study1, washroom1. bedroom2 is next to study1. kitchen1 is adjacent to balcony1. washroom1 is next to washroom2. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 32, "label": "ROOM", "text": "washrooms"}, {"start": 34, "end": 37, "label": "QUANT", "text": "one"}, {"start": 38, "end": 49, "label": "ROOM", "text": "livingroom,"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 59, "label": "ROOM", "text": "study"}, {"start": 61, "end": 64, "label": "QUANT", "text": "two"}, {"start": 65, "end": 73, "label": "ROOM", "text": "bedrooms"}, {"start": 75, "end": 78, "label": "QUANT", "text": "one"}, {"start": 79, "end": 86, "label": "ROOM", "text": "kitchen"}, {"start": 92, "end": 95, "label": "QUANT", "text": "one"}, {"start": 96, "end": 103, "label": "ROOM", "text": "balcony"}, {"start": 118, "end": 127, "label": "ROOM", "text": "washroom1"}, {"start": 202, "end": 211, "label": "DIRECTION", "text": "northeast"}, {"start": 217, "end": 232, "label": "DIMENSION", "text": "5 square meters"}, {"start": 234, "end": 243, "label": "ROOM", "text": "washroom2"}, {"start": 251, "end": 266, "label": "DIMENSION", "text": "3 square meters"}, {"start": 278, "end": 283, "label": "DIRECTION", "text": "north"}, {"start": 362, "end": 373, "label": "ROOM", "text": "livingroom1"}, {"start": 378, "end": 388, "label": "DIMENSION", "text": "51 squares"}, {"start": 481, "end": 487, "label": "ROOM", "text": "study1"}, {"start": 569, "end": 578, "label": "DIMENSION", "text": "9 squares"}, {"start": 582, "end": 586, "label": "DIRECTION", "text": "east"}, {"start": 610, "end": 618, "label": "ROOM", "text": "bedroom1"}, {"start": 689, "end": 699, "label": "DIMENSION", "text": "19 squares"}, {"start": 703, "end": 707, "label": "DIRECTION", "text": "east"}, {"start": 728, "end": 736, "label": "ROOM", "text": "bedroom2"}, {"start": 819, "end": 829, "label": "DIMENSION", "text": "16 squares"}, {"start": 833, "end": 842, "label": "DIRECTION", "text": "southeast"}, {"start": 858, "end": 866, "label": "ROOM", "text": "kitchen1"}, {"start": 941, "end": 951, "label": "DIMENSION", "text": "10 squares"}, {"start": 955, "end": 964, "label": "DIRECTION", "text": "southwest"}, {"start": 974, "end": 982, "label": "ROOM", "text": "balcony1"}, {"start": 1049, "end": 1058, "label": "DIMENSION", "text": "3 squares"}, {"start": 1062, "end": 1066, "label": "DIRECTION", "text": "west"}, {"start": 1068, "end": 1156, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, study1, washroom1, washroom2 and livingroom1 are connected"}, {"start": 1158, "end": 1199, "label": "CONNECTION", "text": "bedroom1 is adjacent to study1, washroom1"}, {"start": 1201, "end": 1227, "label": "CONNECTION", "text": "bedroom2 is next to study1"}, {"start": 1229, "end": 1261, "label": "CONNECTION", "text": "kitchen1 is adjacent to balcony1"}, {"start": 1263, "end": 1293, "label": "CONNECTION", "text": "washroom1 is next to washroom2"}]},
{"document": "The house plan has two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. In practice, bedroom1 is in north with 17 square meters. bedroom1 has Wood_color Wallpaper wall, and floor is Wood_Grain and Purple. bedroom2 uses Gray Stone_Brick for floor while wall is Ceramic_Tile and Orange. bedroom2 has 9 squares in west. washroom1 has Orange Rock_Plate wall, and floor is Ceramics and Wood_color. washroom1 covers 6 square meters located in south. Moreover, balcony1 is in north with 8 square meters. balcony1 uses Red Stone_Brick for floor as well as wall is Rock_Plate and Black. livingroom1 wall is Black Pure_Color_Wood, and floor is Quartz and Blue. livingroom1 covers 38 square meters located in center. Besides, kitchen1 has 8 squares in south. wall of kitchen1 is Mosaic and Red while uses Red Ceramics for floor. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, balcony1, washroom1. bedroom1 is next to bedroom2, balcony1. bedroom2 is adjacent to washroom1. kitchen1 is next to washroom1. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 31, "label": "ROOM", "text": "bedrooms"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 45, "label": "ROOM", "text": "washroom"}, {"start": 47, "end": 50, "label": "QUANT", "text": "one"}, {"start": 51, "end": 59, "label": "ROOM", "text": "balcony,"}, {"start": 60, "end": 63, "label": "QUANT", "text": "one"}, {"start": 64, "end": 74, "label": "ROOM", "text": "livingroom"}, {"start": 80, "end": 83, "label": "QUANT", "text": "one"}, {"start": 84, "end": 92, "label": "ROOM", "text": "kitchen."}, {"start": 106, "end": 114, "label": "ROOM", "text": "bedroom1"}, {"start": 121, "end": 126, "label": "DIRECTION", "text": "north"}, {"start": 132, "end": 148, "label": "DIMENSION", "text": "17 square meters"}, {"start": 150, "end": 158, "label": "ROOM", "text": "bedroom1"}, {"start": 226, "end": 234, "label": "ROOM", "text": "bedroom2"}, {"start": 319, "end": 328, "label": "DIMENSION", "text": "9 squares"}, {"start": 332, "end": 336, "label": "DIRECTION", "text": "west"}, {"start": 338, "end": 347, "label": "ROOM", "text": "washroom1"}, {"start": 414, "end": 423, "label": "ROOM", "text": "washroom1"}, {"start": 431, "end": 446, "label": "DIMENSION", "text": "6 square meters"}, {"start": 458, "end": 463, "label": "DIRECTION", "text": "south"}, {"start": 475, "end": 483, "label": "ROOM", "text": "balcony1"}, {"start": 490, "end": 495, "label": "DIRECTION", "text": "north"}, {"start": 501, "end": 516, "label": "DIMENSION", "text": "8 square meters"}, {"start": 518, "end": 526, "label": "ROOM", "text": "balcony1"}, {"start": 599, "end": 610, "label": "ROOM", "text": "livingroom1"}, {"start": 691, "end": 707, "label": "DIMENSION", "text": "38 square meters"}, {"start": 736, "end": 744, "label": "ROOM", "text": "kitchen1"}, {"start": 749, "end": 758, "label": "DIMENSION", "text": "8 squares"}, {"start": 762, "end": 767, "label": "DIRECTION", "text": "south"}, {"start": 839, "end": 955, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, balcony1, washroom1. bedroom1 is next to bedroom2, balcony1"}, {"start": 957, "end": 990, "label": "CONNECTION", "text": "bedroom2 is adjacent to washroom1"}, {"start": 992, "end": 1021, "label": "CONNECTION", "text": "kitchen1 is next to washroom1"}]},
{"document": "The building contains two washrooms, one livingroom, one study, three bedrooms, one kitchen, and two balconys. More specifically, washroom1 has 5 squares in west. floor of washroom1 is Mosaic and Red as well as has Earth_color Wallpaper wall. washroom2 wall is Gray Cement_Board while floor is Stone_Brick and Pink. washroom2 has 4 squares in north. livingroom1 uses Gray Bamboo_Vine for floor as well as wall is Ceramic_Tile and Gray. livingroom1 has 48 squares in east. Moreover, study1 has Earth_color Wallpaper floor while wall is Mosaic and Yellow. study1 has 9 squares in west. Besides, bedroom1 has Purple Quartz wall, and floor is Quartz and Green. bedroom1 is in southwest with 21 square meters. bedroom2 has 16 squares in south. bedroom2 floor is Purple Mosaic as well as wall is Purple Jade. Additionally, bedroom3 covers 11 square meters located in northwest. bedroom3 floor is Green Cement_Board while has Orange Wallpaper wall. kitchen1 has 7 squares in north. kitchen1 wall is Green Rock_Plate as well as has Yellow Ceramic_Tile floor. balcony1 is in southeast with 8 square meters. balcony1 floor is Purple Ceramics while has White Wallpaper wall. balcony2 uses Purple Granite for floor as well as has Green Bamboo_Vine wall. balcony2 has 6 squares in northeast. bedroom1, bedroom2, bedroom3, study1, balcony1, kitchen1, balcony2, washroom2 and livingroom1 are connected. bedroom1 is adjacent to bedroom2, washroom1. study1, washroom2 and bedroom3 are connected. study1 is adjacent to washroom1. washroom2 and kitchen1 are connected. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "two"}, {"start": 26, "end": 35, "label": "ROOM", "text": "washrooms"}, {"start": 37, "end": 40, "label": "QUANT", "text": "one"}, {"start": 41, "end": 51, "label": "ROOM", "text": "livingroom"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 62, "label": "ROOM", "text": "study"}, {"start": 64, "end": 69, "label": "QUANT", "text": "three"}, {"start": 70, "end": 78, "label": "ROOM", "text": "bedrooms"}, {"start": 80, "end": 83, "label": "QUANT", "text": "one"}, {"start": 84, "end": 96, "label": "ROOM", "text": "kitchen, and"}, {"start": 97, "end": 100, "label": "QUANT", "text": "two"}, {"start": 101, "end": 109, "label": "ROOM", "text": "balconys"}, {"start": 130, "end": 139, "label": "ROOM", "text": "washroom1"}, {"start": 144, "end": 153, "label": "DIMENSION", "text": "5 squares"}, {"start": 157, "end": 161, "label": "DIRECTION", "text": "west"}, {"start": 172, "end": 181, "label": "ROOM", "text": "washroom1"}, {"start": 243, "end": 252, "label": "ROOM", "text": "washroom2"}, {"start": 330, "end": 339, "label": "DIMENSION", "text": "4 squares"}, {"start": 343, "end": 348, "label": "DIRECTION", "text": "north"}, {"start": 350, "end": 361, "label": "ROOM", "text": "livingroom1"}, {"start": 452, "end": 462, "label": "DIMENSION", "text": "48 squares"}, {"start": 466, "end": 470, "label": "DIRECTION", "text": "east"}, {"start": 482, "end": 488, "label": "ROOM", "text": "study1"}, {"start": 554, "end": 560, "label": "ROOM", "text": "study1"}, {"start": 565, "end": 574, "label": "DIMENSION", "text": "9 squares"}, {"start": 578, "end": 582, "label": "DIRECTION", "text": "west"}, {"start": 593, "end": 601, "label": "ROOM", "text": "bedroom1"}, {"start": 672, "end": 681, "label": "DIRECTION", "text": "southwest"}, {"start": 687, "end": 703, "label": "DIMENSION", "text": "21 square meters"}, {"start": 705, "end": 713, "label": "ROOM", "text": "bedroom2"}, {"start": 718, "end": 728, "label": "DIMENSION", "text": "16 squares"}, {"start": 732, "end": 737, "label": "DIRECTION", "text": "south"}, {"start": 817, "end": 825, "label": "ROOM", "text": "bedroom3"}, {"start": 833, "end": 849, "label": "DIMENSION", "text": "11 square meters"}, {"start": 861, "end": 870, "label": "DIRECTION", "text": "northwest"}, {"start": 872, "end": 880, "label": "ROOM", "text": "bedroom3"}, {"start": 942, "end": 950, "label": "ROOM", "text": "kitchen1"}, {"start": 955, "end": 964, "label": "DIMENSION", "text": "7 squares"}, {"start": 968, "end": 973, "label": "DIRECTION", "text": "north"}, {"start": 975, "end": 983, "label": "ROOM", "text": "kitchen1"}, {"start": 1051, "end": 1059, "label": "ROOM", "text": "balcony1"}, {"start": 1066, "end": 1075, "label": "DIRECTION", "text": "southeast"}, {"start": 1081, "end": 1096, "label": "DIMENSION", "text": "8 square meters"}, {"start": 1098, "end": 1106, "label": "ROOM", "text": "balcony1"}, {"start": 1164, "end": 1172, "label": "ROOM", "text": "balcony2"}, {"start": 1255, "end": 1264, "label": "DIMENSION", "text": "6 squares"}, {"start": 1268, "end": 1277, "label": "DIRECTION", "text": "northeast"}, {"start": 1279, "end": 1386, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, study1, balcony1, kitchen1, balcony2, washroom2 and livingroom1 are connected"}, {"start": 1388, "end": 1431, "label": "CONNECTION", "text": "bedroom1 is adjacent to bedroom2, washroom1"}, {"start": 1433, "end": 1477, "label": "CONNECTION", "text": "study1, washroom2 and bedroom3 are connected"}, {"start": 1479, "end": 1510, "label": "CONNECTION", "text": "study1 is adjacent to washroom1"}, {"start": 1512, "end": 1548, "label": "CONNECTION", "text": "washroom2 and kitchen1 are connected"}]},
{"document": "Building layout contains one washroom, two bedrooms, one livingroom, and one kitchen. More specifically, washroom1 has 3 squares in northeast. washroom1 floor is Earth_color Cement_Board, and wall is Gray Pure_Color_Wood. bedroom1 is in southwest with 6 square meters. wall of bedroom1 is Jade and Orange while floor is Quartz and Yellow. bedroom2 covers 5 square meters located in west. bedroom2 wall is Black Wood_Grain, and uses Blue Painted_Wood for floor. livingroom1 covers 19 square meters located in center. livingroom1 wall is Orange Cement_Board while floor is Wallpaper and Wood_color. Moreover, floor of kitchen1 is Jade and Yellow, and wall is Wallpaper and Purple. kitchen1 has 3 squares in northeast. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1. bedroom2 and bedroom1 are connected. kitchen1 is adjacent to washroom1. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "one"}, {"start": 29, "end": 37, "label": "ROOM", "text": "washroom"}, {"start": 39, "end": 42, "label": "QUANT", "text": "two"}, {"start": 43, "end": 51, "label": "ROOM", "text": "bedrooms"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 67, "label": "ROOM", "text": "livingroom"}, {"start": 73, "end": 76, "label": "QUANT", "text": "one"}, {"start": 77, "end": 84, "label": "ROOM", "text": "kitchen"}, {"start": 105, "end": 114, "label": "ROOM", "text": "washroom1"}, {"start": 119, "end": 128, "label": "DIMENSION", "text": "3 squares"}, {"start": 132, "end": 141, "label": "DIRECTION", "text": "northeast"}, {"start": 222, "end": 230, "label": "ROOM", "text": "bedroom1"}, {"start": 237, "end": 246, "label": "DIRECTION", "text": "southwest"}, {"start": 252, "end": 267, "label": "DIMENSION", "text": "6 square meters"}, {"start": 339, "end": 347, "label": "ROOM", "text": "bedroom2"}, {"start": 355, "end": 370, "label": "DIMENSION", "text": "5 square meters"}, {"start": 382, "end": 386, "label": "DIRECTION", "text": "west"}, {"start": 461, "end": 472, "label": "ROOM", "text": "livingroom1"}, {"start": 480, "end": 496, "label": "DIMENSION", "text": "19 square meters"}, {"start": 516, "end": 527, "label": "ROOM", "text": "livingroom1"}, {"start": 616, "end": 624, "label": "ROOM", "text": "kitchen1"}, {"start": 692, "end": 701, "label": "DIMENSION", "text": "3 squares"}, {"start": 705, "end": 714, "label": "DIRECTION", "text": "northeast"}, {"start": 716, "end": 782, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1"}, {"start": 784, "end": 819, "label": "CONNECTION", "text": "bedroom2 and bedroom1 are connected"}, {"start": 821, "end": 854, "label": "CONNECTION", "text": "kitchen1 is adjacent to washroom1"}]},
{"document": "House has three bedrooms, one washroom, one balcony, one livingroom, and one kitchen. Specifically, floor of bedroom1 is Rock_Plate and Green, and has Wood_color Painted_Wood wall. bedroom1 has 12 squares in north. bedroom2 has 10 squares in southwest. bedroom2 has Earth_color Wall_Cloth floor while wall is White Wall_Cloth. bedroom3 covers 8 square meters located in west. bedroom3 has Purple Ceramics wall as well as floor is Marble and White. washroom1 wall is White Granite while floor is Granite and Green. washroom1 is in south with 3 square meters. In addition, balcony1 has 6 squares in northeast. balcony1 wall is Red Wall_Cloth as well as has White Coating floor. Besides, livingroom1 has 32 squares in east. livingroom1 uses Gray Cement_Board for floor while has Orange Pure_Color_Wood wall. floor of kitchen1 is Granite and Earth_color, and wall is Earth_color Mosaic. kitchen1 has 7 squares in south. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1. bedroom3, balcony1 and bedroom1 are connected. bedroom2 is adjacent to bedroom3, washroom1. washroom1 and kitchen1 are connected. ", "annotation": [{"start": 10, "end": 15, "label": "QUANT", "text": "three"}, {"start": 16, "end": 24, "label": "ROOM", "text": "bedrooms"}, {"start": 26, "end": 29, "label": "QUANT", "text": "one"}, {"start": 30, "end": 38, "label": "ROOM", "text": "washroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 51, "label": "ROOM", "text": "balcony"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 67, "label": "ROOM", "text": "livingroom"}, {"start": 73, "end": 76, "label": "QUANT", "text": "one"}, {"start": 77, "end": 84, "label": "ROOM", "text": "kitchen"}, {"start": 109, "end": 117, "label": "ROOM", "text": "bedroom1"}, {"start": 194, "end": 204, "label": "DIMENSION", "text": "12 squares"}, {"start": 208, "end": 213, "label": "DIRECTION", "text": "north"}, {"start": 215, "end": 223, "label": "ROOM", "text": "bedroom2"}, {"start": 228, "end": 238, "label": "DIMENSION", "text": "10 squares"}, {"start": 242, "end": 251, "label": "DIRECTION", "text": "southwest"}, {"start": 327, "end": 335, "label": "ROOM", "text": "bedroom3"}, {"start": 343, "end": 358, "label": "DIMENSION", "text": "8 square meters"}, {"start": 370, "end": 374, "label": "DIRECTION", "text": "west"}, {"start": 448, "end": 457, "label": "ROOM", "text": "washroom1"}, {"start": 514, "end": 523, "label": "ROOM", "text": "washroom1"}, {"start": 530, "end": 535, "label": "DIRECTION", "text": "south"}, {"start": 541, "end": 556, "label": "DIMENSION", "text": "3 square meters"}, {"start": 571, "end": 579, "label": "ROOM", "text": "balcony1"}, {"start": 584, "end": 593, "label": "DIMENSION", "text": "6 squares"}, {"start": 597, "end": 606, "label": "DIRECTION", "text": "northeast"}, {"start": 608, "end": 616, "label": "ROOM", "text": "balcony1"}, {"start": 685, "end": 696, "label": "ROOM", "text": "livingroom1"}, {"start": 701, "end": 711, "label": "DIMENSION", "text": "32 squares"}, {"start": 715, "end": 719, "label": "DIRECTION", "text": "east"}, {"start": 814, "end": 822, "label": "ROOM", "text": "kitchen1"}, {"start": 883, "end": 891, "label": "ROOM", "text": "kitchen1"}, {"start": 896, "end": 905, "label": "DIMENSION", "text": "7 squares"}, {"start": 909, "end": 914, "label": "DIRECTION", "text": "south"}, {"start": 916, "end": 1002, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1"}, {"start": 1004, "end": 1049, "label": "CONNECTION", "text": "bedroom3, balcony1 and bedroom1 are connected"}, {"start": 1051, "end": 1094, "label": "CONNECTION", "text": "bedroom2 is adjacent to bedroom3, washroom1"}, {"start": 1096, "end": 1132, "label": "CONNECTION", "text": "washroom1 and kitchen1 are connected"}]},
{"document": "The building contains two washrooms, one livingroom, one study, two bedrooms, two kitchens, and one balcony. In practice, washroom1 has Purple Wood_Grain floor as well as wall is Green Wood_Grain. washroom1 has 4 squares in center. Additionally, wall of washroom2 is Marble and Wood_color while floor is Log and Red. washroom2 has 3 squares in east. In addition, livingroom1 uses Red Ceramic_Tile for floor, and wall is Marble and Blue. livingroom1 covers 42 square meters located in center. Additionally, study1 has 9 squares in east. study1 floor is Earth_color Coating as well as wall is Orange Marble. Besides, bedroom1 has 15 squares in west. bedroom1 wall is Red Stone_Brick, and uses Black Wall_Cloth for floor. Additionally, bedroom2 wall is Gray Granite while floor is Ceramic_Tile and White. bedroom2 covers 13 square meters located in center. In addition, kitchen1 is in west with 12 square meters. kitchen1 wall is Orange Wall_Cloth as well as has Wood_color Bamboo_Vine floor. Moreover, kitchen2 covers 10 square meters located in southeast. kitchen2 has Yellow Pure_Color_Wood floor while wall is Ceramic_Tile and Yellow. balcony1 has 7 squares in east. floor of balcony1 is Cement_Board and Red, and wall is Red Cement_Board. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, kitchen2, study1, washroom1, washroom2. kitchen1, washroom1 and bedroom1 are connected. bedroom2 is adjacent to study1, washroom1. kitchen2 is next to balcony1, washroom2. study1 is adjacent to balcony1, washroom2. balcony1 is next to washroom2. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "two"}, {"start": 26, "end": 35, "label": "ROOM", "text": "washrooms"}, {"start": 37, "end": 40, "label": "QUANT", "text": "one"}, {"start": 41, "end": 51, "label": "ROOM", "text": "livingroom"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 62, "label": "ROOM", "text": "study"}, {"start": 64, "end": 67, "label": "QUANT", "text": "two"}, {"start": 68, "end": 76, "label": "ROOM", "text": "bedrooms"}, {"start": 78, "end": 81, "label": "QUANT", "text": "two"}, {"start": 82, "end": 90, "label": "ROOM", "text": "kitchens"}, {"start": 96, "end": 99, "label": "QUANT", "text": "one"}, {"start": 100, "end": 107, "label": "ROOM", "text": "balcony"}, {"start": 122, "end": 131, "label": "ROOM", "text": "washroom1"}, {"start": 211, "end": 220, "label": "DIMENSION", "text": "4 squares"}, {"start": 254, "end": 266, "label": "ROOM", "text": "washroom2 is"}, {"start": 331, "end": 340, "label": "DIMENSION", "text": "3 squares"}, {"start": 344, "end": 348, "label": "DIRECTION", "text": "east"}, {"start": 363, "end": 374, "label": "ROOM", "text": "livingroom1"}, {"start": 456, "end": 472, "label": "DIMENSION", "text": "42 square meters"}, {"start": 506, "end": 512, "label": "ROOM", "text": "study1"}, {"start": 517, "end": 526, "label": "DIMENSION", "text": "9 squares"}, {"start": 530, "end": 534, "label": "DIRECTION", "text": "east"}, {"start": 536, "end": 542, "label": "ROOM", "text": "study1"}, {"start": 615, "end": 623, "label": "ROOM", "text": "bedroom1"}, {"start": 628, "end": 638, "label": "DIMENSION", "text": "15 squares"}, {"start": 642, "end": 646, "label": "DIRECTION", "text": "west"}, {"start": 802, "end": 810, "label": "ROOM", "text": "bedroom2"}, {"start": 818, "end": 834, "label": "DIMENSION", "text": "13 square meters"}, {"start": 867, "end": 875, "label": "ROOM", "text": "kitchen1"}, {"start": 882, "end": 886, "label": "DIRECTION", "text": "west"}, {"start": 892, "end": 908, "label": "DIMENSION", "text": "12 square meters"}, {"start": 910, "end": 918, "label": "ROOM", "text": "kitchen1"}, {"start": 1000, "end": 1008, "label": "ROOM", "text": "kitchen2"}, {"start": 1016, "end": 1032, "label": "DIMENSION", "text": "10 square meters"}, {"start": 1044, "end": 1053, "label": "DIRECTION", "text": "southeast"}, {"start": 1055, "end": 1063, "label": "ROOM", "text": "kitchen2"}, {"start": 1136, "end": 1144, "label": "ROOM", "text": "balcony1"}, {"start": 1149, "end": 1158, "label": "DIMENSION", "text": "7 squares"}, {"start": 1162, "end": 1166, "label": "DIRECTION", "text": "east"}, {"start": 1241, "end": 1336, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, kitchen2, study1, washroom1, washroom2"}, {"start": 1338, "end": 1384, "label": "CONNECTION", "text": "kitchen1, washroom1 and bedroom1 are connected"}, {"start": 1386, "end": 1427, "label": "CONNECTION", "text": "bedroom2 is adjacent to study1, washroom1"}, {"start": 1429, "end": 1468, "label": "CONNECTION", "text": "kitchen2 is next to balcony1, washroom2"}, {"start": 1470, "end": 1511, "label": "CONNECTION", "text": "study1 is adjacent to balcony1, washroom2"}, {"start": 1513, "end": 1542, "label": "CONNECTION", "text": "balcony1 is next to washroom2"}]},
{"document": "The house plan has three bedrooms, two washrooms, one balcony, one livingroom, and one kitchen. In practice, floor of bedroom1 is Jade and White as well as wall is Green Cement_Board. bedroom1 has 15 squares in northwest. bedroom2 covers 10 square meters located in north. bedroom2 has Purple Log wall, and floor is Green Ceramic_Tile. Additionally, bedroom3 is in south with 8 square meters. wall of bedroom3 is Painted_Wood and Black as well as floor is Rock_Plate and Green. washroom1 covers 5 square meters located in south. floor of washroom1 is Log and Gray while wall is Log and Gray. washroom2 uses Black Pure_Color_Wood for floor, and wall is Painted_Wood and Blue. washroom2 covers 4 square meters located in west. wall of balcony1 is Quartz and Orange while has Green Quartz floor. balcony1 covers 4 square meters located in northeast. livingroom1 covers 30 square meters located in east. livingroom1 wall is Gray Stone_Brick as well as has Wood_color Cement_Board floor. Besides, floor of kitchen1 is Bamboo_Vine and Black, and wall is Purple Painted_Wood. kitchen1 covers 7 square meters located in south. bedroom1, bedroom2, bedroom3, kitchen1, washroom1, balcony1 and livingroom1 are connected. bedroom1 is adjacent to bedroom2, bedroom3, washroom2. washroom1, washroom2 and bedroom3 are connected. kitchen1 is next to washroom1. ", "annotation": [{"start": 19, "end": 24, "label": "QUANT", "text": "three"}, {"start": 25, "end": 33, "label": "ROOM", "text": "bedrooms"}, {"start": 35, "end": 38, "label": "QUANT", "text": "two"}, {"start": 39, "end": 48, "label": "ROOM", "text": "washrooms"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 61, "label": "ROOM", "text": "balcony"}, {"start": 63, "end": 66, "label": "QUANT", "text": "one"}, {"start": 67, "end": 77, "label": "ROOM", "text": "livingroom"}, {"start": 83, "end": 86, "label": "QUANT", "text": "one"}, {"start": 87, "end": 94, "label": "ROOM", "text": "kitchen"}, {"start": 118, "end": 126, "label": "ROOM", "text": "bedroom1"}, {"start": 197, "end": 207, "label": "DIMENSION", "text": "15 squares"}, {"start": 211, "end": 220, "label": "DIRECTION", "text": "northwest"}, {"start": 222, "end": 230, "label": "ROOM", "text": "bedroom2"}, {"start": 238, "end": 254, "label": "DIMENSION", "text": "10 square meters"}, {"start": 266, "end": 271, "label": "DIRECTION", "text": "north"}, {"start": 350, "end": 358, "label": "ROOM", "text": "bedroom3"}, {"start": 365, "end": 370, "label": "DIRECTION", "text": "south"}, {"start": 376, "end": 391, "label": "DIMENSION", "text": "8 square meters"}, {"start": 401, "end": 409, "label": "ROOM", "text": "bedroom3"}, {"start": 478, "end": 487, "label": "ROOM", "text": "washroom1"}, {"start": 495, "end": 510, "label": "DIMENSION", "text": "5 square meters"}, {"start": 522, "end": 527, "label": "DIRECTION", "text": "south"}, {"start": 592, "end": 601, "label": "ROOM", "text": "washroom2"}, {"start": 692, "end": 707, "label": "DIMENSION", "text": "4 square meters"}, {"start": 719, "end": 723, "label": "DIRECTION", "text": "west"}, {"start": 733, "end": 741, "label": "ROOM", "text": "balcony1"}, {"start": 809, "end": 824, "label": "DIMENSION", "text": "4 square meters"}, {"start": 836, "end": 845, "label": "DIRECTION", "text": "northeast"}, {"start": 847, "end": 858, "label": "ROOM", "text": "livingroom1"}, {"start": 866, "end": 882, "label": "DIMENSION", "text": "30 square meters"}, {"start": 894, "end": 898, "label": "DIRECTION", "text": "east"}, {"start": 900, "end": 911, "label": "ROOM", "text": "livingroom1"}, {"start": 1001, "end": 1009, "label": "ROOM", "text": "kitchen1"}, {"start": 1069, "end": 1077, "label": "ROOM", "text": "kitchen1"}, {"start": 1085, "end": 1100, "label": "DIMENSION", "text": "7 square meters"}, {"start": 1112, "end": 1117, "label": "DIRECTION", "text": "south"}, {"start": 1119, "end": 1208, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, kitchen1, washroom1, balcony1 and livingroom1 are connected"}, {"start": 1210, "end": 1263, "label": "CONNECTION", "text": "bedroom1 is adjacent to bedroom2, bedroom3, washroom2"}, {"start": 1265, "end": 1312, "label": "CONNECTION", "text": "washroom1, washroom2 and bedroom3 are connected"}, {"start": 1314, "end": 1343, "label": "CONNECTION", "text": "kitchen1 is next to washroom1"}]},
{"document": "The house plan has three bedrooms, two washrooms, two balconys, one livingroom, and one kitchen. More specifically, bedroom1 uses Earth_color Cement_Board for floor as well as wall is Wood_Veneer and Red. bedroom1 is in northeast with 12 square meters. bedroom2 has 9 squares in east. bedroom2 wall is Pink Ceramics while floor is Purple Quartz. bedroom3 is in south with 6 square meters. bedroom3 has Wood_color Painted_Wood wall as well as floor is Cement_Board and Earth_color. wall of washroom1 is Cement_Board and Pink, and uses Red Wall_Cloth for floor. washroom1 has 3 squares in east. washroom2 has Yellow Rock_Plate wall while uses Gray Cement_Board for floor. washroom2 covers 3 square meters located in center. balcony1 is in southwest with 6 square meters. floor of balcony1 is Pure_Color_Wood and Wood_color as well as wall is Ceramics and Wood_color. balcony2 has Pink Coating floor, and has Red Ceramic_Tile wall. balcony2 covers 3 square meters located in northwest. In addition, livingroom1 covers 27 square meters located in west. wall of livingroom1 is Quartz and Orange as well as uses Gray Wall_Cloth for floor. kitchen1 wall is Green Bamboo_Vine, and floor is Ceramic_Tile and Blue. kitchen1 has 5 squares in north. bedroom1, bedroom2, bedroom3, balcony1, kitchen1, washroom1, balcony2, washroom2 and livingroom1 are connected. bedroom1 is next to washroom1, washroom2. bedroom2 is adjacent to bedroom3, washroom1. washroom2 and kitchen1 are connected. ", "annotation": [{"start": 19, "end": 24, "label": "QUANT", "text": "three"}, {"start": 25, "end": 33, "label": "ROOM", "text": "bedrooms"}, {"start": 35, "end": 38, "label": "QUANT", "text": "two"}, {"start": 39, "end": 49, "label": "ROOM", "text": "washrooms,"}, {"start": 50, "end": 53, "label": "QUANT", "text": "two"}, {"start": 54, "end": 62, "label": "ROOM", "text": "balconys"}, {"start": 64, "end": 67, "label": "QUANT", "text": "one"}, {"start": 68, "end": 78, "label": "ROOM", "text": "livingroom"}, {"start": 84, "end": 87, "label": "QUANT", "text": "one"}, {"start": 88, "end": 95, "label": "ROOM", "text": "kitchen"}, {"start": 116, "end": 124, "label": "ROOM", "text": "bedroom1"}, {"start": 220, "end": 229, "label": "DIRECTION", "text": "northeast"}, {"start": 235, "end": 251, "label": "DIMENSION", "text": "12 square meters"}, {"start": 253, "end": 261, "label": "ROOM", "text": "bedroom2"}, {"start": 266, "end": 275, "label": "DIMENSION", "text": "9 squares"}, {"start": 279, "end": 283, "label": "ROOM", "text": "east"}, {"start": 346, "end": 354, "label": "ROOM", "text": "bedroom3"}, {"start": 361, "end": 366, "label": "DIRECTION", "text": "south"}, {"start": 372, "end": 387, "label": "DIMENSION", "text": "6 square meters"}, {"start": 489, "end": 498, "label": "ROOM", "text": "washroom1"}, {"start": 560, "end": 569, "label": "ROOM", "text": "washroom1"}, {"start": 574, "end": 583, "label": "DIMENSION", "text": "3 squares"}, {"start": 587, "end": 591, "label": "ROOM", "text": "east"}, {"start": 687, "end": 702, "label": "DIMENSION", "text": "3 square meters"}, {"start": 722, "end": 730, "label": "ROOM", "text": "balcony1"}, {"start": 737, "end": 746, "label": "DIRECTION", "text": "southwest"}, {"start": 752, "end": 767, "label": "DIMENSION", "text": "6 square meters"}, {"start": 865, "end": 873, "label": "ROOM", "text": "balcony2"}, {"start": 938, "end": 960, "label": "DIMENSION", "text": "covers 3 square meters"}, {"start": 972, "end": 981, "label": "DIRECTION", "text": "northwest"}, {"start": 996, "end": 1007, "label": "ROOM", "text": "livingroom1"}, {"start": 1015, "end": 1031, "label": "DIMENSION", "text": "27 square meters"}, {"start": 1043, "end": 1047, "label": "DIRECTION", "text": "west"}, {"start": 1133, "end": 1141, "label": "ROOM", "text": "kitchen1"}, {"start": 1205, "end": 1213, "label": "ROOM", "text": "kitchen1"}, {"start": 1218, "end": 1227, "label": "DIMENSION", "text": "5 squares"}, {"start": 1231, "end": 1236, "label": "DIRECTION", "text": "north"}, {"start": 1238, "end": 1348, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, balcony1, kitchen1, washroom1, balcony2, washroom2 and livingroom1 are connected"}, {"start": 1350, "end": 1390, "label": "CONNECTION", "text": "bedroom1 is next to washroom1, washroom2"}, {"start": 1392, "end": 1435, "label": "CONNECTION", "text": "bedroom2 is adjacent to bedroom3, washroom1"}, {"start": 1437, "end": 1473, "label": "CONNECTION", "text": "washroom2 and kitchen1 are connected"}]},
{"document": "Building layout contains three bedrooms, one washroom, one balcony, one livingroom, and one kitchen. In practice, bedroom1 has Blue Mosaic wall, and has Red Log floor. bedroom1 covers 17 square meters located in southwest. bedroom2 wall is Wood_color Stone_Brick as well as floor is Red Stone_Brick. bedroom2 covers 17 square meters located in northwest. bedroom3 covers 15 square meters located in west. wall of bedroom3 is Log and Red while has Red Marble floor. washroom1 has Yellow Bamboo_Vine wall as well as uses Yellow Pure_Color_Wood for floor. washroom1 is in southeast with 4 square meters. balcony1 floor is Earth_color Granite, and wall is Granite and Blue. balcony1 covers 12 square meters located in west. livingroom1 is in east with 44 square meters. floor of livingroom1 is Bamboo_Vine and Red as well as has Wood_color Wood_Grain wall. Additionally, kitchen1 wall is Pink Coating, and uses Pink Wall_Cloth for floor. kitchen1 covers 8 square meters located in northeast. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, washroom1. bedroom3, balcony1 and bedroom1 are connected. bedroom2 is next to bedroom3. bedroom3 is adjacent to balcony1. ", "annotation": [{"start": 25, "end": 30, "label": "QUANT", "text": "three"}, {"start": 31, "end": 39, "label": "ROOM", "text": "bedrooms"}, {"start": 41, "end": 44, "label": "QUANT", "text": "one"}, {"start": 45, "end": 53, "label": "ROOM", "text": "washroom"}, {"start": 55, "end": 58, "label": "QUANT", "text": "one"}, {"start": 59, "end": 66, "label": "ROOM", "text": "balcony"}, {"start": 68, "end": 71, "label": "QUANT", "text": "one"}, {"start": 72, "end": 82, "label": "ROOM", "text": "livingroom"}, {"start": 88, "end": 91, "label": "QUANT", "text": "one"}, {"start": 92, "end": 99, "label": "ROOM", "text": "kitchen"}, {"start": 114, "end": 122, "label": "ROOM", "text": "bedroom1"}, {"start": 184, "end": 200, "label": "DIMENSION", "text": "17 square meters"}, {"start": 316, "end": 332, "label": "DIMENSION", "text": "17 square meters"}, {"start": 344, "end": 353, "label": "DIRECTION", "text": "northwest"}, {"start": 355, "end": 363, "label": "ROOM", "text": "bedroom3"}, {"start": 371, "end": 387, "label": "DIMENSION", "text": "15 square meters"}, {"start": 399, "end": 403, "label": "DIRECTION", "text": "west"}, {"start": 465, "end": 474, "label": "ROOM", "text": "washroom1"}, {"start": 569, "end": 578, "label": "DIRECTION", "text": "southeast"}, {"start": 584, "end": 599, "label": "DIMENSION", "text": "4 square meters"}, {"start": 601, "end": 609, "label": "ROOM", "text": "balcony1"}, {"start": 686, "end": 702, "label": "DIMENSION", "text": "12 square meters"}, {"start": 714, "end": 718, "label": "DIRECTION", "text": "west"}, {"start": 748, "end": 764, "label": "DIMENSION", "text": "44 square meters"}, {"start": 867, "end": 875, "label": "ROOM", "text": "kitchen1"}, {"start": 934, "end": 942, "label": "ROOM", "text": "kitchen1"}, {"start": 950, "end": 965, "label": "DIMENSION", "text": "8 square meters"}, {"start": 977, "end": 986, "label": "DIRECTION", "text": "northeast"}, {"start": 988, "end": 1064, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, washroom1"}, {"start": 1066, "end": 1111, "label": "CONNECTION", "text": "bedroom3, balcony1 and bedroom1 are connected"}, {"start": 1113, "end": 1141, "label": "CONNECTION", "text": "bedroom2 is next to bedroom3"}, {"start": 1143, "end": 1175, "label": "CONNECTION", "text": "bedroom3 is adjacent to balcony1"}]},
{"document": "Building layout contains one washroom, two bedrooms, one livingroom, and one balcony. More specifically, washroom1 has 3 squares in north. washroom1 uses Black Wood_Veneer for floor as well as wall is Red Painted_Wood. Moreover, bedroom1 floor is Red Ceramics, and wall is Wood_color Jade. bedroom1 covers 12 square meters located in northeast. bedroom2 wall is Black Jade while floor is Bamboo_Vine and Pink. bedroom2 covers 7 square meters located in northwest. livingroom1 is in center with 23 square meters. livingroom1 has Earth_color Quartz floor, and wall is Earth_color Ceramic_Tile. balcony1 floor is Blue Cement_Board while wall is Pure_Color_Wood and Green. balcony1 covers 3 square meters located in southeast. livingroom1 is adjacent to bedroom1, bedroom2, washroom1, balcony1. washroom1, balcony1 and bedroom1 are connected. bedroom2 is adjacent to washroom1. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "one"}, {"start": 29, "end": 37, "label": "ROOM", "text": "washroom"}, {"start": 39, "end": 42, "label": "QUANT", "text": "two"}, {"start": 43, "end": 52, "label": "ROOM", "text": "bedrooms,"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 67, "label": "ROOM", "text": "livingroom"}, {"start": 73, "end": 76, "label": "QUANT", "text": "one"}, {"start": 77, "end": 84, "label": "ROOM", "text": "balcony"}, {"start": 105, "end": 114, "label": "ROOM", "text": "washroom1"}, {"start": 119, "end": 128, "label": "DIMENSION", "text": "3 squares"}, {"start": 132, "end": 137, "label": "DIRECTION", "text": "north"}, {"start": 139, "end": 148, "label": "ROOM", "text": "washroom1"}, {"start": 229, "end": 237, "label": "ROOM", "text": "bedroom1"}, {"start": 290, "end": 298, "label": "ROOM", "text": "bedroom1"}, {"start": 306, "end": 322, "label": "DIMENSION", "text": "12 square meters"}, {"start": 334, "end": 343, "label": "DIRECTION", "text": "northeast"}, {"start": 345, "end": 353, "label": "ROOM", "text": "bedroom2"}, {"start": 426, "end": 441, "label": "DIMENSION", "text": "7 square meters"}, {"start": 453, "end": 462, "label": "DIRECTION", "text": "northwest"}, {"start": 464, "end": 475, "label": "ROOM", "text": "livingroom1"}, {"start": 494, "end": 510, "label": "DIMENSION", "text": "23 square meters"}, {"start": 512, "end": 523, "label": "ROOM", "text": "livingroom1"}, {"start": 592, "end": 600, "label": "ROOM", "text": "balcony1"}, {"start": 669, "end": 721, "label": "CONNECTION", "text": "balcony1 covers 3 square meters located in southeast"}, {"start": 723, "end": 789, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, washroom1, balcony1"}, {"start": 791, "end": 837, "label": "CONNECTION", "text": "washroom1, balcony1 and bedroom1 are connected"}, {"start": 839, "end": 872, "label": "CONNECTION", "text": "bedroom2 is adjacent to washroom1"}]},
{"document": "The house plan has two bedrooms, one washroom, two balconys, one livingroom, and one kitchen. Specifically, wall of bedroom1 is Bamboo_Vine and Red as well as floor is Painted_Wood and White. bedroom1 is in east with 12 square meters. In addition, bedroom2 covers 9 square meters located in northwest. wall of bedroom2 is Bamboo_Vine and Yellow while uses Green Ceramic_Tile for floor. floor of washroom1 is Marble and Purple as well as wall is White Coating. washroom1 has 3 squares in north. balcony1 covers 6 square meters located in southeast. balcony1 uses Pink Marble for floor, and has White Painted_Wood wall. balcony2 wall is Red Marble as well as floor is Painted_Wood and Black. balcony2 is in west with 3 square meters. livingroom1 wall is Red Rock_Plate, and floor is Purple Wood_Veneer. livingroom1 covers 23 square meters located in south. kitchen1 has Blue Wood_Grain floor while wall is Rock_Plate and Blue. kitchen1 has 5 squares in southwest. bedroom1, bedroom2, balcony1, kitchen1, washroom1 and livingroom1 are connected. bedroom1 is next to balcony1, washroom1. washroom1, balcony2 and bedroom2 are connected. kitchen1 is adjacent to balcony2. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 31, "label": "ROOM", "text": "bedrooms"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 45, "label": "ROOM", "text": "washroom"}, {"start": 47, "end": 50, "label": "QUANT", "text": "two"}, {"start": 61, "end": 64, "label": "QUANT", "text": "one"}, {"start": 65, "end": 75, "label": "ROOM", "text": "livingroom"}, {"start": 81, "end": 84, "label": "QUANT", "text": "one"}, {"start": 85, "end": 92, "label": "ROOM", "text": "kitchen"}, {"start": 116, "end": 124, "label": "ROOM", "text": "bedroom1"}, {"start": 207, "end": 211, "label": "DIRECTION", "text": "east"}, {"start": 217, "end": 233, "label": "DIMENSION", "text": "12 square meters"}, {"start": 248, "end": 256, "label": "ROOM", "text": "bedroom2"}, {"start": 264, "end": 279, "label": "DIMENSION", "text": "9 square meters"}, {"start": 291, "end": 300, "label": "DIRECTION", "text": "northwest"}, {"start": 395, "end": 404, "label": "ROOM", "text": "washroom1"}, {"start": 460, "end": 469, "label": "ROOM", "text": "washroom1"}, {"start": 474, "end": 483, "label": "DIMENSION", "text": "3 squares"}, {"start": 487, "end": 492, "label": "DIRECTION", "text": "north"}, {"start": 494, "end": 502, "label": "ROOM", "text": "balcony1"}, {"start": 510, "end": 525, "label": "DIMENSION", "text": "6 square meters"}, {"start": 537, "end": 546, "label": "DIRECTION", "text": "southeast"}, {"start": 548, "end": 556, "label": "ROOM", "text": "balcony1"}, {"start": 618, "end": 626, "label": "ROOM", "text": "balcony2"}, {"start": 715, "end": 730, "label": "DIMENSION", "text": "3 square meters"}, {"start": 732, "end": 743, "label": "ROOM", "text": "livingroom1"}, {"start": 820, "end": 836, "label": "DIMENSION", "text": "23 square meters"}, {"start": 848, "end": 854, "label": "DIRECTION", "text": "south."}, {"start": 855, "end": 863, "label": "ROOM", "text": "kitchen1"}, {"start": 938, "end": 947, "label": "DIMENSION", "text": "5 squares"}, {"start": 951, "end": 960, "label": "DIRECTION", "text": "southwest"}, {"start": 962, "end": 1041, "label": "CONNECTION", "text": "bedroom1, bedroom2, balcony1, kitchen1, washroom1 and livingroom1 are connected"}, {"start": 1043, "end": 1082, "label": "CONNECTION", "text": "bedroom1 is next to balcony1, washroom1"}, {"start": 1084, "end": 1130, "label": "CONNECTION", "text": "washroom1, balcony2 and bedroom2 are connected"}, {"start": 1132, "end": 1164, "label": "CONNECTION", "text": "kitchen1 is adjacent to balcony2"}]},
{"document": "House has one washroom, one livingroom, one study, two bedrooms, one kitchen, and one balcony. More specifically, floor of washroom1 is Stone_Brick and Yellow as well as has Pink Marble wall. washroom1 covers 4 square meters located in west. livingroom1 uses Purple Log for floor while has Orange Coating wall. livingroom1 covers 29 square meters located in center. study1 has 5 squares in west. study1 wall is Green Ceramics, and floor is Stone_Brick and Purple. Moreover, bedroom1 uses Wood_color Log for floor as well as wall is Black Wood_Veneer. bedroom1 covers 13 square meters located in south. bedroom2 has Orange Ceramic_Tile wall while floor is Wood_color Bamboo_Vine. bedroom2 covers 9 square meters located in north. Additionally, kitchen1 covers 7 square meters located in north. floor of kitchen1 is Cement_Board and Black as well as wall is Wood_Veneer and Wood_color. balcony1 has 6 squares in south. balcony1 wall is Orange Pure_Color_Wood, and floor is Pure_Color_Wood and Yellow. bedroom1, bedroom2, kitchen1, balcony1, study1, washroom1 and livingroom1 are connected. bedroom1 is next to balcony1, study1. bedroom2 is adjacent to kitchen1, washroom1. study1 is next to washroom1. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "one"}, {"start": 24, "end": 27, "label": "QUANT", "text": "one"}, {"start": 28, "end": 38, "label": "ROOM", "text": "livingroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 49, "label": "ROOM", "text": "study"}, {"start": 51, "end": 54, "label": "QUANT", "text": "two"}, {"start": 55, "end": 63, "label": "ROOM", "text": "bedrooms"}, {"start": 65, "end": 68, "label": "QUANT", "text": "one"}, {"start": 69, "end": 76, "label": "ROOM", "text": "kitchen"}, {"start": 82, "end": 85, "label": "QUANT", "text": "one"}, {"start": 86, "end": 93, "label": "ROOM", "text": "balcony"}, {"start": 123, "end": 132, "label": "ROOM", "text": "washroom1"}, {"start": 209, "end": 224, "label": "DIMENSION", "text": "4 square meters"}, {"start": 236, "end": 240, "label": "DIRECTION", "text": "west"}, {"start": 242, "end": 253, "label": "ROOM", "text": "livingroom1"}, {"start": 330, "end": 346, "label": "DIMENSION", "text": "29 square meters"}, {"start": 366, "end": 372, "label": "ROOM", "text": "study1"}, {"start": 377, "end": 386, "label": "DIMENSION", "text": "5 squares"}, {"start": 390, "end": 394, "label": "DIRECTION", "text": "west"}, {"start": 474, "end": 482, "label": "ROOM", "text": "bedroom1"}, {"start": 567, "end": 583, "label": "DIMENSION", "text": "13 square meters"}, {"start": 595, "end": 600, "label": "DIRECTION", "text": "south"}, {"start": 602, "end": 610, "label": "ROOM", "text": "bedroom2"}, {"start": 695, "end": 710, "label": "DIMENSION", "text": "9 square meters"}, {"start": 722, "end": 727, "label": "DIRECTION", "text": "north"}, {"start": 743, "end": 751, "label": "ROOM", "text": "kitchen1"}, {"start": 759, "end": 774, "label": "DIMENSION", "text": "7 square meters"}, {"start": 786, "end": 791, "label": "DIRECTION", "text": "north"}, {"start": 884, "end": 892, "label": "ROOM", "text": "balcony1"}, {"start": 897, "end": 906, "label": "DIMENSION", "text": "6 squares"}, {"start": 910, "end": 915, "label": "DIRECTION", "text": "south"}, {"start": 917, "end": 925, "label": "ROOM", "text": "balcony1"}, {"start": 999, "end": 1086, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, balcony1, study1, washroom1 and livingroom1 are connected"}, {"start": 1088, "end": 1124, "label": "CONNECTION", "text": "bedroom1 is next to balcony1, study1"}, {"start": 1126, "end": 1198, "label": "CONNECTION", "text": "bedroom2 is adjacent to kitchen1, washroom1. study1 is next to washroom1"}]},
{"document": "The building contains two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. To be specific, floor of bedroom1 is Ceramics and Wood_color as well as wall is Purple Mosaic. bedroom1 is in north with 13 square meters. In addition, bedroom2 floor is White Log while has Red Wood_Veneer wall. bedroom2 covers 10 square meters located in northeast. Besides, washroom1 has 4 squares in east. washroom1 has Gray Wallpaper wall, and uses Green Coating for floor. balcony1 has 6 squares in northwest. balcony1 has Pink Stone_Brick wall as well as uses Purple Log for floor. Moreover, livingroom1 is in center with 23 square meters. wall of livingroom1 is Coating and Gray, and floor is Wood_color Coating. kitchen1 floor is Earth_color Wood_Veneer while has Red Painted_Wood wall. kitchen1 is in southeast with 7 square meters. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1. bedroom1 is next to bedroom2, balcony1. bedroom2 is adjacent to washroom1. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "two"}, {"start": 26, "end": 35, "label": "ROOM", "text": "bedrooms,"}, {"start": 36, "end": 39, "label": "QUANT", "text": "one"}, {"start": 40, "end": 48, "label": "ROOM", "text": "washroom"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 61, "label": "ROOM", "text": "balcony"}, {"start": 63, "end": 66, "label": "QUANT", "text": "one"}, {"start": 67, "end": 77, "label": "ROOM", "text": "livingroom"}, {"start": 83, "end": 86, "label": "QUANT", "text": "one"}, {"start": 87, "end": 94, "label": "ROOM", "text": "kitchen"}, {"start": 121, "end": 129, "label": "ROOM", "text": "bedroom1"}, {"start": 206, "end": 211, "label": "DIRECTION", "text": "north"}, {"start": 217, "end": 233, "label": "DIMENSION", "text": "13 square meters"}, {"start": 248, "end": 256, "label": "ROOM", "text": "bedroom2"}, {"start": 308, "end": 316, "label": "ROOM", "text": "bedroom2"}, {"start": 324, "end": 340, "label": "DIMENSION", "text": "10 square meters"}, {"start": 352, "end": 361, "label": "DIRECTION", "text": "northeast"}, {"start": 372, "end": 381, "label": "ROOM", "text": "washroom1"}, {"start": 386, "end": 395, "label": "DIMENSION", "text": "4 squares"}, {"start": 399, "end": 403, "label": "DIRECTION", "text": "east"}, {"start": 405, "end": 414, "label": "ROOM", "text": "washroom1"}, {"start": 474, "end": 482, "label": "ROOM", "text": "balcony1"}, {"start": 487, "end": 496, "label": "DIMENSION", "text": "6 squares"}, {"start": 500, "end": 509, "label": "DIRECTION", "text": "northwest"}, {"start": 511, "end": 519, "label": "ROOM", "text": "balcony1"}, {"start": 594, "end": 605, "label": "ROOM", "text": "livingroom1"}, {"start": 624, "end": 640, "label": "DIMENSION", "text": "23 square meters"}, {"start": 716, "end": 724, "label": "ROOM", "text": "kitchen1"}, {"start": 806, "end": 815, "label": "DIRECTION", "text": "southeast"}, {"start": 821, "end": 836, "label": "DIMENSION", "text": "7 square meters"}, {"start": 838, "end": 904, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1"}, {"start": 906, "end": 944, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2, balcony1"}, {"start": 946, "end": 979, "label": "CONNECTION", "text": "bedroom2 is adjacent to washroom1"}]},
{"document": "House has three bedrooms, one washroom, one balcony, one livingroom, and one kitchen. In practice, bedroom1 has 13 squares in south. wall of bedroom1 is Bamboo_Vine and Green, and uses White Mosaic for floor. bedroom2 has 9 squares in north. bedroom2 has Earth_color Coating floor as well as wall is Stone_Brick and Green. bedroom3 covers 5 square meters located in west. bedroom3 uses Red Ceramics for floor while wall is Gray Wood_Veneer. wall of washroom1 is Jade and Green, and has Earth_color Wood_Veneer floor. washroom1 has 4 squares in west. balcony1 is in south with 6 square meters. balcony1 wall is Red Wall_Cloth while floor is Rock_Plate and Purple. livingroom1 covers 30 square meters located in center. livingroom1 floor is Pink Painted_Wood as well as has Black Jade wall. kitchen1 is in north with 6 square meters. kitchen1 uses Wood_color Ceramics for floor, and wall is White Granite. livingroom1 is adjacent to bedroom1, bedroom2, balcony1, kitchen1, bedroom3, washroom1. balcony1, bedroom3 and bedroom1 are connected. bedroom2 is next to kitchen1, washroom1. bedroom3 is adjacent to washroom1. ", "annotation": [{"start": 16, "end": 24, "label": "ROOM", "text": "bedrooms"}, {"start": 26, "end": 29, "label": "QUANT", "text": "one"}, {"start": 30, "end": 38, "label": "ROOM", "text": "washroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 51, "label": "ROOM", "text": "balcony"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 67, "label": "ROOM", "text": "livingroom"}, {"start": 73, "end": 76, "label": "QUANT", "text": "one"}, {"start": 77, "end": 84, "label": "ROOM", "text": "kitchen"}, {"start": 99, "end": 107, "label": "ROOM", "text": "bedroom1"}, {"start": 112, "end": 122, "label": "DIMENSION", "text": "13 squares"}, {"start": 126, "end": 131, "label": "DIRECTION", "text": "south"}, {"start": 141, "end": 149, "label": "ROOM", "text": "bedroom1"}, {"start": 209, "end": 217, "label": "ROOM", "text": "bedroom2"}, {"start": 222, "end": 231, "label": "DIMENSION", "text": "9 squares"}, {"start": 235, "end": 240, "label": "DIRECTION", "text": "north"}, {"start": 242, "end": 250, "label": "ROOM", "text": "bedroom2"}, {"start": 323, "end": 331, "label": "ROOM", "text": "bedroom3"}, {"start": 339, "end": 354, "label": "DIMENSION", "text": "5 square meters"}, {"start": 366, "end": 370, "label": "DIRECTION", "text": "west"}, {"start": 372, "end": 380, "label": "ROOM", "text": "bedroom3"}, {"start": 449, "end": 458, "label": "ROOM", "text": "washroom1"}, {"start": 517, "end": 526, "label": "ROOM", "text": "washroom1"}, {"start": 531, "end": 540, "label": "DIMENSION", "text": "4 squares"}, {"start": 544, "end": 548, "label": "DIRECTION", "text": "west"}, {"start": 550, "end": 558, "label": "ROOM", "text": "balcony1"}, {"start": 565, "end": 570, "label": "DIRECTION", "text": "south"}, {"start": 576, "end": 591, "label": "DIMENSION", "text": "6 square meters"}, {"start": 593, "end": 601, "label": "ROOM", "text": "balcony1"}, {"start": 663, "end": 674, "label": "ROOM", "text": "livingroom1"}, {"start": 682, "end": 698, "label": "DIMENSION", "text": "30 square meters"}, {"start": 789, "end": 797, "label": "ROOM", "text": "kitchen1"}, {"start": 804, "end": 809, "label": "DIRECTION", "text": "north"}, {"start": 810, "end": 830, "label": "DIMENSION", "text": "with 6 square meters"}, {"start": 904, "end": 990, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, balcony1, kitchen1, bedroom3, washroom1"}, {"start": 992, "end": 1037, "label": "CONNECTION", "text": "balcony1, bedroom3 and bedroom1 are connected"}, {"start": 1039, "end": 1078, "label": "CONNECTION", "text": "bedroom2 is next to kitchen1, washroom1"}, {"start": 1080, "end": 1113, "label": "CONNECTION", "text": "bedroom3 is adjacent to washroom1"}]},
{"document": "Building layout contains one washroom, one livingroom, and three bedrooms. Specifically, washroom1 has Yellow Pure_Color_Wood floor as well as has Blue Wallpaper wall. washroom1 is in southwest with 4 square meters. Additionally, livingroom1 uses Gray Bamboo_Vine for floor, and wall is Wall_Cloth and Black. livingroom1 is in center with 27 square meters. floor of bedroom1 is Wood_Veneer and White as well as wall is Yellow Wood_Veneer. bedroom1 has 10 squares in northwest. Besides, bedroom2 covers 9 square meters located in northeast. bedroom2 floor is Wood_color Wood_Grain, and wall is Wood_Veneer and Green. bedroom3 has 8 squares in north. bedroom3 floor is Yellow Quartz as well as has Red Log wall. bedroom1, bedroom2, bedroom3, washroom1 and livingroom1 are connected. bedroom1 is next to bedroom3. bedroom2 is adjacent to bedroom3. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "one"}, {"start": 29, "end": 37, "label": "ROOM", "text": "washroom"}, {"start": 39, "end": 42, "label": "QUANT", "text": "one"}, {"start": 43, "end": 53, "label": "ROOM", "text": "livingroom"}, {"start": 59, "end": 64, "label": "QUANT", "text": "three"}, {"start": 65, "end": 73, "label": "ROOM", "text": "bedrooms"}, {"start": 89, "end": 98, "label": "ROOM", "text": "washroom1"}, {"start": 168, "end": 177, "label": "ROOM", "text": "washroom1"}, {"start": 184, "end": 193, "label": "DIRECTION", "text": "southwest"}, {"start": 199, "end": 214, "label": "DIMENSION", "text": "4 square meters"}, {"start": 230, "end": 241, "label": "ROOM", "text": "livingroom1"}, {"start": 339, "end": 355, "label": "DIMENSION", "text": "27 square meters"}, {"start": 366, "end": 374, "label": "ROOM", "text": "bedroom1"}, {"start": 452, "end": 462, "label": "DIMENSION", "text": "10 squares"}, {"start": 466, "end": 475, "label": "DIRECTION", "text": "northwest"}, {"start": 486, "end": 494, "label": "ROOM", "text": "bedroom2"}, {"start": 502, "end": 517, "label": "DIMENSION", "text": "9 square meters"}, {"start": 529, "end": 538, "label": "DIRECTION", "text": "northeast"}, {"start": 616, "end": 624, "label": "ROOM", "text": "bedroom3"}, {"start": 629, "end": 638, "label": "DIMENSION", "text": "8 squares"}, {"start": 642, "end": 647, "label": "DIRECTION", "text": "north"}, {"start": 649, "end": 657, "label": "ROOM", "text": "bedroom3"}, {"start": 708, "end": 779, "label": "CONNECTION", "text": ". bedroom1, bedroom2, bedroom3, washroom1 and livingroom1 are connected"}, {"start": 781, "end": 809, "label": "CONNECTION", "text": "bedroom1 is next to bedroom3"}, {"start": 811, "end": 843, "label": "CONNECTION", "text": "bedroom2 is adjacent to bedroom3"}]},
{"document": "The house plan has two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. To be specific, bedroom1 is in northwest with 13 square meters. bedroom1 wall is Black Wallpaper as well as floor is Quartz and Red. bedroom2 has Black Mosaic floor, and wall is Mosaic and Wood_color. bedroom2 is in east with 9 square meters. washroom1 is in north with 5 square meters. washroom1 wall is Pink Bamboo_Vine while floor is Cement_Board and White. balcony1 is in west with 5 square meters. balcony1 has Pink Coating wall, and floor is Wood_color Wood_Grain. livingroom1 wall is Blue Bamboo_Vine while has Orange Jade floor. livingroom1 has 26 squares in center. Additionally, kitchen1 covers 6 square meters located in southeast. kitchen1 has Green Wood_Grain floor as well as wall is Gray Quartz. bedroom1, bedroom2, kitchen1, balcony1, washroom1 and livingroom1 are connected. bedroom1 is adjacent to balcony1, washroom1. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 31, "label": "ROOM", "text": "bedrooms"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 45, "label": "ROOM", "text": "washroom"}, {"start": 47, "end": 50, "label": "QUANT", "text": "one"}, {"start": 51, "end": 58, "label": "ROOM", "text": "balcony"}, {"start": 60, "end": 63, "label": "QUANT", "text": "one"}, {"start": 64, "end": 74, "label": "ROOM", "text": "livingroom"}, {"start": 80, "end": 83, "label": "QUANT", "text": "one"}, {"start": 84, "end": 91, "label": "ROOM", "text": "kitchen"}, {"start": 109, "end": 117, "label": "ROOM", "text": "bedroom1"}, {"start": 124, "end": 133, "label": "DIRECTION", "text": "northwest"}, {"start": 139, "end": 155, "label": "DIMENSION", "text": "13 square meters"}, {"start": 157, "end": 165, "label": "ROOM", "text": "bedroom1"}, {"start": 226, "end": 234, "label": "ROOM", "text": "bedroom2"}, {"start": 309, "end": 313, "label": "DIRECTION", "text": "east"}, {"start": 319, "end": 334, "label": "DIMENSION", "text": "9 square meters"}, {"start": 336, "end": 345, "label": "ROOM", "text": "washroom1"}, {"start": 352, "end": 357, "label": "DIRECTION", "text": "north"}, {"start": 363, "end": 378, "label": "DIMENSION", "text": "5 square meters"}, {"start": 454, "end": 462, "label": "ROOM", "text": "balcony1"}, {"start": 469, "end": 473, "label": "DIRECTION", "text": "west"}, {"start": 479, "end": 494, "label": "DIMENSION", "text": "5 square meters"}, {"start": 496, "end": 504, "label": "ROOM", "text": "balcony1"}, {"start": 564, "end": 575, "label": "ROOM", "text": "livingroom1"}, {"start": 646, "end": 656, "label": "DIMENSION", "text": "26 squares"}, {"start": 682, "end": 690, "label": "ROOM", "text": "kitchen1"}, {"start": 698, "end": 713, "label": "DIMENSION", "text": "6 square meters"}, {"start": 725, "end": 734, "label": "DIRECTION", "text": "southeast"}, {"start": 804, "end": 883, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, balcony1, washroom1 and livingroom1 are connected"}, {"start": 885, "end": 928, "label": "CONNECTION", "text": "bedroom1 is adjacent to balcony1, washroom1"}]},
{"document": "The house plan has one washroom, one livingroom, one study, two bedrooms, one kitchen, and one balcony. Specifically, washroom1 has Earth_color Wall_Cloth wall, and uses Green Rock_Plate for floor. washroom1 covers 3 square meters located in west. livingroom1 covers 29 square meters located in center. livingroom1 floor is Pink Wall_Cloth while wall is Blue Mosaic. Additionally, study1 floor is Blue Log, and wall is Stone_Brick and Green. study1 covers 7 square meters located in center. Moreover, bedroom1 wall is White Painted_Wood while floor is Purple Pure_Color_Wood. bedroom1 covers 13 square meters located in south. bedroom2 floor is Gray Wallpaper, and has Purple Granite wall. bedroom2 has 9 squares in north. In addition, kitchen1 is in north with 6 square meters. kitchen1 has Gray Pure_Color_Wood wall while floor is Black Cement_Board. balcony1 uses Blue Wall_Cloth for floor, and wall is Wood_Grain and Red. balcony1 has 6 squares in south. livingroom1 is adjacent to bedroom1, bedroom2, study1, kitchen1, balcony1, washroom1. bedroom1 is next to study1, balcony1. kitchen1, washroom1 and bedroom2 are connected. study1 is adjacent to washroom1. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 31, "label": "ROOM", "text": "washroom"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 47, "label": "ROOM", "text": "livingroom"}, {"start": 49, "end": 52, "label": "QUANT", "text": "one"}, {"start": 53, "end": 58, "label": "ROOM", "text": "study"}, {"start": 60, "end": 63, "label": "QUANT", "text": "two"}, {"start": 64, "end": 72, "label": "ROOM", "text": "bedrooms"}, {"start": 74, "end": 77, "label": "QUANT", "text": "one"}, {"start": 78, "end": 85, "label": "ROOM", "text": "kitchen"}, {"start": 91, "end": 94, "label": "QUANT", "text": "one"}, {"start": 95, "end": 102, "label": "ROOM", "text": "balcony"}, {"start": 118, "end": 127, "label": "ROOM", "text": "washroom1"}, {"start": 215, "end": 230, "label": "DIMENSION", "text": "3 square meters"}, {"start": 242, "end": 246, "label": "DIRECTION", "text": "west"}, {"start": 248, "end": 259, "label": "ROOM", "text": "livingroom1"}, {"start": 267, "end": 283, "label": "DIMENSION", "text": "29 square meters"}, {"start": 381, "end": 387, "label": "ROOM", "text": "study1"}, {"start": 442, "end": 448, "label": "ROOM", "text": "study1"}, {"start": 456, "end": 471, "label": "DIMENSION", "text": "7 square meters"}, {"start": 501, "end": 509, "label": "ROOM", "text": "bedroom1"}, {"start": 592, "end": 608, "label": "DIMENSION", "text": "13 square meters"}, {"start": 620, "end": 625, "label": "DIRECTION", "text": "south"}, {"start": 627, "end": 635, "label": "ROOM", "text": "bedroom2"}, {"start": 703, "end": 712, "label": "DIMENSION", "text": "9 squares"}, {"start": 716, "end": 721, "label": "DIRECTION", "text": "north"}, {"start": 736, "end": 744, "label": "ROOM", "text": "kitchen1"}, {"start": 751, "end": 756, "label": "DIRECTION", "text": "north"}, {"start": 762, "end": 777, "label": "DIMENSION", "text": "6 square meters"}, {"start": 853, "end": 861, "label": "ROOM", "text": "balcony1"}, {"start": 939, "end": 948, "label": "DIMENSION", "text": "6 squares"}, {"start": 952, "end": 957, "label": "DIRECTION", "text": "south"}, {"start": 959, "end": 1043, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, study1, kitchen1, balcony1, washroom1"}, {"start": 1045, "end": 1081, "label": "CONNECTION", "text": "bedroom1 is next to study1, balcony1"}, {"start": 1083, "end": 1129, "label": "CONNECTION", "text": "kitchen1, washroom1 and bedroom2 are connected"}, {"start": 1129, "end": 1162, "label": "CONNECTION", "text": ". study1 is adjacent to washroom1"}]},
{"document": "The house plan has one washroom, one livingroom, and two bedrooms. Specifically, washroom1 wall is Earth_color Cement_Board as well as floor is Pink Bamboo_Vine. washroom1 covers 6 square meters located in north. In addition, livingroom1 uses Pink Mosaic for floor, and wall is Purple Ceramic_Tile. livingroom1 covers 46 square meters located in center. Additionally, bedroom1 has 13 squares in northwest. bedroom1 has Orange Marble wall while uses White Granite for floor. Besides, bedroom2 uses Wood_color Ceramics for floor, and wall is Pink Stone_Brick. bedroom2 has 10 squares in northeast. livingroom1 is adjacent to bedroom1, bedroom2, washroom1. washroom1 and bedroom1 are connected. bedroom2 is next to washroom1. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 31, "label": "ROOM", "text": "washroom"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 47, "label": "ROOM", "text": "livingroom"}, {"start": 53, "end": 56, "label": "QUANT", "text": "two"}, {"start": 57, "end": 65, "label": "ROOM", "text": "bedrooms"}, {"start": 81, "end": 90, "label": "ROOM", "text": "washroom1"}, {"start": 179, "end": 187, "label": "DIMENSION", "text": "6 square"}, {"start": 226, "end": 237, "label": "ROOM", "text": "livingroom1"}, {"start": 318, "end": 334, "label": "DIMENSION", "text": "46 square meters"}, {"start": 368, "end": 376, "label": "ROOM", "text": "bedroom1"}, {"start": 381, "end": 391, "label": "DIMENSION", "text": "13 squares"}, {"start": 395, "end": 404, "label": "DIRECTION", "text": "northwest"}, {"start": 483, "end": 491, "label": "ROOM", "text": "bedroom2"}, {"start": 571, "end": 581, "label": "DIMENSION", "text": "10 squares"}, {"start": 585, "end": 594, "label": "DIRECTION", "text": "northeast"}, {"start": 596, "end": 652, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, washroom1"}, {"start": 654, "end": 690, "label": "CONNECTION", "text": "washroom1 and bedroom1 are connected"}, {"start": 692, "end": 721, "label": "CONNECTION", "text": "bedroom2 is next to washroom1"}]},
{"document": "The house plan has two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. To be specific, bedroom1 has 14 squares in south. bedroom1 has White Marble floor, and has Black Wood_Veneer wall. In addition, bedroom2 is in north with 13 square meters. bedroom2 wall is Wood_color Wood_Veneer as well as floor is Ceramics and Blue. Additionally, washroom1 is in west with 6 square meters. floor of washroom1 is Log and Orange, and wall is Pink Granite. In addition, balcony1 is in south with 4 square meters. balcony1 has Earth_color Wood_Veneer wall while has Red Coating floor. floor of livingroom1 is Mosaic and White as well as wall is Yellow Ceramic_Tile. livingroom1 has 38 squares in center. kitchen1 has 7 squares in north. kitchen1 wall is Black Pure_Color_Wood, and uses Wood_color Wall_Cloth for floor. bedroom1, bedroom2, kitchen1, washroom1, balcony1 and livingroom1 are connected. bedroom1 is next to washroom1. kitchen1, washroom1 and bedroom2 are connected. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "two"}, {"start": 23, "end": 31, "label": "ROOM", "text": "bedrooms"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 45, "label": "ROOM", "text": "washroom"}, {"start": 47, "end": 50, "label": "QUANT", "text": "one"}, {"start": 51, "end": 58, "label": "ROOM", "text": "balcony"}, {"start": 60, "end": 63, "label": "QUANT", "text": "one"}, {"start": 64, "end": 74, "label": "ROOM", "text": "livingroom"}, {"start": 80, "end": 83, "label": "QUANT", "text": "one"}, {"start": 84, "end": 91, "label": "ROOM", "text": "kitchen"}, {"start": 109, "end": 117, "label": "ROOM", "text": "bedroom1"}, {"start": 136, "end": 141, "label": "DIRECTION", "text": "south"}, {"start": 221, "end": 229, "label": "ROOM", "text": "bedroom2"}, {"start": 236, "end": 241, "label": "DIRECTION", "text": "north"}, {"start": 247, "end": 263, "label": "DIMENSION", "text": "13 square meters"}, {"start": 265, "end": 273, "label": "ROOM", "text": "bedroom2"}, {"start": 358, "end": 367, "label": "ROOM", "text": "washroom1"}, {"start": 374, "end": 378, "label": "DIRECTION", "text": "west"}, {"start": 384, "end": 399, "label": "DIMENSION", "text": "6 square meters"}, {"start": 410, "end": 419, "label": "ROOM", "text": "washroom1"}, {"start": 478, "end": 486, "label": "ROOM", "text": "balcony1"}, {"start": 493, "end": 498, "label": "DIRECTION", "text": "south"}, {"start": 504, "end": 519, "label": "DIMENSION", "text": "4 square meters"}, {"start": 521, "end": 529, "label": "ROOM", "text": "balcony1"}, {"start": 673, "end": 684, "label": "ROOM", "text": "livingroom1"}, {"start": 689, "end": 699, "label": "DIMENSION", "text": "38 squares"}, {"start": 711, "end": 719, "label": "ROOM", "text": "kitchen1"}, {"start": 724, "end": 733, "label": "DIMENSION", "text": "7 squares"}, {"start": 737, "end": 742, "label": "DIRECTION", "text": "north"}, {"start": 826, "end": 905, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, washroom1, balcony1 and livingroom1 are connected"}, {"start": 907, "end": 936, "label": "CONNECTION", "text": "bedroom1 is next to washroom1"}, {"start": 936, "end": 984, "label": "CONNECTION", "text": ". kitchen1, washroom1 and bedroom2 are connected"}]},
{"document": "House has three bedrooms, one washroom, one balcony, one livingroom, and one kitchen. Specifically, bedroom1 has 13 squares in west. bedroom1 wall is Red Quartz, and uses Pink Cement_Board for floor. In addition, bedroom2 has Yellow Jade floor while wall is Green Pure_Color_Wood. bedroom2 covers 10 square meters located in east. bedroom3 uses Wood_color Rock_Plate for floor, and wall is Wood_Veneer and Purple. bedroom3 covers 7 square meters located in east. washroom1 uses Gray Wallpaper for floor as well as has Gray Rock_Plate wall. washroom1 has 4 squares in north. Additionally, balcony1 has Gray Ceramic_Tile wall, and uses Gray Wall_Cloth for floor. balcony1 has 6 squares in west. Besides, livingroom1 uses Gray Cement_Board for floor as well as wall is Mosaic and Black. livingroom1 has 30 squares in center. Additionally, wall of kitchen1 is Ceramic_Tile and Red, and floor is Earth_color Granite. kitchen1 covers 7 square meters located in center. bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1 and livingroom1 are connected. bedroom1 is adjacent to kitchen1, balcony1. bedroom2 is next to bedroom3. washroom1 and bedroom3 are connected. kitchen1 is next to washroom1. ", "annotation": [{"start": 10, "end": 15, "label": "QUANT", "text": "three"}, {"start": 16, "end": 24, "label": "ROOM", "text": "bedrooms"}, {"start": 26, "end": 29, "label": "QUANT", "text": "one"}, {"start": 30, "end": 39, "label": "ROOM", "text": "washroom,"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 51, "label": "ROOM", "text": "balcony"}, {"start": 53, "end": 56, "label": "QUANT", "text": "one"}, {"start": 57, "end": 67, "label": "ROOM", "text": "livingroom"}, {"start": 73, "end": 76, "label": "QUANT", "text": "one"}, {"start": 77, "end": 84, "label": "ROOM", "text": "kitchen"}, {"start": 100, "end": 108, "label": "ROOM", "text": "bedroom1"}, {"start": 113, "end": 123, "label": "DIMENSION", "text": "13 squares"}, {"start": 127, "end": 131, "label": "DIRECTION", "text": "west"}, {"start": 213, "end": 221, "label": "ROOM", "text": "bedroom2"}, {"start": 297, "end": 313, "label": "DIMENSION", "text": "10 square meters"}, {"start": 325, "end": 329, "label": "DIRECTION", "text": "east"}, {"start": 331, "end": 339, "label": "ROOM", "text": "bedroom3"}, {"start": 414, "end": 422, "label": "ROOM", "text": "bedroom3"}, {"start": 430, "end": 445, "label": "DIMENSION", "text": "7 square meters"}, {"start": 457, "end": 461, "label": "DIRECTION", "text": "east"}, {"start": 540, "end": 549, "label": "ROOM", "text": "washroom1"}, {"start": 554, "end": 563, "label": "DIMENSION", "text": "4 squares"}, {"start": 567, "end": 572, "label": "DIRECTION", "text": "north"}, {"start": 588, "end": 596, "label": "ROOM", "text": "balcony1"}, {"start": 674, "end": 683, "label": "DIMENSION", "text": "6 squares"}, {"start": 687, "end": 691, "label": "DIRECTION", "text": "west"}, {"start": 702, "end": 713, "label": "ROOM", "text": "livingroom1"}, {"start": 800, "end": 810, "label": "DIMENSION", "text": "30 squares"}, {"start": 844, "end": 852, "label": "ROOM", "text": "kitchen1"}, {"start": 912, "end": 920, "label": "ROOM", "text": "kitchen1"}, {"start": 928, "end": 943, "label": "DIMENSION", "text": "7 square meters"}, {"start": 963, "end": 1052, "label": "CONNECTION", "text": "bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1 and livingroom1 are connected"}, {"start": 1054, "end": 1096, "label": "CONNECTION", "text": "bedroom1 is adjacent to kitchen1, balcony1"}, {"start": 1098, "end": 1126, "label": "CONNECTION", "text": "bedroom2 is next to bedroom3"}, {"start": 1128, "end": 1195, "label": "CONNECTION", "text": "washroom1 and bedroom3 are connected. kitchen1 is next to washroom1"}]},
{"document": "The house plan has one washroom, one livingroom, and two bedrooms. Specifically, washroom1 wall is Wood_color Ceramics, and floor is Pink Cement_Board. washroom1 has 5 squares in west. livingroom1 covers 48 square meters located in center. livingroom1 has Green Stone_Brick floor as well as has Earth_color Ceramic_Tile wall. Moreover, bedroom1 covers 15 square meters located in north. bedroom1 has Black Ceramics wall, and floor is Orange Cement_Board. bedroom2 is in south with 13 square meters. bedroom2 has Green Painted_Wood wall while floor is Wood_color Stone_Brick. livingroom1 is adjacent to bedroom1, bedroom2, washroom1. washroom1 and bedroom1 are connected. bedroom2 is next to washroom1. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 31, "label": "ROOM", "text": "washroom"}, {"start": 33, "end": 36, "label": "QUANT", "text": "one"}, {"start": 37, "end": 47, "label": "ROOM", "text": "livingroom"}, {"start": 53, "end": 56, "label": "QUANT", "text": "two"}, {"start": 57, "end": 65, "label": "ROOM", "text": "bedrooms"}, {"start": 81, "end": 90, "label": "ROOM", "text": "washroom1"}, {"start": 162, "end": 175, "label": "DIMENSION", "text": "has 5 squares"}, {"start": 179, "end": 183, "label": "DIRECTION", "text": "west"}, {"start": 185, "end": 196, "label": "ROOM", "text": "livingroom1"}, {"start": 204, "end": 220, "label": "DIMENSION", "text": "48 square meters"}, {"start": 336, "end": 344, "label": "ROOM", "text": "bedroom1"}, {"start": 352, "end": 368, "label": "DIMENSION", "text": "15 square meters"}, {"start": 380, "end": 385, "label": "DIRECTION", "text": "north"}, {"start": 455, "end": 463, "label": "ROOM", "text": "bedroom2"}, {"start": 470, "end": 475, "label": "DIRECTION", "text": "south"}, {"start": 481, "end": 497, "label": "DIMENSION", "text": "13 square meters"}, {"start": 575, "end": 631, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, washroom1"}, {"start": 633, "end": 669, "label": "CONNECTION", "text": "washroom1 and bedroom1 are connected"}, {"start": 671, "end": 700, "label": "CONNECTION", "text": "bedroom2 is next to washroom1"}]},
{"document": "Building layout contains two washrooms, one livingroom, one study, two bedrooms, one kitchen, and two balconys. In practice, washroom1 is in southwest with 9 square meters. washroom1 floor is Earth_color Wallpaper as well as wall is Mosaic and Pink. In addition, washroom2 covers 5 square meters located in south. washroom2 floor is White Painted_Wood while has Green Mosaic wall. livingroom1 is in east with 35 square meters. livingroom1 uses Earth_color Log for floor as well as wall is Gray Wood_Grain. Besides, floor of study1 is Wallpaper and Blue, and wall is Purple Granite. study1 covers 11 square meters located in south. bedroom1 is in west with 22 square meters. bedroom1 has Earth_color Pure_Color_Wood wall as well as has White Bamboo_Vine floor. Additionally, bedroom2 covers 12 square meters located in north. bedroom2 uses Red Rock_Plate for floor, and wall is Ceramic_Tile and Gray. kitchen1 has 10 squares in south. kitchen1 wall is Green Marble while floor is Wood_color Painted_Wood. In addition, balcony1 covers 13 square meters located in northeast. balcony1 has Blue Ceramics floor as well as wall is Gray Pure_Color_Wood. Moreover, balcony2 has Red Wood_Grain wall while floor is Green Granite. balcony2 is in south with 3 square meters. bedroom1, balcony1, bedroom2, study1, kitchen1, washroom2 and livingroom1 are connected. bedroom1 is next to bedroom2, study1, washroom1. balcony1 is adjacent to bedroom2. washroom1, washroom2, balcony2 and study1 are connected. kitchen1 is adjacent to washroom2, balcony2. balcony2 and washroom2 are connected. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "two"}, {"start": 29, "end": 38, "label": "ROOM", "text": "washrooms"}, {"start": 40, "end": 43, "label": "QUANT", "text": "one"}, {"start": 44, "end": 54, "label": "ROOM", "text": "livingroom"}, {"start": 56, "end": 59, "label": "QUANT", "text": "one"}, {"start": 60, "end": 65, "label": "ROOM", "text": "study"}, {"start": 67, "end": 70, "label": "QUANT", "text": "two"}, {"start": 71, "end": 79, "label": "ROOM", "text": "bedrooms"}, {"start": 81, "end": 84, "label": "QUANT", "text": "one"}, {"start": 85, "end": 92, "label": "ROOM", "text": "kitchen"}, {"start": 98, "end": 101, "label": "QUANT", "text": "two"}, {"start": 102, "end": 110, "label": "ROOM", "text": "balconys"}, {"start": 125, "end": 134, "label": "ROOM", "text": "washroom1"}, {"start": 141, "end": 150, "label": "DIRECTION", "text": "southwest"}, {"start": 156, "end": 171, "label": "DIMENSION", "text": "9 square meters"}, {"start": 173, "end": 182, "label": "ROOM", "text": "washroom1"}, {"start": 263, "end": 272, "label": "ROOM", "text": "washroom2"}, {"start": 273, "end": 295, "label": "DIMENSION", "text": "covers 5 square meters"}, {"start": 307, "end": 312, "label": "DIRECTION", "text": "south"}, {"start": 381, "end": 392, "label": "ROOM", "text": "livingroom1"}, {"start": 399, "end": 403, "label": "DIRECTION", "text": "east"}, {"start": 409, "end": 425, "label": "DIMENSION", "text": "35 square meters"}, {"start": 524, "end": 530, "label": "ROOM", "text": "study1"}, {"start": 596, "end": 612, "label": "DIMENSION", "text": "11 square meters"}, {"start": 624, "end": 629, "label": "DIRECTION", "text": "south"}, {"start": 631, "end": 639, "label": "ROOM", "text": "bedroom1"}, {"start": 646, "end": 650, "label": "DIRECTION", "text": "west"}, {"start": 656, "end": 672, "label": "DIMENSION", "text": "22 square meters"}, {"start": 674, "end": 682, "label": "ROOM", "text": "bedroom1"}, {"start": 790, "end": 806, "label": "DIMENSION", "text": "12 square meters"}, {"start": 818, "end": 823, "label": "DIRECTION", "text": "north"}, {"start": 900, "end": 908, "label": "ROOM", "text": "kitchen1"}, {"start": 913, "end": 923, "label": "DIMENSION", "text": "10 squares"}, {"start": 927, "end": 932, "label": "DIRECTION", "text": "south"}, {"start": 934, "end": 942, "label": "ROOM", "text": "kitchen1"}, {"start": 1033, "end": 1049, "label": "DIMENSION", "text": "13 square meters"}, {"start": 1061, "end": 1070, "label": "DIRECTION", "text": "northeast"}, {"start": 1156, "end": 1164, "label": "ROOM", "text": "balcony2"}, {"start": 1219, "end": 1227, "label": "ROOM", "text": "balcony2"}, {"start": 1234, "end": 1239, "label": "DIRECTION", "text": "south"}, {"start": 1245, "end": 1260, "label": "CONNECTION", "text": "3 square meters"}, {"start": 1262, "end": 1349, "label": "CONNECTION", "text": "bedroom1, balcony1, bedroom2, study1, kitchen1, washroom2 and livingroom1 are connected"}, {"start": 1351, "end": 1398, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2, study1, washroom1"}, {"start": 1400, "end": 1432, "label": "CONNECTION", "text": "balcony1 is adjacent to bedroom2"}, {"start": 1434, "end": 1489, "label": "CONNECTION", "text": "washroom1, washroom2, balcony2 and study1 are connected"}, {"start": 1491, "end": 1534, "label": "CONNECTION", "text": "kitchen1 is adjacent to washroom2, balcony2"}, {"start": 1536, "end": 1572, "label": "CONNECTION", "text": "balcony2 and washroom2 are connected"}]},
{"document": "The building contains one washroom, one livingroom, and one bedroom. Specifically, washroom1 wall is Orange Wood_Veneer, and has Orange Wood_Veneer floor. washroom1 covers 5 square meters located in northeast. livingroom1 covers 37 square meters located in center. livingroom1 has Green Coating wall as well as floor is Ceramics and Purple. In addition, bedroom1 covers 14 square meters located in east. wall of bedroom1 is Coating and Green, and floor is Purple Cement_Board. livingroom1 is adjacent to bedroom1, washroom1. washroom1 and bedroom1 are connected. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "one"}, {"start": 26, "end": 34, "label": "ROOM", "text": "washroom"}, {"start": 36, "end": 39, "label": "QUANT", "text": "one"}, {"start": 40, "end": 55, "label": "ROOM", "text": "livingroom, and"}, {"start": 56, "end": 59, "label": "QUANT", "text": "one"}, {"start": 60, "end": 67, "label": "ROOM", "text": "bedroom"}, {"start": 83, "end": 92, "label": "ROOM", "text": "washroom1"}, {"start": 172, "end": 187, "label": "DIMENSION", "text": "5 square meters"}, {"start": 199, "end": 208, "label": "DIRECTION", "text": "northeast"}, {"start": 210, "end": 221, "label": "ROOM", "text": "livingroom1"}, {"start": 229, "end": 245, "label": "DIMENSION", "text": "37 square meters"}, {"start": 354, "end": 362, "label": "ROOM", "text": "bedroom1"}, {"start": 370, "end": 386, "label": "DIMENSION", "text": "14 square meters"}, {"start": 398, "end": 402, "label": "DIRECTION", "text": "east"}]},
{"document": "The building contains two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. To be specific, bedroom1 has 10 squares in south. bedroom1 has White Wall_Cloth floor, and wall is Gray Jade. In addition, bedroom2 is in northeast with 10 square meters. bedroom2 has Earth_color Jade wall while has Pink Wallpaper floor. Moreover, washroom1 has 4 squares in northwest. washroom1 has Purple Pure_Color_Wood floor, and wall is Pink Mosaic. balcony1 covers 4 square meters located in southwest. floor of balcony1 is Wood_Grain and Wood_color as well as wall is Blue Coating. Besides, livingroom1 has Purple Ceramic_Tile wall while uses Blue Coating for floor. livingroom1 is in center with 22 square meters. kitchen1 covers 6 square meters located in center. floor of kitchen1 is Wood_Grain and Red as well as has Gray Bamboo_Vine wall. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, balcony1, washroom1. bedroom1 is next to kitchen1, balcony1. bedroom2 is adjacent to kitchen1. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "two"}, {"start": 26, "end": 34, "label": "ROOM", "text": "bedrooms"}, {"start": 36, "end": 39, "label": "QUANT", "text": "one"}, {"start": 40, "end": 48, "label": "ROOM", "text": "washroom"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 61, "label": "ROOM", "text": "balcony"}, {"start": 63, "end": 66, "label": "QUANT", "text": "one"}, {"start": 67, "end": 77, "label": "ROOM", "text": "livingroom"}, {"start": 83, "end": 86, "label": "QUANT", "text": "one"}, {"start": 87, "end": 94, "label": "ROOM", "text": "kitchen"}, {"start": 112, "end": 120, "label": "ROOM", "text": "bedroom1"}, {"start": 125, "end": 135, "label": "DIMENSION", "text": "10 squares"}, {"start": 139, "end": 144, "label": "DIRECTION", "text": "south"}, {"start": 219, "end": 227, "label": "ROOM", "text": "bedroom2"}, {"start": 234, "end": 243, "label": "DIRECTION", "text": "northeast"}, {"start": 249, "end": 265, "label": "DIMENSION", "text": "10 square meters"}, {"start": 344, "end": 353, "label": "ROOM", "text": "washroom1"}, {"start": 354, "end": 367, "label": "DIMENSION", "text": "has 4 squares"}, {"start": 371, "end": 380, "label": "DIRECTION", "text": "northwest"}, {"start": 451, "end": 459, "label": "ROOM", "text": "balcony1"}, {"start": 467, "end": 482, "label": "DIMENSION", "text": "4 square meters"}, {"start": 494, "end": 503, "label": "DIRECTION", "text": "southwest"}, {"start": 594, "end": 605, "label": "ROOM", "text": "livingroom1"}, {"start": 700, "end": 716, "label": "DIMENSION", "text": "22 square meters"}, {"start": 718, "end": 726, "label": "ROOM", "text": "kitchen1"}, {"start": 734, "end": 749, "label": "DIMENSION", "text": "6 square meters"}, {"start": 847, "end": 923, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, balcony1, washroom1"}, {"start": 925, "end": 963, "label": "CONNECTION", "text": "bedroom1 is next to kitchen1, balcony1"}, {"start": 965, "end": 997, "label": "CONNECTION", "text": "bedroom2 is adjacent to kitchen1"}]},
{"document": "House has two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. To be specific, bedroom1 covers 19 square meters located in west. wall of bedroom1 is Painted_Wood and White, and has Orange Mosaic floor. Additionally, bedroom2 covers 13 square meters located in northeast. floor of bedroom2 is Ceramic_Tile and Blue as well as has Gray Jade wall. washroom1 covers 5 square meters located in east. washroom1 has Black Painted_Wood floor while has Wood_color Painted_Wood wall. In addition, balcony1 wall is Pink Wall_Cloth, and has Black Wood_Veneer floor. balcony1 has 7 squares in southwest. wall of livingroom1 is Wood_Veneer and Yellow while has Orange Rock_Plate floor. livingroom1 is in center with 43 square meters. Additionally, kitchen1 has 8 squares in southeast. kitchen1 floor is Black Marble, and has Earth_color Mosaic wall. bedroom1, bedroom2, kitchen1, balcony1, washroom1 and livingroom1 are connected. bedroom1 is adjacent to balcony1. bedroom2 is next to washroom1. washroom1 and kitchen1 are connected. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "two"}, {"start": 14, "end": 22, "label": "ROOM", "text": "bedrooms"}, {"start": 24, "end": 27, "label": "QUANT", "text": "one"}, {"start": 28, "end": 36, "label": "ROOM", "text": "washroom"}, {"start": 38, "end": 41, "label": "QUANT", "text": "one"}, {"start": 42, "end": 49, "label": "ROOM", "text": "balcony"}, {"start": 51, "end": 54, "label": "QUANT", "text": "one"}, {"start": 55, "end": 65, "label": "ROOM", "text": "livingroom"}, {"start": 71, "end": 74, "label": "QUANT", "text": "one"}, {"start": 75, "end": 83, "label": "ROOM", "text": "kitchen."}, {"start": 100, "end": 108, "label": "ROOM", "text": "bedroom1"}, {"start": 116, "end": 132, "label": "DIMENSION", "text": "19 square meters"}, {"start": 144, "end": 148, "label": "DIRECTION", "text": "west"}, {"start": 237, "end": 245, "label": "ROOM", "text": "bedroom2"}, {"start": 253, "end": 269, "label": "DIMENSION", "text": "13 square meters"}, {"start": 281, "end": 290, "label": "DIRECTION", "text": "northeast"}, {"start": 366, "end": 375, "label": "ROOM", "text": "washroom1"}, {"start": 376, "end": 398, "label": "DIMENSION", "text": "covers 5 square meters"}, {"start": 410, "end": 414, "label": "DIRECTION", "text": "east"}, {"start": 508, "end": 516, "label": "ROOM", "text": "balcony1"}, {"start": 588, "end": 597, "label": "DIMENSION", "text": "7 squares"}, {"start": 601, "end": 610, "label": "DIRECTION", "text": "southwest"}, {"start": 620, "end": 631, "label": "ROOM", "text": "livingroom1"}, {"start": 723, "end": 739, "label": "DIMENSION", "text": "43 square meters"}, {"start": 768, "end": 777, "label": "DIMENSION", "text": "8 squares"}, {"start": 781, "end": 790, "label": "DIRECTION", "text": "southeast"}, {"start": 857, "end": 936, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, balcony1, washroom1 and livingroom1 are connected"}, {"start": 938, "end": 970, "label": "CONNECTION", "text": "bedroom1 is adjacent to balcony1"}, {"start": 970, "end": 1001, "label": "CONNECTION", "text": ". bedroom2 is next to washroom1"}, {"start": 1003, "end": 1039, "label": "CONNECTION", "text": "washroom1 and kitchen1 are connected"}]},
{"document": "The house plan has one bedroom, one washroom, two balconys, one livingroom, and one kitchen. In practice, bedroom1 is in east with 12 square meters. bedroom1 wall is Pink Ceramics as well as uses Red Quartz for floor. Moreover, washroom1 covers 5 square meters located in northeast. wall of washroom1 is Cement_Board and Purple while has Wood_color Granite floor. Besides, balcony1 covers 3 square meters located in southwest. balcony1 wall is Yellow Coating as well as floor is Black Wood_Veneer. In addition, balcony2 wall is Earth_color Bamboo_Vine, and has Pink Wallpaper floor. balcony2 is in northeast with 2 square meters. Besides, livingroom1 is in west with 20 square meters. livingroom1 wall is Green Marble as well as floor is Yellow Cement_Board. floor of kitchen1 is Painted_Wood and Green, and wall is Quartz and Yellow. kitchen1 has 7 squares in north. bedroom1, kitchen1, washroom1, balcony1 and livingroom1 are connected. bedroom1 is adjacent to washroom1. kitchen1 is next to washroom1, balcony2. washroom1 is adjacent to balcony2. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 30, "label": "ROOM", "text": "bedroom"}, {"start": 32, "end": 35, "label": "QUANT", "text": "one"}, {"start": 36, "end": 44, "label": "ROOM", "text": "washroom"}, {"start": 46, "end": 49, "label": "QUANT", "text": "two"}, {"start": 50, "end": 58, "label": "ROOM", "text": "balconys"}, {"start": 60, "end": 63, "label": "QUANT", "text": "one"}, {"start": 64, "end": 75, "label": "ROOM", "text": "livingroom,"}, {"start": 80, "end": 83, "label": "QUANT", "text": "one"}, {"start": 84, "end": 91, "label": "ROOM", "text": "kitchen"}, {"start": 106, "end": 114, "label": "ROOM", "text": "bedroom1"}, {"start": 121, "end": 125, "label": "DIRECTION", "text": "east"}, {"start": 131, "end": 147, "label": "DIMENSION", "text": "12 square meters"}, {"start": 228, "end": 237, "label": "ROOM", "text": "washroom1"}, {"start": 238, "end": 260, "label": "DIMENSION", "text": "covers 5 square meters"}, {"start": 272, "end": 281, "label": "DIRECTION", "text": "northeast"}, {"start": 373, "end": 381, "label": "ROOM", "text": "balcony1"}, {"start": 389, "end": 404, "label": "DIMENSION", "text": "3 square meters"}, {"start": 511, "end": 519, "label": "ROOM", "text": "balcony2"}, {"start": 598, "end": 607, "label": "DIRECTION", "text": "northeast"}, {"start": 613, "end": 628, "label": "DIMENSION", "text": "2 square meters"}, {"start": 639, "end": 650, "label": "ROOM", "text": "livingroom1"}, {"start": 657, "end": 661, "label": "DIRECTION", "text": "west"}, {"start": 667, "end": 683, "label": "DIMENSION", "text": "20 square meters"}, {"start": 844, "end": 857, "label": "DIMENSION", "text": "has 7 squares"}, {"start": 861, "end": 866, "label": "DIRECTION", "text": "north"}, {"start": 866, "end": 937, "label": "CONNECTION", "text": ". bedroom1, kitchen1, washroom1, balcony1 and livingroom1 are connected"}, {"start": 939, "end": 972, "label": "CONNECTION", "text": "bedroom1 is adjacent to washroom1"}, {"start": 974, "end": 1013, "label": "CONNECTION", "text": "kitchen1 is next to washroom1, balcony2"}, {"start": 1013, "end": 1048, "label": "CONNECTION", "text": ". washroom1 is adjacent to balcony2"}]},
{"document": "The building contains one washroom, two bedrooms, one livingroom, and one kitchen. Specifically, washroom1 has 2 squares in northeast. washroom1 uses Green Wood_Veneer for floor, and wall is Ceramic_Tile and Blue. bedroom1 is in southwest with 6 square meters. bedroom1 has Green Marble floor while has Blue Marble wall. Additionally, bedroom2 has Orange Jade wall as well as floor is Cement_Board and Earth_color. bedroom2 is in west with 5 square meters. livingroom1 has 18 squares in center. livingroom1 uses Yellow Wall_Cloth for floor while wall is Purple Stone_Brick. kitchen1 has Black Quartz floor, and wall is Bamboo_Vine and White. kitchen1 covers 4 square meters located in northeast. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1. bedroom1 is next to bedroom2. kitchen1 is adjacent to washroom1. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "one"}, {"start": 26, "end": 34, "label": "ROOM", "text": "washroom"}, {"start": 36, "end": 39, "label": "QUANT", "text": "two"}, {"start": 40, "end": 48, "label": "ROOM", "text": "bedrooms"}, {"start": 50, "end": 53, "label": "QUANT", "text": "one"}, {"start": 54, "end": 64, "label": "ROOM", "text": "livingroom"}, {"start": 70, "end": 73, "label": "QUANT", "text": "one"}, {"start": 74, "end": 81, "label": "ROOM", "text": "kitchen"}, {"start": 97, "end": 106, "label": "ROOM", "text": "washroom1"}, {"start": 111, "end": 120, "label": "ROOM", "text": "2 squares"}, {"start": 124, "end": 133, "label": "DIRECTION", "text": "northeast"}, {"start": 214, "end": 222, "label": "ROOM", "text": "bedroom1"}, {"start": 229, "end": 238, "label": "DIRECTION", "text": "southwest"}, {"start": 239, "end": 259, "label": "DIMENSION", "text": "with 6 square meters"}, {"start": 335, "end": 343, "label": "ROOM", "text": "bedroom2"}, {"start": 430, "end": 434, "label": "DIRECTION", "text": "west"}, {"start": 440, "end": 455, "label": "DIMENSION", "text": "5 square meters"}, {"start": 473, "end": 483, "label": "DIMENSION", "text": "18 squares"}, {"start": 574, "end": 582, "label": "ROOM", "text": "kitchen1"}, {"start": 651, "end": 673, "label": "DIMENSION", "text": "covers 4 square meters"}, {"start": 685, "end": 694, "label": "DIRECTION", "text": "northeast"}, {"start": 696, "end": 762, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, washroom1"}, {"start": 762, "end": 792, "label": "CONNECTION", "text": ". bedroom1 is next to bedroom2"}, {"start": 794, "end": 827, "label": "CONNECTION", "text": "kitchen1 is adjacent to washroom1"}]},
{"document": "House has one washroom, one livingroom, two studys, one bedroom, one kitchen, and one balcony. Specifically, washroom1 is in west with 4 square meters. washroom1 floor is Blue Ceramic_Tile as well as wall is Stone_Brick and Blue. Additionally, livingroom1 wall is White Bamboo_Vine while floor is Coating and Blue. livingroom1 is in center with 34 square meters. Besides, study1 covers 10 square meters located in east. wall of study1 is Wood_Veneer and Orange, and uses White Wood_Veneer for floor. wall of study2 is Ceramic_Tile and Gray as well as floor is Pure_Color_Wood and Earth_color. study2 is in west with 7 square meters. bedroom1 floor is Wood_color Pure_Color_Wood while has Earth_color Stone_Brick wall. bedroom1 has 13 squares in center. Moreover, wall of kitchen1 is Cement_Board and Yellow as well as has Wood_color Jade floor. kitchen1 has 5 squares in center. floor of balcony1 is Wood_Veneer and Pink while wall is Pure_Color_Wood and White. balcony1 covers 5 square meters located in east. livingroom1 is adjacent to bedroom1, study1, study2, balcony1, kitchen1, washroom1. study1, kitchen1 and bedroom1 are connected. study2 is next to washroom1. washroom1 and kitchen1 are connected. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "one"}, {"start": 14, "end": 22, "label": "ROOM", "text": "washroom"}, {"start": 24, "end": 27, "label": "QUANT", "text": "one"}, {"start": 28, "end": 38, "label": "ROOM", "text": "livingroom"}, {"start": 40, "end": 43, "label": "QUANT", "text": "two"}, {"start": 44, "end": 50, "label": "ROOM", "text": "studys"}, {"start": 52, "end": 55, "label": "QUANT", "text": "one"}, {"start": 56, "end": 63, "label": "ROOM", "text": "bedroom"}, {"start": 65, "end": 68, "label": "QUANT", "text": "one"}, {"start": 69, "end": 76, "label": "ROOM", "text": "kitchen"}, {"start": 82, "end": 85, "label": "QUANT", "text": "one"}, {"start": 86, "end": 93, "label": "ROOM", "text": "balcony"}, {"start": 109, "end": 118, "label": "ROOM", "text": "washroom1"}, {"start": 125, "end": 129, "label": "DIRECTION", "text": "west"}, {"start": 130, "end": 150, "label": "DIMENSION", "text": "with 4 square meters"}, {"start": 244, "end": 255, "label": "ROOM", "text": "livingroom1"}, {"start": 345, "end": 361, "label": "DIMENSION", "text": "34 square meters"}, {"start": 372, "end": 378, "label": "ROOM", "text": "study1"}, {"start": 386, "end": 402, "label": "DIMENSION", "text": "10 square meters"}, {"start": 414, "end": 418, "label": "DIRECTION", "text": "east"}, {"start": 508, "end": 514, "label": "ROOM", "text": "study2"}, {"start": 606, "end": 610, "label": "DIRECTION", "text": "west"}, {"start": 616, "end": 631, "label": "DIMENSION", "text": "7 square meters"}, {"start": 731, "end": 741, "label": "DIMENSION", "text": "13 squares"}, {"start": 771, "end": 779, "label": "ROOM", "text": "kitchen1"}, {"start": 858, "end": 867, "label": "DIMENSION", "text": "5 squares"}, {"start": 971, "end": 993, "label": "DIMENSION", "text": "covers 5 square meters"}, {"start": 1005, "end": 1009, "label": "DIRECTION", "text": "east"}, {"start": 1011, "end": 1093, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, study1, study2, balcony1, kitchen1, washroom1"}, {"start": 1095, "end": 1138, "label": "CONNECTION", "text": "study1, kitchen1 and bedroom1 are connected"}, {"start": 1140, "end": 1167, "label": "CONNECTION", "text": "study2 is next to washroom1"}, {"start": 1169, "end": 1205, "label": "CONNECTION", "text": "washroom1 and kitchen1 are connected"}]},
{"document": "House has two bedrooms, one washroom, one balcony, one livingroom, and one kitchen. To be specific, bedroom1 has 14 squares in north. bedroom1 has Purple Log wall as well as uses Yellow Wood_Grain for floor. Additionally, bedroom2 uses Red Rock_Plate for floor while wall is Ceramics and Gray. bedroom2 covers 11 square meters located in southeast. floor of washroom1 is Pure_Color_Wood and Red as well as wall is Orange Coating. washroom1 covers 3 square meters located in east. balcony1 has 5 squares in north. balcony1 wall is Green Log, and uses Red Pure_Color_Wood for floor. In addition, livingroom1 is in center with 26 square meters. wall of livingroom1 is Wood_Grain and Wood_color as well as uses Green Bamboo_Vine for floor. Moreover, wall of kitchen1 is Quartz and Black, and has Earth_color Wallpaper floor. kitchen1 is in south with 5 square meters. livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, balcony1, washroom1. balcony1, washroom1 and bedroom1 are connected. bedroom2 is adjacent to kitchen1, washroom1. ", "annotation": [{"start": 10, "end": 13, "label": "QUANT", "text": "two"}, {"start": 14, "end": 22, "label": "ROOM", "text": "bedrooms"}, {"start": 24, "end": 27, "label": "QUANT", "text": "one"}, {"start": 28, "end": 36, "label": "ROOM", "text": "washroom"}, {"start": 38, "end": 41, "label": "QUANT", "text": "one"}, {"start": 42, "end": 49, "label": "ROOM", "text": "balcony"}, {"start": 51, "end": 54, "label": "QUANT", "text": "one"}, {"start": 55, "end": 65, "label": "ROOM", "text": "livingroom"}, {"start": 71, "end": 74, "label": "QUANT", "text": "one"}, {"start": 75, "end": 82, "label": "ROOM", "text": "kitchen"}, {"start": 100, "end": 108, "label": "ROOM", "text": "bedroom1"}, {"start": 113, "end": 123, "label": "DIMENSION", "text": "14 squares"}, {"start": 127, "end": 132, "label": "DIRECTION", "text": "north"}, {"start": 222, "end": 230, "label": "ROOM", "text": "bedroom2"}, {"start": 310, "end": 326, "label": "DIMENSION", "text": "11 square meters"}, {"start": 338, "end": 347, "label": "DIRECTION", "text": "southeast"}, {"start": 358, "end": 367, "label": "ROOM", "text": "washroom1"}, {"start": 447, "end": 462, "label": "DIMENSION", "text": "3 square meters"}, {"start": 474, "end": 478, "label": "DIRECTION", "text": "east"}, {"start": 480, "end": 488, "label": "ROOM", "text": "balcony1"}, {"start": 493, "end": 502, "label": "DIMENSION", "text": "5 squares"}, {"start": 506, "end": 511, "label": "DIRECTION", "text": "north"}, {"start": 624, "end": 640, "label": "DIMENSION", "text": "26 square meters"}, {"start": 836, "end": 841, "label": "DIRECTION", "text": "south"}, {"start": 847, "end": 862, "label": "DIMENSION", "text": "5 square meters"}, {"start": 864, "end": 940, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, kitchen1, balcony1, washroom1"}, {"start": 942, "end": 988, "label": "CONNECTION", "text": "balcony1, washroom1 and bedroom1 are connected"}, {"start": 990, "end": 1033, "label": "CONNECTION", "text": "bedroom2 is adjacent to kitchen1, washroom1"}]},
{"document": "The house plan has one washroom, two bedrooms, one livingroom, and one kitchen. More specifically, washroom1 uses Pink Quartz for floor, and wall is Green Wood_Veneer. washroom1 covers 4 square meters located in east. In addition, bedroom1 is in south with 13 square meters. bedroom1 has Earth_color Marble floor as well as has Green Wallpaper wall. Besides, bedroom2 is in center with 10 square meters. bedroom2 wall is Red Ceramics while uses Earth_color Wood_Grain for floor. Additionally, livingroom1 has Wood_color Wood_Veneer floor, and wall is Bamboo_Vine and Yellow. livingroom1 has 41 squares in center. Besides, kitchen1 uses Black Stone_Brick for floor as well as has Wood_color Cement_Board wall. kitchen1 is in northeast with 9 square meters. bedroom1, bedroom2, kitchen1, washroom1 and livingroom1 are connected. bedroom1 is adjacent to washroom1. kitchen1, washroom1 and bedroom2 are connected. ", "annotation": [{"start": 19, "end": 22, "label": "QUANT", "text": "one"}, {"start": 23, "end": 31, "label": "ROOM", "text": "washroom"}, {"start": 33, "end": 36, "label": "QUANT", "text": "two"}, {"start": 37, "end": 45, "label": "ROOM", "text": "bedrooms"}, {"start": 47, "end": 50, "label": "QUANT", "text": "one"}, {"start": 51, "end": 61, "label": "ROOM", "text": "livingroom"}, {"start": 67, "end": 70, "label": "QUANT", "text": "one"}, {"start": 71, "end": 78, "label": "ROOM", "text": "kitchen"}, {"start": 99, "end": 108, "label": "ROOM", "text": "washroom1"}, {"start": 185, "end": 200, "label": "DIMENSION", "text": "4 square meters"}, {"start": 212, "end": 216, "label": "DIRECTION", "text": "east"}, {"start": 231, "end": 239, "label": "ROOM", "text": "bedroom1"}, {"start": 246, "end": 251, "label": "DIRECTION", "text": "south"}, {"start": 257, "end": 273, "label": "DIMENSION", "text": "13 square meters"}, {"start": 275, "end": 283, "label": "ROOM", "text": "bedroom1"}, {"start": 357, "end": 367, "label": "ROOM", "text": ", bedroom2"}, {"start": 374, "end": 380, "label": "DIRECTION", "text": "center"}, {"start": 386, "end": 402, "label": "DIMENSION", "text": "10 square meters"}, {"start": 493, "end": 504, "label": "ROOM", "text": "livingroom1"}, {"start": 591, "end": 601, "label": "DIMENSION", "text": "41 squares"}, {"start": 605, "end": 611, "label": "DIRECTION", "text": "center"}, {"start": 622, "end": 630, "label": "ROOM", "text": "kitchen1"}, {"start": 739, "end": 754, "label": "DIMENSION", "text": "9 square meters"}, {"start": 756, "end": 825, "label": "CONNECTION", "text": "bedroom1, bedroom2, kitchen1, washroom1 and livingroom1 are connected"}, {"start": 827, "end": 860, "label": "CONNECTION", "text": "bedroom1 is adjacent to washroom1"}, {"start": 862, "end": 908, "label": "CONNECTION", "text": "kitchen1, washroom1 and bedroom2 are connected"}]},
{"document": "The building contains one washroom, one livingroom, and one bedroom. More specifically, washroom1 uses Purple Wood_Veneer for floor as well as has Blue Wood_Grain wall. washroom1 covers 5 square meters located in northwest. Moreover, livingroom1 has 29 squares in south. livingroom1 floor is White Marble while has Yellow Jade wall. bedroom1 is in north with 11 square meters. bedroom1 floor is Black Rock_Plate, and wall is Wood_Grain and Gray. bedroom1, washroom1 and livingroom1 are connected. bedroom1 is adjacent to washroom1. ", "annotation": [{"start": 22, "end": 25, "label": "QUANT", "text": "one"}, {"start": 26, "end": 34, "label": "ROOM", "text": "washroom"}, {"start": 36, "end": 39, "label": "QUANT", "text": "one"}, {"start": 40, "end": 50, "label": "ROOM", "text": "livingroom"}, {"start": 56, "end": 59, "label": "QUANT", "text": "one"}, {"start": 60, "end": 67, "label": "ROOM", "text": "bedroom"}, {"start": 88, "end": 97, "label": "ROOM", "text": "washroom1"}, {"start": 169, "end": 178, "label": "ROOM", "text": "washroom1"}, {"start": 186, "end": 201, "label": "DIMENSION", "text": "5 square meters"}, {"start": 213, "end": 222, "label": "DIRECTION", "text": "northwest"}, {"start": 234, "end": 245, "label": "ROOM", "text": "livingroom1"}, {"start": 250, "end": 260, "label": "DIMENSION", "text": "29 squares"}, {"start": 264, "end": 269, "label": "DIRECTION", "text": "south"}, {"start": 333, "end": 341, "label": "ROOM", "text": "bedroom1"}, {"start": 348, "end": 353, "label": "DIRECTION", "text": "north"}, {"start": 359, "end": 375, "label": "DIMENSION", "text": "11 square meters"}, {"start": 446, "end": 495, "label": "CONNECTION", "text": "bedroom1, washroom1 and livingroom1 are connected"}, {"start": 495, "end": 530, "label": "CONNECTION", "text": ". bedroom1 is adjacent to washroom1"}]},
{"document": "Building layout contains one washroom, one livingroom, one study, two bedrooms, one kitchen, and one balcony. To be specific, washroom1 has Earth_color Wood_Grain floor as well as wall is Ceramic_Tile and Earth_color. washroom1 has 5 squares in north. floor of livingroom1 is Bamboo_Vine and Pink while has Wood_color Coating wall. livingroom1 has 41 squares in south. In addition, study1 covers 9 square meters located in northeast. study1 uses Red Ceramics for floor as well as wall is Gray Wallpaper. Besides, floor of bedroom1 is Ceramics and Pink while has Black Wood_Grain wall. bedroom1 covers 12 square meters located in west. bedroom2 is in northwest with 12 square meters. bedroom2 wall is Blue Ceramics as well as floor is Black Wood_Grain. floor of kitchen1 is Quartz and Red, and wall is Red Wallpaper. kitchen1 has 6 squares in east. balcony1 covers 6 square meters located in southwest. balcony1 floor is Green Wood_Veneer while wall is Cement_Board and Yellow. bedroom1, bedroom2, study1, kitchen1, balcony1, washroom1 and livingroom1 are connected. bedroom1 is next to bedroom2. washroom1 and bedroom2 are connected. study1 is adjacent to kitchen1, washroom1. ", "annotation": [{"start": 25, "end": 28, "label": "QUANT", "text": "one"}, {"start": 29, "end": 37, "label": "ROOM", "text": "washroom"}, {"start": 39, "end": 42, "label": "QUANT", "text": "one"}, {"start": 43, "end": 53, "label": "ROOM", "text": "livingroom"}, {"start": 55, "end": 58, "label": "QUANT", "text": "one"}, {"start": 59, "end": 64, "label": "ROOM", "text": "study"}, {"start": 66, "end": 69, "label": "QUANT", "text": "two"}, {"start": 70, "end": 78, "label": "ROOM", "text": "bedrooms"}, {"start": 80, "end": 83, "label": "QUANT", "text": "one"}, {"start": 84, "end": 91, "label": "ROOM", "text": "kitchen"}, {"start": 97, "end": 100, "label": "QUANT", "text": "one"}, {"start": 101, "end": 108, "label": "ROOM", "text": "balcony"}, {"start": 124, "end": 135, "label": "ROOM", "text": ", washroom1"}, {"start": 232, "end": 241, "label": "DIMENSION", "text": "5 squares"}, {"start": 245, "end": 250, "label": "DIRECTION", "text": "north"}, {"start": 261, "end": 272, "label": "ROOM", "text": "livingroom1"}, {"start": 348, "end": 358, "label": "DIMENSION", "text": "41 squares"}, {"start": 382, "end": 388, "label": "ROOM", "text": "study1"}, {"start": 396, "end": 411, "label": "DIMENSION", "text": "9 square meters"}, {"start": 423, "end": 432, "label": "DIRECTION", "text": "northeast"}, {"start": 522, "end": 530, "label": "ROOM", "text": "bedroom1"}, {"start": 601, "end": 617, "label": "DIMENSION", "text": "12 square meters"}, {"start": 629, "end": 633, "label": "DIRECTION", "text": "west"}, {"start": 633, "end": 643, "label": "ROOM", "text": ". bedroom2"}, {"start": 650, "end": 659, "label": "DIRECTION", "text": "northwest"}, {"start": 665, "end": 681, "label": "DIMENSION", "text": "12 square meters"}, {"start": 761, "end": 769, "label": "ROOM", "text": "kitchen1"}, {"start": 829, "end": 838, "label": "DIMENSION", "text": "6 squares"}, {"start": 846, "end": 856, "label": "ROOM", "text": ". balcony1"}, {"start": 864, "end": 879, "label": "DIMENSION", "text": "6 square meters"}, {"start": 891, "end": 900, "label": "DIRECTION", "text": "southwest"}, {"start": 977, "end": 1064, "label": "CONNECTION", "text": "bedroom1, bedroom2, study1, kitchen1, balcony1, washroom1 and livingroom1 are connected"}, {"start": 1066, "end": 1094, "label": "CONNECTION", "text": "bedroom1 is next to bedroom2"}, {"start": 1096, "end": 1132, "label": "CONNECTION", "text": "washroom1 and bedroom2 are connected"}, {"start": 1134, "end": 1175, "label": "CONNECTION", "text": "study1 is adjacent to kitchen1, washroom1"}]},
{"document": "The building contains three bedrooms, one washroom, two balconys, one livingroom, and one kitchen. In practice, bedroom1 has 16 squares in west. bedroom1 wall is Gray Coating as well as has Blue Mosaic floor. bedroom2 floor is White Rock_Plate, and wall is Green Quartz. bedroom2 has 10 squares in northwest. Additionally, bedroom3 has Earth_color Painted_Wood floor while wall is Black Wood_Grain. bedroom3 has 9 squares in north. washroom1 is in northwest with 5 square meters. floor of washroom1 is Granite and Wood_color as well as has Yellow Wood_Grain wall. balcony1 wall is Black Log while has Green Painted_Wood floor. balcony1 is in south with 7 square meters. In addition, balcony2 has Yellow Granite floor as well as wall is Wood_Veneer and Blue. balcony2 has 4 squares in northeast. livingroom1 covers 36 square meters located in center. livingroom1 has Black Log wall, and floor is Purple Jade. kitchen1 is in northeast with 7 square meters. kitchen1 floor is Gray Mosaic while wall is Blue Rock_Plate. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1. bedroom2 and bedroom1 are connected. bedroom2 is next to washroom1. washroom1 and bedroom3 are connected. kitchen1 is next to balcony2. ", "annotation": [{"start": 0, "end": 21, "label": "CONNECTION", "text": "The building contains"}, {"start": 22, "end": 27, "label": "QUANT", "text": "three"}, {"start": 28, "end": 36, "label": "ROOM", "text": "bedrooms"}, {"start": 36, "end": 41, "label": "QUANT", "text": ", one"}, {"start": 42, "end": 50, "label": "ROOM", "text": "washroom"}, {"start": 52, "end": 55, "label": "QUANT", "text": "two"}, {"start": 56, "end": 64, "label": "ROOM", "text": "balconys"}, {"start": 64, "end": 69, "label": "QUANT", "text": ", one"}, {"start": 70, "end": 80, "label": "ROOM", "text": "livingroom"}, {"start": 86, "end": 89, "label": "QUANT", "text": "one"}, {"start": 90, "end": 97, "label": "ROOM", "text": "kitchen"}, {"start": 112, "end": 120, "label": "ROOM", "text": "bedroom1"}, {"start": 125, "end": 135, "label": "DIMENSION", "text": "16 squares"}, {"start": 136, "end": 143, "label": "DIRECTION", "text": "in west"}, {"start": 145, "end": 153, "label": "ROOM", "text": "bedroom1"}, {"start": 207, "end": 217, "label": "ROOM", "text": ". bedroom2"}, {"start": 271, "end": 279, "label": "ROOM", "text": "bedroom2"}, {"start": 284, "end": 294, "label": "DIMENSION", "text": "10 squares"}, {"start": 295, "end": 307, "label": "DIRECTION", "text": "in northwest"}, {"start": 323, "end": 331, "label": "ROOM", "text": "bedroom3"}, {"start": 399, "end": 407, "label": "ROOM", "text": "bedroom3"}, {"start": 412, "end": 421, "label": "DIMENSION", "text": "9 squares"}, {"start": 425, "end": 430, "label": "DIRECTION", "text": "north"}, {"start": 432, "end": 441, "label": "ROOM", "text": "washroom1"}, {"start": 445, "end": 457, "label": "DIRECTION", "text": "in northwest"}, {"start": 458, "end": 478, "label": "DIMENSION", "text": "with 5 square meters"}, {"start": 489, "end": 498, "label": "ROOM", "text": "washroom1"}, {"start": 564, "end": 572, "label": "ROOM", "text": "balcony1"}, {"start": 627, "end": 635, "label": "ROOM", "text": "balcony1"}, {"start": 639, "end": 647, "label": "DIRECTION", "text": "in south"}, {"start": 653, "end": 668, "label": "DIMENSION", "text": "7 square meters"}, {"start": 683, "end": 691, "label": "ROOM", "text": "balcony2"}, {"start": 758, "end": 766, "label": "ROOM", "text": "balcony2"}, {"start": 767, "end": 780, "label": "DIMENSION", "text": "has 4 squares"}, {"start": 784, "end": 793, "label": "DIRECTION", "text": "northeast"}, {"start": 795, "end": 806, "label": "ROOM", "text": "livingroom1"}, {"start": 814, "end": 830, "label": "DIMENSION", "text": "36 square meters"}, {"start": 850, "end": 861, "label": "ROOM", "text": "livingroom1"}, {"start": 908, "end": 916, "label": "ROOM", "text": "kitchen1"}, {"start": 923, "end": 932, "label": "DIRECTION", "text": "northeast"}, {"start": 938, "end": 953, "label": "DIMENSION", "text": "7 square meters"}, {"start": 1016, "end": 1102, "label": "CONNECTION", "text": "livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1"}, {"start": 1104, "end": 1139, "label": "CONNECTION", "text": "bedroom2 and bedroom1 are connected"}, {"start": 1141, "end": 1170, "label": "CONNECTION", "text": "bedroom2 is next to washroom1"}, {"start": 1172, "end": 1208, "label": "CONNECTION", "text": "washroom1 and bedroom3 are connected"}, {"start": 1210, "end": 1238, "label": "CONNECTION", "text": "kitchen1 is next to balcony2"}]}]

# %%
import pandas as pd
df = pd.json_normalize(data)
print(df)
# Out:
#                                                                                                                                                                                                    document                                                                                                                                                                                               annotation
# 0   The house plan has two bedrooms, two washrooms, two balconys, one livingroom, and one kitchen. To be specific, floor of bedroom1 is Quartz and White, and wall is Wall_Cloth and Yellow. bedroom1 is...  [{'start': 19, 'end': 22, 'label': 'QUANT', 'text': 'two'}, {'start': 23, 'end': 31, 'label': 'ROOM', 'text': 'bedrooms'}, {'start': 33, 'end': 36, 'label': 'QUANT', 'text': 'two'}, {'start': 37, ...
# ...

# %%
df = df.drop(['document'], axis=1)

# %%
# converting the dataframe to numpy array
a = df.iloc[:].values
type(a)
# Out:
# numpy.ndarray

# %%
print(a)
# Out:
# [[list([{'start': 19, 'end': 22, 'label': 'QUANT', 'text': 'two'}, {'start': 23, 'end': 31, 'label': 'ROOM', 'text': 'bedrooms'}, {'start': 33, 'end': 36, 'label': 'QUANT', 'text': 'two'}, {'start': 37, 'end': 46, 'label': 'ROOM', 'text': 'washrooms'}, {'start': 48, 'end': 51, 'label': 'QUANT', 'text': 'two'}, {'start': 52, 'end': 60, 'label': 'ROOM', 'text': 'balconys'}, {'start': 62, 'end': 65, 'label': 'QUANT', 'text': 'one'}, {'start': 66, 'end': 76, 'label': 'ROOM', 'text': 'livingroom'}, {'start': 82, 'end': 85, 'label': 'QUANT', 'text': 'one'}, {'start': 86, 'end': 93, 'label': 'ROOM', 'text': 'kitchen'}, {'start': 120, 'end': 128, 'label': 'ROOM', 'text': 'bedroom1'}, {'start': 200, 'end': 209, 'label': 'DIRECTION', 'text': 'southwest'}, {'start': 215, 'end': 231, 'label': 'DIMENSION', 'text': '17 square meters'}, {'start': 246, 'end': 254, 'label': 'ROOM', 'text': 'bedroom2'}, {'start': 341, 'end': 351, 'label': 'DIMENSION', 'text': '12 squares'}, {'start': 355, 'end': 360, 
# ...

# %%
# we only need the dicts from "annotation" where the label "CONNECTION" appears
d = []
for i in range(len(a)):
    b = a[i]
    for j in range(len(b)):
        c = b[j]
        for k in range(len(c)):
            print(c[k])
            if "CONNECTION" in c[k].values():
                d.append(c[k])
# Out:
# {'start': 19, 'end': 22, 'label': 'QUANT', 'text': 'two'}
# {'start': 23, 'end': 31, 'label': 'ROOM', 'text': 'bedrooms'}
# {'start': 33, 'end': 36, 'label': 'QUANT', 'text': 'two'}
# {'start': 37, 'end': 46, 'label': 'ROOM', 'text': 'washrooms'}
# {'start': 48, 'end': 51, 'label': 'QUANT', 'text': 'two'}
# {'start': 52, 'end': 60, 'label': 'ROOM', 'text': 'balconys'}
# {'start': 62, 'end': 65, 'label': 'QUANT', 'text': 'one'}
# {'start': 66, 'end': 76, 'label': 'ROOM', 'text': 'livingroom'}
# {'start': 82, 'end': 85, 'label': 'QUANT', 'text': 'one'}
# {'start': 86, 'end': 93, 'label': 'ROOM', 'text': 'kitchen'}
# {'start': 120, 'end': 128, 'label': 'ROOM', 'text': 'bedroom1'}
# {'start': 200, 'end': 209, 'label': 'DIRECTION', 'text': 'southwest'}
# {'start': 215, 'end': 231, 'label': 'DIMENSION', 'text': '17 square meters'}
# {'start': 246, 'end': 254, 'label': 'ROOM', 'text': 'bedroom2'}
# {'start': 341, 'end': 351, 'label': 'DIMENSION', 'text': '12 squares'}
# ...

# %%
# d has all the dicts where the label "CONNECTION" appears
for i in range(len(d)):
    print(d[i])
# Out:
# {'start': 1069, 'end': 1169, 'label': 'CONNECTION', 'text': 'bedroom1, bedroom2, kitchen1, balcony1, washroom1, washroom2, balcony2 and livingroom1 are connected'}
# {'start': 1171, 'end': 1214, 'label': 'CONNECTION', 'text': 'bedroom1 is adjacent to balcony1, washroom1'}
# {'start': 1216, 'end': 1255, 'label': 'CONNECTION', 'text': 'bedroom2 is next to washroom2, balcony2'}
# {'start': 1257, 'end': 1289, 'label': 'CONNECTION', 'text': 'kitchen1 is adjacent to balcony2'}
# {'start': 1291, 'end': 1328, 'label': 'CONNECTION', 'text': 'washroom2 and washroom1 are connected'}
# {'start': 946, 'end': 1033, 'label': 'CONNECTION', 'text': 'bedroom1, bedroom2, study1, balcony1, kitchen1, washroom1 and livingroom1 are connected'}
# {'start': 1035, 'end': 1074, 'label': 'CONNECTION', 'text': 'bedroom1 is next to balcony1, washroom1'}
# {'start': 1076, 'end': 1137, 'label': 'CONNECTION', 'text': 'bedroom2 is adjacent to study1. kitchen1 is next to washroom1'}
# ...

# %%
print(len(a), len(b), len(c), len(d))
type(d)
# Out:
# 50 1 46 189
# list

# %%
df = pd.DataFrame(d)

# %%
print(df)
# Out:
#      start  ...                                                                                                  text
# 0     1069  ...  bedroom1, bedroom2, kitchen1, balcony1, washroom1, washroom2, balcony2 and livingroom1 are connected
# 1     1171  ...                                                           bedroom1 is adjacent to balcony1, washroom1
# 2     1216  ...                                                               bedroom2 is next to washroom2, balcony2
# 3     1257  ...                                                                      kitchen1 is adjacent to balcony2
# 4     1291  ...                                                                 washroom2 and washroom1 are connected
# ..     ...  ...                                                                                                   ...
# 184   1016  ...                livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1
# ...

# %%
# saving the data to an excel sheet, used for readability purposes
df.to_excel('data.xlsx')

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
df.shape
# Out:
# (189, 4)

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
entity_pairs = []

for i in tqdm(df["text"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 189/189 [00:01<00:00, 120.43it/s]

# %%
entity_pairs[10:20]
# Out:
# [['bedroom2', ''],
#  ['kitchen1', ''],
#  ['livingroom1', ''],
#  ['washroom1', ''],
#  ['bedroom2', ''],
#  ['bedroom1', ''],
#  ['bedroom1', ''],
#  ['washroom2', ''],
#  ['bedroom3', ''],
#  ['washroom2', '']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", None, pattern) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
relations = [get_relation(i) for i in tqdm(df['text'])]
# Out:
# 100%|██████████| 189/189 [00:01<00:00, 117.50it/s]

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(15,15))

pos = nx.spring_layout(G, k = 1.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
kg_df.to_excel('connected.xlsx')

# %%
# this dataframe has source and target rooms which are next to each other
next_df = kg_df[kg_df['edge'] == 'is next']
next_df
# Out:
#                  source       target     edge
# 2              bedroom2    washroom2  is next
# 7              kitchen1               is next
# 16             bedroom1               is next
# 18             bedroom3               is next
# 21             bedroom1     bedroom2  is next
# 23             bedroom2               is next
# 28             bedroom3               is next
# 31             bedroom1               is next
# 34              closet1    washroom2  is next
# 40            washroom2  livingroom2  is next
# 42             bedroom1               is next
# 44             bedroom1               is next
# 47             kitchen1     bedroom1  is next
# 51             bedroom1     bedroom2  is next
# 53             bedroom2               is next
# 56             bedroom1     bedroom2  is next
# 58             kitchen1               is next
# 60             bedroom1     bedroom2  is next
# 63             kitchen1     balcony2  is next
# ...

# %%
G=nx.from_pandas_edgelist(next_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())
plt.figure(figsize=(15,15))

pos = nx.spring_layout(G, k = 1.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# # Using the plan50.zip file

# %%
# upload the plan50.zip first
# !unzip plan50.zip
# Out:
# Archive:  plan50.zip
#   inflating: 01950.txt
#   inflating: 01951.txt
#   inflating: 01952.txt
#   inflating: 01953.txt
#   inflating: 01954.txt
#   inflating: 01955.txt
#   inflating: 01956.txt
#   inflating: 01957.txt
#   inflating: 01958.txt
#   inflating: 01959.txt
#   inflating: 01960.txt
#   inflating: 01961.txt
#   inflating: 01962.txt
#   inflating: 01963.txt
#   inflating: 01964.txt
#   inflating: 01965.txt
#   inflating: 01966.txt
#   inflating: 01967.txt
#   inflating: 01968.txt
#   inflating: 01969.txt
#   inflating: 01970.txt
#   inflating: 01971.txt
#   inflating: 01972.txt
#   inflating: 01973.txt
#   inflating: 01974.txt
#   inflating: 01975.txt
#   inflating: 01976.txt
#   inflating: 01977.txt
#   inflating: 01978.txt
#   inflating: 01979.txt
#   inflating: 01980.txt
#   inflating: 01981.txt
#   inflating: 01982.txt
#   inflating: 01983.txt
#   inflating: 01984.txt
#   inflating: 01985.txt
#   inflating: 01986.txt
#   inflating: 01987.txt
#   inflating: 01988.txt
# ...

# %%
# since the data is a corpus of 50 text files, we need to convert them all to a single csv first

import csv
import os

header = ["S.no", "Description"]

with open('data.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output)
    csv_output.writerow(header)

    for x in range(50):
        filepath = os.path.normpath(r'0{}.txt'.format(x+1950))

        with open(filepath, 'r', newline='') as f_text:
            csv_text = csv.reader(f_text, delimiter=':', skipinitialspace=True)
            csv_output.writerow(row[0] for row in csv_text)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

doc = nlp("The 22-year-old recently won ATP Challenger tournament.")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# The ... det
# 22-year ... npadvmod
# - ... punct
# old ... nsubj
# recently ... advmod
# won ... ROOT
# ATP ... compound
# Challenger ... compound
# tournament ... dobj
# . ... punct

# %%
doc = nlp("Nagal won the first set.")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# Nagal ... nsubj
# won ... ROOT
# the ... det
# first ... amod
# set ... dobj
# . ... punct

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
candidate_sentences = pd.read_csv("data.csv")
candidate_sentences.shape
# Out:
# (50, 2)

# %%
doc = nlp("the drawdown process is governed by astm standard d823")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# the ... det
# drawdown ... amod
# process ... nsubjpass
# is ... auxpass
# governed ... ROOT
# by ... agent
# astm ... compound
# standard ... amod
# d823 ... pobj

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["S.no"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 28.46it/s]

# %%
entity_pairs[10:20]
# Out:
# [['kitchen1', 'closet1'],
#  ['bedroom2', 'Wood_color Ceramic_Tile wall'],
#  ['washroom1', 'closet1'],
#  ['washroom1', 'bedroom2'],
#  ['closet1', 'bedroom2'],
#  ['washroom1', 'washroom2'],
#  ['balcony1', 'bedroom2'],
#  ['kitchen1', 'washroom2'],
#  ['bedroom1', 'square  center'],
#  ['washroom1  washroom1', 'square  meters']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", None, pattern) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['S.no'])]
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 29.65it/s]

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(15,15))

pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="connected"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="is adjacent"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="is next"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
# we can visualize all of these dataframes as well
is_next_df = kg_df[kg_df['edge'] == 'is next']
is_adjacent_df = kg_df[kg_df['edge'] == 'is adjacent']
connected_df = kg_df[kg_df['edge'] == 'connected']

# %%
is_next_df
# Out:
#                             source                   target     edge
# 1                         kitchen1             5  southeast  is next
# 2                         bedroom2                 bedroom2  is next
# 3                         bedroom1                 12  west  is next
# 4                         bedroom2  Wood_color Quartz floor  is next
# 8               bedroom2  bedroom1                 bedroom2  is next
# 9                         bedroom3        square  northwest  is next
# 10                        kitchen1                  closet1  is next
# 14                         closet1                 bedroom2  is next
# 17                        kitchen1                washroom2  is next
# 20                        kitchen1                     Pink  is next
# 21                       washroom2                corridor1  is next
# 26              bedroom2  bedroom1                 kitchen1  is next
# 27                       washroom1                  closet1  is next
# ...

# %%
is_adjacent_df
# Out:
#                        source                        target         edge
# 5        washroom2  washroom1                     washroom2  is adjacent
# 6                   washroom2                     washroom2  is adjacent
# 7                    bedroom3                     washroom2  is adjacent
# 11                   bedroom2  Wood_color Ceramic_Tile wall  is adjacent
# 12                  washroom1                       closet1  is adjacent
# 15                  washroom1                     washroom2  is adjacent
# 18                   bedroom1                square  center  is adjacent
# 22                  washroom1                     washroom2  is adjacent
# 23                   bedroom1                      bedroom2  is adjacent
# 24                   bedroom2             square  southwest  is adjacent
# 25                  washroom1                     washroom2  is adjacent
# 30         kitchen1  kitchen1                square  meters  is adjacent
# ...

# %%
connected_df
# Out:
#                   source                       target       edge
# 0               kitchen1                     bedroom2  connected
# 13             washroom1                     bedroom2  connected
# 16              balcony1                     bedroom2  connected
# 19  washroom1  washroom1               square  meters  connected
# 28    bedroom2  bedroom2                 square  west  connected
# 38              balcony1  well Green Stone_Brick wall  connected
# 43             washroom2                    washroom1  connected
# 44    kitchen1  kitchen2                     kitchen2  connected
# 48             washroom3                    washroom2  connected
